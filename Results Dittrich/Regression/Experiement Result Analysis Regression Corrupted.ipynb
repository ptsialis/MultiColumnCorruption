# %% [markdown]
# # Visualize Results: Downstream Performance - Regression Corrupted Experiments
#
# [Set Average Best Imputation Method Manually](#Set-Average-Best-Imputation-Method-Manually)
#
# This notebook should answer the questions: *Does imputation lead to better downstream performances?*
#
# Data needs to be preprocessed with other notebook, her we only import two csv files with raw data regarding the results of the experiment and information about the used datasets!

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import seaborn as sns
from pandas.api.types import CategoricalDtype
from pathlib import Path

import plotly as py
import plotly.express as px
import plotly.graph_objects as go
import xarray as xr


# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Settings

# %%
sns.set(style="whitegrid")
sns.set_context('paper', font_scale=1.5)
mpl.rcParams['lines.linewidth'] = '2'

# %%
CLF_METRIC = "Classification Tasks"
REG_METRIC = "Regression Tasks"

DOWNSTREAM_RESULT_TYPE = "downstream_performance_mean"
IMPUTE_RESULT_TYPE = "impute_performance_mean"

# %% [markdown]
# ## Data Preparation

# %%
# import preprocessed data from experiments
results = pd.read_csv('../regression_corrupted.csv')
results
# Out:
#                             experiment           imputer   task missing_type  \
# 0      corrupted_regression_experiment  AutoKerasImputer   1193          MAR
# 1      corrupted_regression_experiment  AutoKerasImputer   1193          MAR
# 2      corrupted_regression_experiment  AutoKerasImputer   1193          MAR
# 3      corrupted_regression_experiment  AutoKerasImputer   1193          MAR
# 4      corrupted_regression_experiment  AutoKerasImputer   1193          MAR
# ...                                ...               ...    ...          ...
# 16135  corrupted_regression_experiment        VAEImputer  42712         MNAR
# 16136  corrupted_regression_experiment        VAEImputer  42712         MNAR
# 16137  corrupted_regression_experiment        VAEImputer  42712         MNAR
# 16138  corrupted_regression_experiment        VAEImputer  42712         MNAR
# 16139  corrupted_regression_experiment        VAEImputer  42712         MNAR
#
#        missing_fraction       strategy    column                  result_type  \
# 0                  0.01  single_single        UI       impute_performance_std
# 1                  0.01  single_single        UI       impute_performance_std
# 2                  0.01  single_single        UI       impute_performance_std
# 3                  0.10  single_single        UI       impute_performance_std
# 4                  0.10  single_single        UI       impute_performance_std
# ...                 ...            ...       ...                          ...
# 16135              0.30  single_single  humidity  downstream_performance_mean
# 16136              0.30  single_single  humidity  downstream_performance_mean
# 16137              0.50  single_single  humidity  downstream_performance_mean
# 16138              0.50  single_single  humidity  downstream_performance_mean
# 16139              0.50  single_single  humidity  downstream_performance_mean
#
#             metric     train      test      baseline  corrupted       imputed
# 0         F1_micro  0.018478  0.016129           NaN        NaN           NaN
# 1         F1_macro  0.005412  0.104607           NaN        NaN           NaN
# 2      F1_weighted  0.022187  0.039366           NaN        NaN           NaN
# 3         F1_micro  0.005025  0.013673           NaN        NaN           NaN
# 4         F1_macro  0.004450  0.008727           NaN        NaN           NaN
# ...            ...       ...       ...           ...        ...           ...
# 16135          MSE       NaN       NaN  22884.632072        0.0  23006.528894
# 16136         RMSE       NaN       NaN    151.276674        0.0    151.678701
# 16137          MAE       NaN       NaN    104.177676        0.0    103.074606
# 16138          MSE       NaN       NaN  22505.093207        0.0  22281.280851
# 16139         RMSE       NaN       NaN    150.016976        0.0    149.268209
#
# [16140 rows x 14 columns]

# %%
# Filtering the relevant data for downstream analysis

na_impute_results = results[
    (results["result_type"] == IMPUTE_RESULT_TYPE) & 
    (results["metric"].isin(["F1_macro", "RMSE"]))
]
na_impute_results.drop(["baseline", "corrupted", "imputed"], axis=1, inplace=True)
na_impute_results = na_impute_results[na_impute_results.isna().any(axis=1)]
na_impute_results.shape
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\3401284833.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (3, 11)

# %%
# check if strategy type is correct!
STRATEGY_TYPE = "single_single"

downstream_results = results[
    (results["result_type"] == DOWNSTREAM_RESULT_TYPE) & 
    (results["metric"].isin(["F1_macro", "RMSE"]) &
    (results["strategy"] == STRATEGY_TYPE))
]

# remove experiments where imputation failed
downstream_results = downstream_results.merge(
    na_impute_results,
    how = "left",
    validate = "one_to_one",
    indicator = True,
    suffixes=("", "_imp"),
    on = ["experiment", "imputer", "task", "missing_type", "missing_fraction", "strategy", "column"]
)
downstream_results = downstream_results[downstream_results["_merge"]=="left_only"]

assert len(results["strategy"].unique()) == 1
downstream_results.drop(["experiment", "strategy", "result_type_imp", "metric_imp", "train", "test", "train_imp", "test_imp", "_merge"], axis=1, inplace=True)

downstream_results = downstream_results.rename(
    {
        "imputer": "Imputation_Method",
        "task": "Task",
        "missing_type": "Missing Type",
        "missing_fraction": "Missing Fraction",
        "column": "Column",
        "baseline": "Baseline",
        "imputed": "Imputed",
        "corrupted": "Corrupted"
    },
    axis = 1
)

# %%
rename_imputer_dict = {
    "ModeImputer": "Mean/Mode",
    "KNNImputer": "KNN",
    "ForestImputer": "Random Forest",
    "AutoKerasImputer": "Discriminative DL",
    "VAEImputer": "VAE",
    "GAINImputer": "GAIN"    
}

rename_metric_dict = {
    "F1_macro": CLF_METRIC,
    "RMSE": REG_METRIC
}

downstream_results = downstream_results.replace(rename_imputer_dict)
downstream_results = downstream_results.replace(rename_metric_dict)

downstream_results
# Out:
#       Imputation_Method   Task Missing Type  Missing Fraction    Column  \
# 0     Discriminative DL   1193          MAR              0.01        UI
# 1     Discriminative DL   1193          MAR              0.10        UI
# 2     Discriminative DL   1193          MAR              0.30        UI
# 3     Discriminative DL   1193          MAR              0.50        UI
# 4     Discriminative DL   1193         MCAR              0.01        UI
# ...                 ...    ...          ...               ...       ...
# 1340                VAE  42712         MCAR              0.50  humidity
# 1341                VAE  42712         MNAR              0.01  humidity
# 1342                VAE  42712         MNAR              0.10  humidity
# 1343                VAE  42712         MNAR              0.30  humidity
# 1344                VAE  42712         MNAR              0.50  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks  949.139559        0.0
# 1     downstream_performance_mean  Regression Tasks  945.054395        0.0
# 2     downstream_performance_mean  Regression Tasks  937.919925        0.0
# 3     downstream_performance_mean  Regression Tasks  928.297444        0.0
# 4     downstream_performance_mean  Regression Tasks  949.015231        0.0
# ...                           ...               ...         ...        ...
# 1340  downstream_performance_mean  Regression Tasks  152.144893        0.0
# 1341  downstream_performance_mean  Regression Tasks  149.535129        0.0
# 1342  downstream_performance_mean  Regression Tasks  150.072266        0.0
# 1343  downstream_performance_mean  Regression Tasks  151.276674        0.0
# 1344  downstream_performance_mean  Regression Tasks  150.016976        0.0
#
#          Imputed
# 0     948.994662
# 1     945.582069
# 2     935.517056
# 3     928.683026
# 4     948.979379
# ...          ...
# 1340  152.251677
# 1341  149.664127
# 1342  149.894417
# 1343  151.678701
# 1344  149.268209
#
# [1342 rows x 10 columns]

# %% [markdown]
# ### Robustness: check which imputers yielded `NaN`values

# %%
for col in downstream_results.columns:
    na_sum = downstream_results[col].isna().sum()
    if na_sum > 0:
        print("-----" * 10)        
        print(col, na_sum)
        print("-----" * 10)        
        na_idx = downstream_results[col].isna()
        print(downstream_results.loc[na_idx, "Imputation Method"].value_counts(dropna=False))
        print("\n")

# %% [markdown]
# ## Adding Dataset Info, Sorting and Ranking

# %%
clf_row_idx = downstream_results["metric"] == CLF_METRIC
reg_row_idx = downstream_results["metric"] == REG_METRIC

# Sorting of data

#adjust order to fit the processing time -> fastest first
methods_order = CategoricalDtype(['Mean/Mode', 'KNN', 'Random Forest', 'VAE', 'GAIN', 'Discriminative DL'], ordered=True)
downstream_results_full_sort = downstream_results.copy()

downstream_results_full_sort['Imputation_Method'] = downstream_results_full_sort['Imputation_Method'].astype(methods_order)
downstream_results_full_sort = downstream_results_full_sort.sort_values(['Task', 'Missing Type',
                                                                         'Missing Fraction', 'Imputed','Imputation_Method'], ascending=[True, True, True, True, True])


downstream_results.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction Column  \
# 0  Discriminative DL  1193          MAR              0.01     UI
# 1  Discriminative DL  1193          MAR              0.10     UI
# 2  Discriminative DL  1193          MAR              0.30     UI
# 3  Discriminative DL  1193          MAR              0.50     UI
# 4  Discriminative DL  1193         MCAR              0.01     UI
#
#                    result_type            metric    Baseline  Corrupted  \
# 0  downstream_performance_mean  Regression Tasks  949.139559        0.0
# 1  downstream_performance_mean  Regression Tasks  945.054395        0.0
# 2  downstream_performance_mean  Regression Tasks  937.919925        0.0
# 3  downstream_performance_mean  Regression Tasks  928.297444        0.0
# 4  downstream_performance_mean  Regression Tasks  949.015231        0.0
#
#       Imputed
# 0  948.994662
# 1  945.582069
# 2  935.517056
# 3  928.683026
# 4  948.979379

# %%
#downstream_results_full_sort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1342 entries, 494 to 660
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Imputation_Method  1342 non-null   category
#  1   Task               1342 non-null   int64
#  2   Missing Type       1342 non-null   object
#  3   Missing Fraction   1342 non-null   float64
#  4   Column             1342 non-null   object
#  5   result_type        1342 non-null   object
#  6   metric             1342 non-null   object
#  7   Baseline           1342 non-null   float64
#  8   Corrupted          1342 non-null   float64
#  9   Imputed            1342 non-null   float64
# dtypes: category(1), float64(4), int64(1), object(4)
# memory usage: 106.4+ KB

# %%
# add dataset information from other csv file
dataset_info = pd.read_csv('../datasets_information_overview.csv')
dataset_info = dataset_info.rename(columns={"did": "Task"})


downstream_results_full_sort = pd.merge(downstream_results_full_sort, dataset_info, on='Task')
downstream_results_full_sort.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction  Column  \
# 0               GAIN   189          MAR              0.01  theta8
# 1      Random Forest   189          MAR              0.01  theta8
# 2          Mean/Mode   189          MAR              0.01  theta8
# 3                VAE   189          MAR              0.01  theta8
# 4  Discriminative DL   189          MAR              0.01  theta8
#
#                    result_type            metric  Baseline  Corrupted  \
# 0  downstream_performance_mean  Regression Tasks  0.204873        0.0
# 1  downstream_performance_mean  Regression Tasks  0.204919        0.0
# 2  downstream_performance_mean  Regression Tasks  0.204909        0.0
# 3  downstream_performance_mean  Regression Tasks  0.204895        0.0
# 4  downstream_performance_mean  Regression Tasks  0.204909        0.0
#
#     Imputed  Unnamed: 0    name  MajorityClassSize  MinorityClassSize  \
# 0  0.204926          67  kin8nm                NaN                NaN
# 1  0.204999          67  kin8nm                NaN                NaN
# 2  0.205023          67  kin8nm                NaN                NaN
# 3  0.205026          67  kin8nm                NaN                NaN
# 4  0.205028          67  kin8nm                NaN                NaN
#
#    NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0               9.0             8192.0                      9.0
# 1               9.0             8192.0                      9.0
# 2               9.0             8192.0                      9.0
# 3               9.0             8192.0                      9.0
# 4               9.0             8192.0                      9.0
#
#    NumberOfCategoricalFeatures  NumberOfClasses
# 0                          0.0              NaN
# 1                          0.0              NaN
# 2                          0.0              NaN
# 3                          0.0              NaN
# 4                          0.0              NaN

# %%
# Ranking of downstream performance per data constellation for every imputation method

EXPERIMENTAL_CONDITIONS = ["Task", "Missing Type", "Missing Fraction", "Column", "result_type"]

downstream_results_rank = downstream_results_full_sort.copy()

downstream_results_rank["Downstream Performance Rank"] = downstream_results_rank.groupby(EXPERIMENTAL_CONDITIONS).rank(ascending=True, na_option="bottom", method="first")["Imputed"]
# create csv for detailled checks
downstream_results_rank.to_csv('downstream_results_complete_overview.csv')
downstream_results_rank.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction  Column  \
# 0               GAIN   189          MAR              0.01  theta8
# 1      Random Forest   189          MAR              0.01  theta8
# 2          Mean/Mode   189          MAR              0.01  theta8
# 3                VAE   189          MAR              0.01  theta8
# 4  Discriminative DL   189          MAR              0.01  theta8
#
#                    result_type            metric  Baseline  Corrupted  \
# 0  downstream_performance_mean  Regression Tasks  0.204873        0.0
# 1  downstream_performance_mean  Regression Tasks  0.204919        0.0
# 2  downstream_performance_mean  Regression Tasks  0.204909        0.0
# 3  downstream_performance_mean  Regression Tasks  0.204895        0.0
# 4  downstream_performance_mean  Regression Tasks  0.204909        0.0
#
#     Imputed  Unnamed: 0    name  MajorityClassSize  MinorityClassSize  \
# 0  0.204926          67  kin8nm                NaN                NaN
# 1  0.204999          67  kin8nm                NaN                NaN
# 2  0.205023          67  kin8nm                NaN                NaN
# 3  0.205026          67  kin8nm                NaN                NaN
# 4  0.205028          67  kin8nm                NaN                NaN
#
#    NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0               9.0             8192.0                      9.0
# 1               9.0             8192.0                      9.0
# 2               9.0             8192.0                      9.0
# 3               9.0             8192.0                      9.0
# 4               9.0             8192.0                      9.0
#
#    NumberOfCategoricalFeatures  NumberOfClasses  Downstream Performance Rank
# 0                          0.0              NaN                          1.0
# 1                          0.0              NaN                          2.0
# 2                          0.0              NaN                          3.0
# 3                          0.0              NaN                          4.0
# 4                          0.0              NaN                          5.0

# %%
# Adjust column type for Imputation_Method
downstream_results_rank['Imputation_Method'] = downstream_results_rank['Imputation_Method'].astype('object')

#downstream_results_rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1342 entries, 0 to 1341
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Imputation_Method            1342 non-null   object
#  1   Task                         1342 non-null   int64
#  2   Missing Type                 1342 non-null   object
#  3   Missing Fraction             1342 non-null   float64
#  4   Column                       1342 non-null   object
#  5   result_type                  1342 non-null   object
#  6   metric                       1342 non-null   object
#  7   Baseline                     1342 non-null   float64
#  8   Corrupted                    1342 non-null   float64
#  9   Imputed                      1342 non-null   float64
#  10  Unnamed: 0                   1342 non-null   int64
#  11  name                         1342 non-null   object
#  12  MajorityClassSize            0 non-null      float64
#  13  MinorityClassSize            0 non-null      float64
#  14  NumberOfFeatures             1342 non-null   float64
#  15  NumberOfInstances            1342 non-null   float64
#  16  NumberOfNumericFeatures      1342 non-null   float64
#  17  NumberOfCategoricalFeatures  1342 non-null   float64
#  18  NumberOfClasses              0 non-null      float64
#  19  Downstream Performance Rank  1342 non-null   float64
# dtypes: float64(12), int64(2), object(6)
# memory usage: 220.2+ KB

# %%
# Merge the two columns "Missing Type" and "Missing Fraction"

downstream_results_rank['Missing Type'] = downstream_results_rank['Missing Type'].astype(str)
downstream_results_rank['Missing Fraction'] = downstream_results_rank['Missing Fraction'].astype(str)
#datatype_new = downstream_results_rank.dtypes

downstream_results_rank['Data_Constellation'] = downstream_results_rank['Missing Type'] + ' - ' + downstream_results_rank['Missing Fraction']
#downstream_results_rank.to_csv('downstream_results_rank_temp.csv')
downstream_results_rank_heatmap2 = downstream_results_rank.copy()
downstream_results_rank.head()
# Out:
#    Imputation_Method  Task Missing Type Missing Fraction  Column  \
# 0               GAIN   189          MAR             0.01  theta8
# 1      Random Forest   189          MAR             0.01  theta8
# 2          Mean/Mode   189          MAR             0.01  theta8
# 3                VAE   189          MAR             0.01  theta8
# 4  Discriminative DL   189          MAR             0.01  theta8
#
#                    result_type            metric  Baseline  Corrupted  \
# 0  downstream_performance_mean  Regression Tasks  0.204873        0.0
# 1  downstream_performance_mean  Regression Tasks  0.204919        0.0
# 2  downstream_performance_mean  Regression Tasks  0.204909        0.0
# 3  downstream_performance_mean  Regression Tasks  0.204895        0.0
# 4  downstream_performance_mean  Regression Tasks  0.204909        0.0
#
#     Imputed  ...    name MajorityClassSize  MinorityClassSize  \
# 0  0.204926  ...  kin8nm               NaN                NaN
# 1  0.204999  ...  kin8nm               NaN                NaN
# 2  0.205023  ...  kin8nm               NaN                NaN
# 3  0.205026  ...  kin8nm               NaN                NaN
# 4  0.205028  ...  kin8nm               NaN                NaN
#
#    NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0               9.0             8192.0                      9.0
# 1               9.0             8192.0                      9.0
# 2               9.0             8192.0                      9.0
# 3               9.0             8192.0                      9.0
# 4               9.0             8192.0                      9.0
#
#    NumberOfCategoricalFeatures  NumberOfClasses  Downstream Performance Rank  \
# 0                          0.0              NaN                          1.0
# 1                          0.0              NaN                          2.0
# 2                          0.0              NaN                          3.0
# 3                          0.0              NaN                          4.0
# 4                          0.0              NaN                          5.0
#
#    Data_Constellation
# 0          MAR - 0.01
# 1          MAR - 0.01
# 2          MAR - 0.01
# 3          MAR - 0.01
# 4          MAR - 0.01
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Analyzing Performance based on Rank per Data Constellation

# %%
data = downstream_results_rank.copy()

# Count amount of different Data constellations in column "Data_Constellation"
dc_unique = data.Data_Constellation.unique().size
print(dc_unique, "Data Constellations")
print("_____________________")
# Count amount of 1.0 Ranking result in column "Downstream Performance Rank" (Numbers must match)
rank_count = data['Downstream Performance Rank'].value_counts()
print(rank_count)
print("_____________________")
# Filter for 1.0 Ranking -> Overview -> save as csv
rank_1 = data.loc[data['Downstream Performance Rank'] == 1.0]
rank_1.to_csv('rank_1.csv')

print("_____________________")
# Count how often each Imputation Method is present -> most "wins"
rank_wins = rank_1['Imputation_Method'].value_counts()
print(rank_wins)
print("_____________________")
# Take initial overview and filter for each imputation method and calculate average rank
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
for i in methods:
    df_average_rank = data.loc[data['Imputation_Method'] == i]
    len_ar = len(df_average_rank)
    print(len_ar, "Amount of results available")
    rank_pos = df_average_rank['Downstream Performance Rank'].value_counts().sort_index(ascending=True)
    print(rank_pos)
    average_rank = df_average_rank["Downstream Performance Rank"].mean()
    print("Average Rank for", i, "is", average_rank)
# Out:
# 12 Data Constellations
# _____________________
# 1.0    228
# 2.0    228
# 3.0    228
# 4.0    228
# 5.0    228
# 6.0    202
# Name: Downstream Performance Rank, dtype: int64
# _____________________
# _____________________
# Mean/Mode            50
# Random Forest        48
# GAIN                 38
# Discriminative DL    37
# VAE                  31
# KNN                  24
# Name: Imputation_Method, dtype: int64
# _____________________
# 228 Amount of results available
# 1.0    48
# 2.0    49
# 3.0    40
# 4.0    33
# 5.0    38
# 6.0    20
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for Random Forest is 3.1052631578947367
# _____________________
# 228 Amount of results available
# 1.0    24
# 2.0    38
# 3.0    71
# 4.0    51
# 5.0    28
# 6.0    16
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for KNN is 3.3026315789473686
# _____________________
# 228 Amount of results available
# 1.0    50
# 2.0    37
# 3.0    26
# 4.0    49
# 5.0    41
# 6.0    25
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for Mean/Mode is 3.3026315789473686
# _____________________
# 228 Amount of results available
# 1.0    31
# 2.0    29
# 3.0    29
# 4.0    35
# 5.0    74
# 6.0    30
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for VAE is 3.7982456140350878
# _____________________
# 208 Amount of results available
# 1.0    38
# 2.0    18
# 3.0    16
# 4.0    22
# 5.0    18
# 6.0    96
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for GAIN is 4.211538461538462
# _____________________
# 222 Amount of results available
# 1.0    37
# 2.0    57
# 3.0    46
# 4.0    38
# 5.0    29
# 6.0    15
# Name: Downstream Performance Rank, dtype: int64
# Average Rank for Discriminative DL is 3.045045045045045
# _____________________

# %%
rank_1_backup = rank_1.copy()
rank_1
# Out:
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 0                  GAIN    189          MAR             0.01    theta8
# 6     Discriminative DL    189          MAR              0.1    theta8
# 12            Mean/Mode    189          MAR              0.3    theta8
# 18    Discriminative DL    189          MAR              0.5    theta8
# 24    Discriminative DL    189         MCAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1312      Random Forest  42712         MCAR              0.5  humidity
# 1318  Discriminative DL  42712         MNAR             0.01  humidity
# 1324  Discriminative DL  42712         MNAR              0.1  humidity
# 1330  Discriminative DL  42712         MNAR              0.3  humidity
# 1336          Mean/Mode  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks    0.204873        0.0
# 6     downstream_performance_mean  Regression Tasks    0.204813        0.0
# 12    downstream_performance_mean  Regression Tasks    0.204820        0.0
# 18    downstream_performance_mean  Regression Tasks    0.205841        0.0
# 24    downstream_performance_mean  Regression Tasks    0.205083        0.0
# ...                           ...               ...         ...        ...
# 1312  downstream_performance_mean  Regression Tasks  148.991778        0.0
# 1318  downstream_performance_mean  Regression Tasks  149.507994        0.0
# 1324  downstream_performance_mean  Regression Tasks  149.523046        0.0
# 1330  downstream_performance_mean  Regression Tasks  149.431371        0.0
# 1336  downstream_performance_mean  Regression Tasks  147.017846        0.0
#
#          Imputed  ...                 name MajorityClassSize  \
# 0       0.204926  ...               kin8nm               NaN
# 6       0.204953  ...               kin8nm               NaN
# 12      0.205069  ...               kin8nm               NaN
# 18      0.205878  ...               kin8nm               NaN
# 24      0.204972  ...               kin8nm               NaN
# ...          ...  ...                  ...               ...
# 1312  148.880924  ...  Bike_Sharing_Demand               NaN
# 1318  149.475688  ...  Bike_Sharing_Demand               NaN
# 1324  149.372273  ...  Bike_Sharing_Demand               NaN
# 1330  149.346814  ...  Bike_Sharing_Demand               NaN
# 1336  146.311138  ...  Bike_Sharing_Demand               NaN
#
#       MinorityClassSize  NumberOfFeatures  NumberOfInstances  \
# 0                   NaN               9.0             8192.0
# 6                   NaN               9.0             8192.0
# 12                  NaN               9.0             8192.0
# 18                  NaN               9.0             8192.0
# 24                  NaN               9.0             8192.0
# ...                 ...               ...                ...
# 1312                NaN              13.0            17379.0
# 1318                NaN              13.0            17379.0
# 1324                NaN              13.0            17379.0
# 1330                NaN              13.0            17379.0
# 1336                NaN              13.0            17379.0
#
#       NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                         9.0                          0.0              NaN
# 6                         9.0                          0.0              NaN
# 12                        9.0                          0.0              NaN
# 18                        9.0                          0.0              NaN
# 24                        9.0                          0.0              NaN
# ...                       ...                          ...              ...
# 1312                      9.0                          4.0              NaN
# 1318                      9.0                          4.0              NaN
# 1324                      9.0                          4.0              NaN
# 1330                      9.0                          4.0              NaN
# 1336                      9.0                          4.0              NaN
#
#       Downstream Performance Rank  Data_Constellation
# 0                             1.0          MAR - 0.01
# 6                             1.0           MAR - 0.1
# 12                            1.0           MAR - 0.3
# 18                            1.0           MAR - 0.5
# 24                            1.0         MCAR - 0.01
# ...                           ...                 ...
# 1312                          1.0          MCAR - 0.5
# 1318                          1.0         MNAR - 0.01
# 1324                          1.0          MNAR - 0.1
# 1330                          1.0          MNAR - 0.3
# 1336                          1.0          MNAR - 0.5
#
# [228 rows x 21 columns]

# %% [markdown]
# ## Set Average Best Imputation Method Manually

# %%
# SET AVERAGE BEST IMPUTATION METHOD HERE, BASED ON THE PREVIOUS RESULTS
# Alternatively you can define a baseline method here, which will be used instead, depending on your analysis goals

AVERAGE_BEST_IMPUTATION_METHOD = "Random Forest"

# %% [markdown]
# ## Differences in Performance Relative to Average Best Imputation Method

# %%
av_best = data.loc[data['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
av_best['Task'] = av_best['Task'].astype(str)
av_best['Data_Constellation'] = av_best['Data_Constellation'] + ' - ' + av_best['Task']

av_best = av_best[['Imputation_Method', 'Imputed', 'Data_Constellation', 'Downstream Performance Rank']]
av_best = av_best.rename(columns={'Imputation_Method':'Imputation_Method_average', 
                               'Imputed':'Imputed_average',
                                 'Downstream Performance Rank':'Downstream Performance Rank Average'})


rank_1['Task'] = rank_1['Task'].astype(str)
rank_1['Data_Constellation'] = rank_1['Data_Constellation'] + ' - ' + rank_1['Task']
rank_1 = rank_1[['Imputation_Method', 'Imputed', 'Data_Constellation', 'Downstream Performance Rank']]
rank_1 = rank_1.rename(columns={'Imputation_Method':'Imputation_Method_best', 
                               'Imputed':'Imputed_best',
                               'Downstream Performance Rank':'Downstream Performance Rank Best'})

performance_difference = pd.merge(av_best, rank_1, on='Data_Constellation')
#performance_difference.head()
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\2063573927.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\2063573927.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\2063573927.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\2063573927.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Calculate the difference between the best imputation method for each data constellation to the average best imputation method in F1 score
performance_difference['Performance Difference Best to Average'] = performance_difference['Imputed_best'] - performance_difference['Imputed_average']
Average_Difference = performance_difference['Performance Difference Best to Average'].mean()
print("Average Difference in Improvement from best method to average best method for RMSE", Average_Difference)
# Out:
# Average Difference in Improvement from best method to average best method for RMSE -0.831525330739394

# %%
performance_difference.to_csv('performance_difference.csv')
performance_difference.head()
# Out:
#   Imputation_Method_average  Imputed_average Data_Constellation  \
# 0             Random Forest         0.204999   MAR - 0.01 - 189
# 1             Random Forest         0.205008    MAR - 0.1 - 189
# 2             Random Forest         0.205515    MAR - 0.3 - 189
# 3             Random Forest         0.205979    MAR - 0.5 - 189
# 4             Random Forest         0.205077  MCAR - 0.01 - 189
#
#    Downstream Performance Rank Average Imputation_Method_best  Imputed_best  \
# 0                                  2.0                   GAIN      0.204926
# 1                                  3.0      Discriminative DL      0.204953
# 2                                  3.0              Mean/Mode      0.205069
# 3                                  4.0      Discriminative DL      0.205878
# 4                                  5.0      Discriminative DL      0.204972
#
#    Downstream Performance Rank Best  Performance Difference Best to Average
# 0                               1.0                               -0.000073
# 1                               1.0                               -0.000055
# 2                               1.0                               -0.000447
# 3                               1.0                               -0.000101
# 4                               1.0                               -0.000105

# %% [markdown]
# ## Analysis and Ranking based on RMSE Score

# %%
# Relative Difference in Percent -> Best Method to Average Best Method

data = downstream_results_rank.copy()
data['Task'] = data['Task'].astype(str)
data['Data_Constellation_full'] = data['Data_Constellation'] + ' - ' + data['Task']

dc_unique = data.Data_Constellation_full.unique()

data_constellations = dc_unique.tolist()
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
average_best_complete = pd.DataFrame()


for i in data_constellations:
    data_constel = data.loc[data['Data_Constellation_full'] == i]
    best_score = data_constel.loc[data_constel['Downstream Performance Rank'] == 1.0]
    average_best = data_constel.loc[data_constel['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
    best_score_int = best_score.iloc[0]['Imputed']
    average_best_int = average_best.iloc[0]['Imputed']
    calc_result = ((best_score_int - average_best_int)/best_score_int)
    calc_result = abs(calc_result)
    average_best['Performance Difference to Best to Average in Percent'] = calc_result
    average_best_complete = average_best_complete.append(average_best)

average_best_complete
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\1428686177.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#      Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 1        Random Forest    189          MAR             0.01    theta8
# 8        Random Forest    189          MAR              0.1    theta8
# 14       Random Forest    189          MAR              0.3    theta8
# 21       Random Forest    189          MAR              0.5    theta8
# 28       Random Forest    189         MCAR             0.01    theta8
# ...                ...    ...          ...              ...       ...
# 1312     Random Forest  42712         MCAR              0.5  humidity
# 1321     Random Forest  42712         MNAR             0.01  humidity
# 1327     Random Forest  42712         MNAR              0.1  humidity
# 1332     Random Forest  42712         MNAR              0.3  humidity
# 1337     Random Forest  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 1     downstream_performance_mean  Regression Tasks    0.204919        0.0
# 8     downstream_performance_mean  Regression Tasks    0.204910        0.0
# 14    downstream_performance_mean  Regression Tasks    0.204800        0.0
# 21    downstream_performance_mean  Regression Tasks    0.206002        0.0
# 28    downstream_performance_mean  Regression Tasks    0.205079        0.0
# ...                           ...               ...         ...        ...
# 1312  downstream_performance_mean  Regression Tasks  148.991778        0.0
# 1321  downstream_performance_mean  Regression Tasks  149.513804        0.0
# 1327  downstream_performance_mean  Regression Tasks  149.557789        0.0
# 1332  downstream_performance_mean  Regression Tasks  149.430117        0.0
# 1337  downstream_performance_mean  Regression Tasks  148.151741        0.0
#
#          Imputed  ...  MinorityClassSize NumberOfFeatures  NumberOfInstances  \
# 1       0.204999  ...                NaN              9.0             8192.0
# 8       0.205008  ...                NaN              9.0             8192.0
# 14      0.205515  ...                NaN              9.0             8192.0
# 21      0.205979  ...                NaN              9.0             8192.0
# 28      0.205077  ...                NaN              9.0             8192.0
# ...          ...  ...                ...              ...                ...
# 1312  148.880924  ...                NaN             13.0            17379.0
# 1321  149.548996  ...                NaN             13.0            17379.0
# 1327  149.782113  ...                NaN             13.0            17379.0
# 1332  150.008179  ...                NaN             13.0            17379.0
# 1337  147.707377  ...                NaN             13.0            17379.0
#
#       NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 1                         9.0                          0.0              NaN
# 8                         9.0                          0.0              NaN
# 14                        9.0                          0.0              NaN
# 21                        9.0                          0.0              NaN
# 28                        9.0                          0.0              NaN
# ...                       ...                          ...              ...
# 1312                      9.0                          4.0              NaN
# 1321                      9.0                          4.0              NaN
# 1327                      9.0                          4.0              NaN
# 1332                      9.0                          4.0              NaN
# 1337                      9.0                          4.0              NaN
#
#       Downstream Performance Rank  Data_Constellation  \
# 1                             2.0          MAR - 0.01
# 8                             3.0           MAR - 0.1
# 14                            3.0           MAR - 0.3
# 21                            4.0           MAR - 0.5
# 28                            5.0         MCAR - 0.01
# ...                           ...                 ...
# 1312                          1.0          MCAR - 0.5
# 1321                          4.0         MNAR - 0.01
# 1327                          4.0          MNAR - 0.1
# 1332                          3.0          MNAR - 0.3
# 1337                          2.0          MNAR - 0.5
#
#       Data_Constellation_full  \
# 1            MAR - 0.01 - 189
# 8             MAR - 0.1 - 189
# 14            MAR - 0.3 - 189
# 21            MAR - 0.5 - 189
# 28          MCAR - 0.01 - 189
# ...                       ...
# 1312       MCAR - 0.5 - 42712
# 1321      MNAR - 0.01 - 42712
# 1327       MNAR - 0.1 - 42712
# 1332       MNAR - 0.3 - 42712
# 1337       MNAR - 0.5 - 42712
#
#       Performance Difference to Best to Average in Percent
# 1                                              0.000356
# 8                                              0.000270
# 14                                             0.002178
# 21                                             0.000489
# 28                                             0.000514
# ...                                                 ...
# 1312                                           0.000000
# 1321                                           0.000490
# 1327                                           0.002744
# 1332                                           0.004428
# 1337                                           0.009543
#
# [228 rows x 23 columns]

# %%
#Difference in Percentage
average_difference = average_best_complete['Performance Difference to Best to Average in Percent'].mean()
print(average_difference, "average difference in Percent (Verschlechterung der durchschnittlich besten Methode relativ zu jeweils besten Methode)")
# Out:
# 0.002383376610533895 average difference in Percent (Verschlechterung der durchschnittlich besten Methode relativ zu jeweils besten Methode)

# %% [markdown]
# ## Heatmap to Show Detailled Performance of Each Imputation Method for Each Data Constellation

# %%
df_heat = downstream_results_rank.copy()
df_heat.drop(["Missing Type", "Missing Fraction", "Column", "result_type", "metric", "Baseline", "Corrupted", "Unnamed: 0", "Unnamed: 0", "name", "NumberOfClasses", "MajorityClassSize", "MinorityClassSize"], axis=1, inplace=True)
df_heat
# Out:
#       Imputation_Method   Task     Imputed  NumberOfFeatures  \
# 0                  GAIN    189    0.204926               9.0
# 1         Random Forest    189    0.204999               9.0
# 2             Mean/Mode    189    0.205023               9.0
# 3                   VAE    189    0.205026               9.0
# 4     Discriminative DL    189    0.205028               9.0
# ...                 ...    ...         ...               ...
# 1337      Random Forest  42712  147.707377              13.0
# 1338                KNN  42712  148.474038              13.0
# 1339  Discriminative DL  42712  148.593887              13.0
# 1340                VAE  42712  149.268209              13.0
# 1341               GAIN  42712  149.936478              13.0
#
#       NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0                8192.0                      9.0                          0.0
# 1                8192.0                      9.0                          0.0
# 2                8192.0                      9.0                          0.0
# 3                8192.0                      9.0                          0.0
# 4                8192.0                      9.0                          0.0
# ...                 ...                      ...                          ...
# 1337            17379.0                      9.0                          4.0
# 1338            17379.0                      9.0                          4.0
# 1339            17379.0                      9.0                          4.0
# 1340            17379.0                      9.0                          4.0
# 1341            17379.0                      9.0                          4.0
#
#       Downstream Performance Rank Data_Constellation
# 0                             1.0         MAR - 0.01
# 1                             2.0         MAR - 0.01
# 2                             3.0         MAR - 0.01
# 3                             4.0         MAR - 0.01
# 4                             5.0         MAR - 0.01
# ...                           ...                ...
# 1337                          2.0         MNAR - 0.5
# 1338                          3.0         MNAR - 0.5
# 1339                          4.0         MNAR - 0.5
# 1340                          5.0         MNAR - 0.5
# 1341                          6.0         MNAR - 0.5
#
# [1342 rows x 9 columns]

# %%
# Heatmap for total RMSE score for each data constellation for each method

df_heat = df_heat.astype({"Task":"string"})

data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MCAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']


for i in data_constellations:
    data_constel = df_heat.loc[df_heat['Data_Constellation'] == i]

    ### uncomment whatever you want to investigate

    ## sort by amount datapoints (ascending)
    data_constel = data_constel.sort_values(by=['NumberOfInstances'])

    ## sort by amount of features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfFeatures'])

    ## sort by amount of datapoints and features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances', 'NumberOfFeatures'])

    ## sort by amount of categorical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfCategoricalFeatures', 'NumberOfInstances'])

    ## sort by amount of numerical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfNumericFeatures', 'NumberOfInstances'])
    
    Dataset_number = data_constel["Task"]
    Imputation_Method = data_constel["Imputation_Method"]
    Improvement = data_constel["Imputed"]
    

    trace = go.Heatmap(
                   z=Improvement,
                   x=Dataset_number,
                   y=Imputation_Method,
                   type = 'heatmap',
                    autocolorscale= False,
                    colorscale = 'Reds',
                    zmin=0,
                    )
    data = [trace]
    fig = go.Figure(data=data)
    fig.update_layout(
        title=i,
        xaxis_nticks=36)
    fig.show()
# Out:
# <div>                            <div id="51818774-eea2-4ccc-88c5-ec5221bd6117" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51818774-eea2-4ccc-88c5-ec5221bd6117")) {                    Plotly.newPlot(                        "51818774-eea2-4ccc-88c5-ec5221bd6117",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395"],"y":["Discriminative DL","GAIN","VAE","Random Forest","Mean/Mode","KNN","Discriminative DL","GAIN","Mean/Mode","Random Forest","VAE","KNN","Mean/Mode","GAIN","KNN","Random Forest","VAE","Discriminative DL","GAIN","GAIN","Random Forest","Mean/Mode","VAE","Discriminative DL","KNN","Discriminative DL","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","GAIN","Mean/Mode","Random Forest","VAE","KNN","Discriminative DL","GAIN","Mean/Mode","Random Forest","VAE","Discriminative DL","KNN","Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","Discriminative DL","KNN","VAE","Random Forest","Mean/Mode","Mean/Mode","Random Forest","VAE","KNN","GAIN","Discriminative DL","Mean/Mode","KNN","Random Forest","GAIN","Discriminative DL","VAE","Discriminative DL","VAE","Mean/Mode","KNN","GAIN","Random Forest","Random Forest","Discriminative DL","Mean/Mode","KNN","VAE","VAE","Random Forest","Discriminative DL","KNN","Mean/Mode","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Mean/Mode","VAE","Discriminative DL","KNN","Random Forest","Random Forest","Discriminative DL","Mean/Mode","VAE","KNN"],"z":[0.332306090386958,0.3340389883894321,0.3327273953150806,0.3323209399097812,0.3318784861302149,0.3318171810727413,20.76705396191626,20.767068265952123,20.767072771030072,20.76707393459633,20.76704866825462,20.767076768463976,0.746546738197273,0.7463121291370864,0.7463411937047467,0.746457558543775,0.746288795403736,0.7464832249738619,0.204925859080356,9.193775604409522,0.2049988023013744,0.2050227769861828,0.2050256349684556,0.205028252662848,0.205037619383157,9.193376703361755,9.193425761773096,9.19441524817858,9.194369890599036,9.193456719289983,0.0014195584264762,0.0014190045893378,0.0014190145163052,0.0014191297259253,0.0014192813832624,0.0014193408874079,0.0468785043387893,0.0468723971251412,0.0468708821293008,0.0468720120537865,0.0468701719202207,0.0468705722416017,6500.916471439301,6500.916481075025,6500.91647280674,6500.916476642964,6500.916475079335,6500.916474677816,4.530622396196242,4.530498112705022,4.530595704775146,4.5306063105307,4.530627860428539,4.53062545323161,0.0028376127090218,0.0028380656138216,0.0028381838985003,0.0028382014823368,0.0028385663407465,149.4995957579056,149.50495073700077,149.5210292174108,149.5241123520285,149.56170773140207,149.52795756348658,11.9477455 ...
# <div>                            <div id="d80123df-5d79-492e-84b6-251d9298f729" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d80123df-5d79-492e-84b6-251d9298f729")) {                    Plotly.newPlot(                        "d80123df-5d79-492e-84b6-251d9298f729",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","Random Forest","Mean/Mode","KNN","GAIN","VAE","VAE","Mean/Mode","Random Forest","KNN","GAIN","Discriminative DL","Discriminative DL","GAIN","GAIN","Random Forest","Discriminative DL","KNN","VAE","VAE","Mean/Mode","Random Forest","Mean/Mode","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","KNN","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Discriminative DL","GAIN","VAE","Random Forest","Mean/Mode","KNN","Mean/Mode","GAIN","KNN","VAE","Random Forest","Discriminative DL","GAIN","Random Forest","VAE","KNN","Discriminative DL","Mean/Mode","VAE","Mean/Mode","Random Forest","KNN","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","VAE","Discriminative DL","Mean/Mode","GAIN","KNN","Random Forest","GAIN","Discriminative DL","Mean/Mode","VAE","VAE","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Discriminative DL","Mean/Mode","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","GAIN","VAE","KNN","Mean/Mode","Discriminative DL","Random Forest"],"z":[0.3364151525023002,0.3492699993087453,0.3415747605711203,0.336735678672762,0.3350859805561355,0.3348398199181564,20.76677782801075,20.76678033515944,20.766800199694217,20.766818867823776,20.76542326630223,0.7463352816010275,0.7465269914636078,0.7458514941551949,0.7460500815008636,0.7475422833583395,0.7461281588213241,0.2049532149971689,9.196883947334424,0.2052876800929578,9.19321898836428,9.193642224726055,9.193907521000137,9.199314403656407,0.2050674677929385,9.20001375030707,0.2050084858172677,0.2049698534317144,0.2050266510921327,0.0014189987800975,0.0014193341141322,0.0014199711561957,0.0014198818921107,0.0014198913271702,0.0014188902223799,0.046829802828707,0.0468585809589723,0.046868847043169,0.046856055365141,0.0467915259101081,0.0468231131920669,6500.916450329249,6500.916362063145,6500.916529234591,6500.916494953756,6500.916520365965,6500.91650968391,4.530527490064837,4.529970910969725,4.530479796342864,4.530481235682049,4.530616675111357,4.530616805952224,0.0028989376555235,0.0028493905838154,0.0028504793206862,0.0028523451009271,0.0028490752336705,0.0028553591398026,148.91865032527764,148.98840088035922,149.32306738178372,14 ...
# <div>                            <div id="d6223cbf-1d1c-4fae-91ba-e42d28bdf95a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6223cbf-1d1c-4fae-91ba-e42d28bdf95a")) {                    Plotly.newPlot(                        "d6223cbf-1d1c-4fae-91ba-e42d28bdf95a",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","Random Forest","VAE","GAIN","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","GAIN","Discriminative DL","Mean/Mode","Discriminative DL","KNN","Random Forest","VAE","Discriminative DL","GAIN","KNN","GAIN","VAE","Mean/Mode","Random Forest","GAIN","Discriminative DL","Random Forest","Mean/Mode","VAE","KNN","GAIN","VAE","Random Forest","Discriminative DL","Mean/Mode","KNN","VAE","Mean/Mode","GAIN","Discriminative DL","KNN","Random Forest","Random Forest","Mean/Mode","KNN","Discriminative DL","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","Random Forest","GAIN","VAE","Random Forest","VAE","KNN","Discriminative DL","Mean/Mode","GAIN","Random Forest","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","Random Forest","KNN","GAIN","Discriminative DL","VAE","Mean/Mode","VAE","KNN","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","GAIN","Random Forest","KNN","Mean/Mode","Discriminative DL","Random Forest","GAIN","KNN","Discriminative DL","Mean/Mode","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","KNN","Discriminative DL","Random Forest","Mean/Mode","GAIN","VAE","GAIN","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN"],"z":[0.3428141416226145,0.3561074000899588,0.3641913157853711,0.3439643146351808,0.3399815188454258,0.338437827437656,20.76732308260323,20.76744803270268,20.7674729989104,20.76759860649935,20.766575251310783,20.76773177001172,0.7513927020046762,0.7519217154749409,0.7475936551952648,0.7488013608554626,0.7557440866264725,0.7497750829403295,0.2050686590763679,9.196028018676069,0.2052476794083685,0.2055153878533241,0.205905003376708,0.206035661807487,0.2061093176124016,9.190250755372292,9.191264266158036,9.200721423746366,9.198793591279625,9.192042168455805,0.0014221647806579,0.001418231626572,0.0014191468288003,0.0014198706721806,0.0014201397687688,0.0014209399769624,0.046964370780882,0.0469352892190941,0.046878539728932,0.04689459592671,0.0468699701352532,0.0468712430487851,6500.916397829539,6500.916199077606,6500.91679489888,6500.916511769956,6500.916445966831,6500.916482983176,4.530642826139112,4.530528946668434,4.53061274528491,4.530721282451834,4.530811536684777,4.530835443611333,0.0028789933248714,0.002872738518197,0.0028570128360626,0.0028635987288388,0.0029220428119123,0.0028722975277454,149.18 ...
# <div>                            <div id="a886ba6c-f2cf-42d7-aef9-fd078ba8b1da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a886ba6c-f2cf-42d7-aef9-fd078ba8b1da")) {                    Plotly.newPlot(                        "a886ba6c-f2cf-42d7-aef9-fd078ba8b1da",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","KNN","VAE","GAIN","Random Forest","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","KNN","Discriminative DL","GAIN","GAIN","Mean/Mode","VAE","KNN","Discriminative DL","KNN","Random Forest","Random Forest","Mean/Mode","VAE","Discriminative DL","Mean/Mode","VAE","GAIN","KNN","Random Forest","KNN","Random Forest","Discriminative DL","Mean/Mode","GAIN","VAE","VAE","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","Random Forest","Mean/Mode","GAIN","Random Forest","Mean/Mode","Discriminative DL","VAE","GAIN","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","GAIN","VAE","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","GAIN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","KNN","Discriminative DL","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","KNN","VAE","Mean/Mode","Mean/Mode","Discriminative DL","KNN","Random Forest","GAIN","VAE"],"z":[0.3500106537701202,0.3599095913285794,0.3608792977027148,0.442423460022115,0.3472860800181343,0.3446705473641926,20.76777788266355,20.767823731566533,20.768124415337947,20.768201330817018,20.767752431262704,0.7486460042653583,0.7487273763416482,0.7486561718312227,0.7473022063813625,0.750015247056537,0.7482018161257703,0.2053476994172965,9.18882640994416,0.2057842752012852,9.184502957973724,9.186842718124298,9.186887625576013,9.19263043609953,0.2056857682091617,9.193344881667588,0.2054955075377277,0.205423580095382,0.2055327974740969,0.0014189631038953,0.0014193703510081,0.0014202923220329,0.0014195281572549,0.0014195807498176,0.0014188663963735,0.0469049142110887,0.0469096272115999,0.0469184035103234,0.046909149989125,0.0468833508656759,0.0469018308420529,6500.916196264531,6500.916100734937,6500.916769684052,6500.9163588283,6500.916244263016,4.530770819925423,4.5307020873170885,4.530642332491996,4.530618268505863,4.5304967875239415,4.5327440308981926,0.0028925604460133,0.0028763988477463,0.0029060507058466,0.0029194452155805,0.0031130562855031,0.0028987554898989,148.8809244939562,150.0091002345346,150.0188207606662,151.3561461592183,153.501806483830 ...
# <div>                            <div id="1b4da3ba-5a21-4d32-b880-4f8c561b426a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b4da3ba-5a21-4d32-b880-4f8c561b426a")) {                    Plotly.newPlot(                        "1b4da3ba-5a21-4d32-b880-4f8c561b426a",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["KNN","Mean/Mode","VAE","Random Forest","Discriminative DL","GAIN","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","GAIN","KNN","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","Discriminative DL","GAIN","GAIN","VAE","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Random Forest","KNN","Discriminative DL","VAE","GAIN","KNN","Random Forest","Mean/Mode","Discriminative DL","Mean/Mode","Random Forest","VAE","KNN","GAIN","KNN","GAIN","Mean/Mode","Random Forest","VAE","Discriminative DL","GAIN","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","Random Forest","Mean/Mode","Discriminative DL","VAE","KNN","Random Forest","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Mean/Mode","KNN","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","Random Forest","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","VAE","Discriminative DL","Random Forest","Discriminative DL","Mean/Mode","VAE","KNN","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Mean/Mode","Discriminative DL","VAE","KNN","Random Forest","GAIN","Mean/Mode","VAE","KNN","Random Forest","Discriminative DL"],"z":[0.3324973982417362,0.33326102774125,0.3339559655484083,0.3326067024724968,0.3324572184945143,0.3322159605207659,20.767068403748794,20.767077332130693,20.767077765802075,20.76708415722273,20.76704577990517,20.76711499325173,0.7463923353264185,0.746331116149749,0.7463458350317492,0.7463495819184209,0.746309678700635,0.7463888708064497,0.2049715610470641,9.19312369081652,0.2050245821075384,0.2050408695312299,0.2050742329094039,0.2050768689185906,0.205083349020534,9.192548590854418,9.192709266302968,9.193590814518966,9.193402170706628,9.192952941754909,0.0014193644280122,0.0014191362676668,0.0014191833032921,0.0014192879324684,0.0014192919023998,0.001419321076333,0.0468760857656659,0.0468727015978817,0.0468725772647747,0.0468726693413854,0.0468715921182924,0.046872058083399,6500.916473478673,6500.916452225675,6500.916471230288,6500.916466834897,6500.9164690933,6500.916468764396,4.530676603618528,4.530623781126328,4.530598355162414,4.530597659785622,4.530593138560015,4.530625452045656,0.0028368320536733,0.0028367061550383,0.0028359508916176,0.0028380345290761,0.0028373671643897,149.49675560658662,149.51019519035853,149.5385528476645,149.5657637236477,149.55555136553062,11.947565746 ...
# <div>                            <div id="be250f95-8dfe-44ea-940a-3ee1fa05e0ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be250f95-8dfe-44ea-940a-3ee1fa05e0ff")) {                    Plotly.newPlot(                        "be250f95-8dfe-44ea-940a-3ee1fa05e0ff",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["GAIN","Mean/Mode","VAE","KNN","Discriminative DL","Random Forest","Discriminative DL","GAIN","KNN","VAE","Mean/Mode","Random Forest","VAE","KNN","Random Forest","Mean/Mode","GAIN","Discriminative DL","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","GAIN","KNN","Mean/Mode","VAE","Random Forest","Discriminative DL","KNN","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","VAE","GAIN","KNN","Discriminative DL","VAE","Random Forest","Mean/Mode","Mean/Mode","VAE","Random Forest","Discriminative DL","GAIN","KNN","Random Forest","Mean/Mode","VAE","Discriminative DL","KNN","GAIN","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","Discriminative DL","KNN","VAE","GAIN","Mean/Mode","Random Forest","Mean/Mode","KNN","VAE","GAIN","Discriminative DL","VAE","Random Forest","Discriminative DL","KNN","GAIN","Mean/Mode","GAIN","KNN","VAE","Random Forest","Mean/Mode","Discriminative DL","VAE","KNN","Random Forest","Discriminative DL","Mean/Mode","GAIN","Random Forest","KNN","Discriminative DL","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","KNN","Random Forest","Discriminative DL","Mean/Mode","GAIN","VAE","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest"],"z":[0.3363799242873935,0.3450611320866272,0.3436304269778731,0.3364218741873586,0.3355786488062899,0.3350135389392599,20.767231352146496,20.76727584961534,20.76728606150741,20.767445707996355,20.767181743019027,20.76762167073313,0.7467125473259496,0.7461820677996833,0.7463233163884212,0.7464642896047046,0.7467354145280906,0.7465409056423177,0.2049781137264811,9.19212578809432,0.2049859335529445,0.2050794851613383,0.2050910037922322,0.2051359982830636,0.2051688631299961,9.190877803374915,9.191423204846169,9.19367372183458,9.19249026254431,9.191556315217085,0.0014202325441904,0.0014177069272466,0.0014194612814716,0.0014197223499473,0.0014199286236335,0.001420188321868,0.046885650954077,0.046881566095199,0.0468753019546986,0.0468813343609536,0.0468695168692332,0.0468733677182528,6500.916423008707,6500.916376325135,6500.916520075672,6500.91642538764,6500.916500489019,6500.916470909632,4.530625752660645,4.530578188260786,4.530596646822056,4.530614183185269,4.530727308994663,4.530901827398464,0.0028844152935685,0.0028433637421973,0.0028434925094091,0.0028445023984438,0.0028410552904182,0.0028496122470294,149.40961440 ...
# <div>                            <div id="2143974c-5cb5-43a5-bb39-158ddf79cdb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2143974c-5cb5-43a5-bb39-158ddf79cdb1")) {                    Plotly.newPlot(                        "2143974c-5cb5-43a5-bb39-158ddf79cdb1",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["KNN","VAE","GAIN","Mean/Mode","Discriminative DL","Random Forest","Mean/Mode","KNN","Random Forest","VAE","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","KNN","Random Forest","Mean/Mode","KNN","VAE","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Random Forest","Random Forest","Discriminative DL","KNN","Discriminative DL","Random Forest","GAIN","Mean/Mode","KNN","VAE","Random Forest","VAE","GAIN","Discriminative DL","Mean/Mode","KNN","Mean/Mode","VAE","GAIN","Random Forest","KNN","Discriminative DL","Random Forest","GAIN","Discriminative DL","Mean/Mode","VAE","KNN","VAE","KNN","Discriminative DL","Mean/Mode","GAIN","Random Forest","Random Forest","KNN","Discriminative DL","Mean/Mode","VAE","GAIN","KNN","Discriminative DL","Mean/Mode","Random Forest","VAE","GAIN","VAE","Random Forest","KNN","GAIN","Discriminative DL","Mean/Mode","Mean/Mode","KNN","Discriminative DL","Random Forest","VAE","GAIN","GAIN","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","KNN","GAIN","Discriminative DL","Mean/Mode","VAE","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","GAIN","VAE","VAE","Mean/Mode","Discriminative DL","KNN","Random Forest","GAIN"],"z":[0.3439784062955859,0.3564218214233539,0.357825823319634,0.3543497738409842,0.3412927559635991,0.3410649977120706,20.76681790293136,20.76698247633077,20.76786963824448,20.768292083927992,20.7667241331654,0.7476617375081944,0.7489698774727819,0.748380581024812,0.7453855223136054,0.7489769821799553,0.7473525177602846,0.2052467381726689,9.190087753349257,0.2055768264908611,9.185488170393391,9.18645696367112,9.187619766928334,9.192887687011485,0.2054916171000352,9.193562957630594,0.2052895287702096,0.2052733250498265,0.2053251412429524,0.0014189279497133,0.0014189561786337,0.0014221407779778,0.0014193493468862,0.0014196436499412,0.0014187529633652,0.0468873580560289,0.0468999101607619,0.0469437843335347,0.0468923576753467,0.0468784383439463,0.0468864083628695,6500.916326141509,6500.9162545233485,6500.916978726024,6500.916525607612,6500.916455673004,6500.916470196837,4.530621912350058,4.53039682251834,4.530621094663414,4.530686130808481,4.530732154923258,4.530796499658268,0.0028977791928382,0.0028751671977193,0.0028693160228857,0.002870927231588,0.0029179370182446,0.0028719832454493,149.23179649195296,149.6555400558227,149.7649 ...
# <div>                            <div id="2702faa0-dcec-4faa-b0f8-7a1ef512c434" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2702faa0-dcec-4faa-b0f8-7a1ef512c434")) {                    Plotly.newPlot(                        "2702faa0-dcec-4faa-b0f8-7a1ef512c434",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","KNN","VAE","GAIN","Random Forest","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","KNN","Discriminative DL","GAIN","GAIN","Mean/Mode","VAE","KNN","Discriminative DL","KNN","Random Forest","Random Forest","Mean/Mode","VAE","Discriminative DL","Mean/Mode","VAE","GAIN","KNN","Random Forest","KNN","Random Forest","Discriminative DL","Mean/Mode","GAIN","VAE","VAE","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","Random Forest","Mean/Mode","GAIN","Random Forest","Mean/Mode","Discriminative DL","VAE","GAIN","KNN","Random Forest","Discriminative DL","KNN","Mean/Mode","GAIN","VAE","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","GAIN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","KNN","Discriminative DL","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","KNN","VAE","Mean/Mode","Mean/Mode","Discriminative DL","KNN","Random Forest","GAIN","VAE"],"z":[0.3500106537701202,0.3599095913285794,0.3608792977027148,0.442423460022115,0.3472860800181343,0.3446705473641926,20.76777788266355,20.767823731566533,20.768124415337947,20.768201330817018,20.767752431262704,0.7486460042653583,0.7487273763416482,0.7486561718312227,0.7473022063813625,0.750015247056537,0.7482018161257703,0.2053476994172965,9.18882640994416,0.2057842752012852,9.184502957973724,9.186842718124298,9.186887625576013,9.19263043609953,0.2056857682091617,9.193344881667588,0.2054955075377277,0.205423580095382,0.2055327974740969,0.0014189631038953,0.0014193703510081,0.0014202923220329,0.0014195281572549,0.0014195807498176,0.0014188663963735,0.0469049142110887,0.0469096272115999,0.0469184035103234,0.046909149989125,0.0468833508656759,0.0469018308420529,6500.916196264531,6500.916100734937,6500.916769684052,6500.9163588283,6500.916244263016,4.530770819925423,4.5307020873170885,4.530642332491996,4.530618268505863,4.5304967875239415,4.5327440308981926,0.0028925604460133,0.0028763988477463,0.0029060507058466,0.0029194452155805,0.0031130562855031,0.0028987554898989,148.8809244939562,150.0091002345346,150.0188207606662,151.3561461592183,153.501806483830 ...
# <div>                            <div id="72a8fb86-302e-46d5-a68a-81a3dc1c5ee1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72a8fb86-302e-46d5-a68a-81a3dc1c5ee1")) {                    Plotly.newPlot(                        "72a8fb86-302e-46d5-a68a-81a3dc1c5ee1",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","GAIN","Mean/Mode","VAE","Random Forest","Discriminative DL","KNN","Mean/Mode","Random Forest","Discriminative DL","GAIN","KNN","VAE","VAE","Discriminative DL","Mean/Mode","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","KNN","Random Forest","GAIN","GAIN","Discriminative DL","Mean/Mode","VAE","Random Forest","KNN","GAIN","Mean/Mode","Discriminative DL","VAE","Random Forest","KNN","GAIN","VAE","Random Forest","Mean/Mode","KNN","KNN","GAIN","Mean/Mode","Random Forest","Discriminative DL","VAE","Discriminative DL","VAE","Random Forest","Mean/Mode","KNN","Discriminative DL","KNN","Mean/Mode","Random Forest","GAIN","VAE","GAIN","Random Forest","VAE","Mean/Mode","KNN","Discriminative DL","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","GAIN","Mean/Mode","VAE","Random Forest","GAIN","Discriminative DL","KNN","KNN","Random Forest","Discriminative DL","VAE","Mean/Mode","Mean/Mode","Discriminative DL","KNN","Random Forest","VAE","Random Forest","Discriminative DL","KNN","VAE","GAIN","Mean/Mode","Discriminative DL","VAE","KNN","Mean/Mode","Random Forest","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN"],"z":[0.3326649076947596,0.3331120014732751,0.3334079907851247,0.3330873457259148,0.3325806197680365,0.3325501165509578,20.767074910872378,20.7670765707192,20.767079381981347,20.76708828733648,20.76707246684433,20.76710267643351,0.7466273393207605,0.7464119994858152,0.7464999018716373,0.7465120857898623,0.7463628639471808,0.7466231826067062,0.2049422976134271,9.193429648564148,0.2049635408522521,0.204973839122674,0.2049755066274911,0.2049846659875086,0.2050457367085482,9.19319912341637,9.193213868649424,9.193438785613758,9.193429888628089,9.193296312155296,0.0014192617438915,0.0014185711776926,0.001418894930569,0.0014189102612675,0.0014189813579095,0.001419045073685,0.0468832266704148,0.0468768261602116,0.0468704884481727,0.0468755578955777,0.0468694274308631,0.0468701663243008,6500.916458174913,6500.916477325841,6500.916459994639,6500.916472807461,6500.916470457108,4.5306239892307785,4.530601337904396,4.5306232993826505,4.530624128018521,4.530630977034253,4.530648313869331,0.0028358466938416,0.0028379156469881,0.0028371766818658,0.0028376530957307,0.0028376656904244,149.47568817773947,149.47912763847492,149.52934435274634,149.54899563317906,149.677082554603,149.66412743312375,11.9 ...
# <div>                            <div id="b1c175b1-6990-4ad8-afa5-a2ca2828f612" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1c175b1-6990-4ad8-afa5-a2ca2828f612")) {                    Plotly.newPlot(                        "b1c175b1-6990-4ad8-afa5-a2ca2828f612",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Mean/Mode","KNN","Random Forest","VAE","GAIN","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","KNN","VAE","GAIN","Random Forest","Random Forest","Discriminative DL","KNN","VAE","GAIN","Mean/Mode","Mean/Mode","KNN","Discriminative DL","GAIN","Mean/Mode","VAE","KNN","Random Forest","Discriminative DL","Discriminative DL","GAIN","KNN","VAE","Mean/Mode","Random Forest","GAIN","Random Forest","Mean/Mode","VAE","KNN","Discriminative DL","Discriminative DL","KNN","Mean/Mode","VAE","Random Forest","GAIN","Random Forest","VAE","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","KNN","GAIN","Random Forest","VAE","Mean/Mode","Mean/Mode","Random Forest","KNN","VAE","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","VAE","GAIN","KNN","Random Forest","KNN","GAIN","VAE","Discriminative DL","Mean/Mode","Random Forest","Random Forest","GAIN","KNN","Mean/Mode","Discriminative DL","VAE","VAE","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","Random Forest","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","Random Forest","Mean/Mode","VAE","KNN","Random Forest","Discriminative DL","GAIN"],"z":[0.3394586399205501,0.3590681610412947,0.3747369907938929,0.3448442049430744,0.3378903933001811,0.3373424909669982,20.7670889888496,20.767127548766883,20.767175489383018,20.76745219318936,20.76705653579971,0.7477860366561148,0.748332837371377,0.7480908402595531,0.7471935798040592,0.7488800977911799,0.7473888372433443,0.2044514495008806,9.195258775236978,0.2049305092341883,9.193384597663648,9.19348768299384,9.194395179494396,9.198153470122566,0.2047403849743611,9.198367703572304,0.2045749447499143,0.2045645428621629,0.2046019136444269,0.0014181635207634,0.0014187160247445,0.0014198689228095,0.0014188741696148,0.0014192661971988,0.0014178655615567,0.046866153944676,0.04687612440351,0.0468840679316046,0.0468687104947828,0.046850809440238,0.0468642276215293,6500.916429517542,6500.916390564066,6500.916582145495,6500.916574837332,6500.91643178213,6500.916545016703,4.530058235860788,4.529875011142113,4.529989491277372,4.530059438857515,4.530100366991081,4.530600087500927,0.0028514401497757,0.0028455376146952,0.002841638355496,0.0028419694618761,0.0028694461164385,0.0028421127347208,149.37227256123015,149.4516053954822,149.50384237617388,149.78 ...
# <div>                            <div id="2744653f-8e6a-4f7b-b88e-41243ddc97d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2744653f-8e6a-4f7b-b88e-41243ddc97d8")) {                    Plotly.newPlot(                        "2744653f-8e6a-4f7b-b88e-41243ddc97d8",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Random Forest","Mean/Mode","GAIN","KNN","Discriminative DL","VAE","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","Random Forest","VAE","Mean/Mode","KNN","Discriminative DL","GAIN","Discriminative DL","GAIN","GAIN","Mean/Mode","Random Forest","KNN","VAE","KNN","Random Forest","Mean/Mode","VAE","Discriminative DL","VAE","KNN","GAIN","Random Forest","Discriminative DL","Mean/Mode","KNN","GAIN","VAE","Random Forest","Mean/Mode","Discriminative DL","VAE","Mean/Mode","Random Forest","KNN","GAIN","Discriminative DL","VAE","Random Forest","GAIN","Discriminative DL","Mean/Mode","KNN","Discriminative DL","Mean/Mode","KNN","VAE","GAIN","Random Forest","Discriminative DL","KNN","Random Forest","GAIN","VAE","Mean/Mode","VAE","KNN","Mean/Mode","Discriminative DL","Random Forest","GAIN","GAIN","Discriminative DL","KNN","Mean/Mode","Random Forest","VAE","Mean/Mode","VAE","KNN","Random Forest","Discriminative DL","GAIN","Random Forest","Discriminative DL","VAE","KNN","GAIN","Mean/Mode","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","KNN","Discriminative DL","GAIN","Mean/Mode","Random Forest","GAIN","Mean/Mode","VAE","Discriminative DL","Random Forest","KNN"],"z":[0.3433801931295122,0.3520829124572493,0.3644354837356172,0.3458400295685669,0.3403531604816166,0.2959840550064926,20.767030972133,20.767050258921568,20.767124531124946,20.767275374468163,20.7666650103535,20.768373996751983,0.7451482407007942,0.7460853466836689,0.7427953411998928,0.7443201368028038,0.7461715162280957,0.7443686279468805,0.2036392534903846,9.194423116063628,0.2039458068585171,0.2041438645275761,0.2041665678628496,0.2042130850790965,0.2052414716527547,9.190196488336117,9.192884529029996,9.206307552118831,9.203132448883132,9.193672700967936,0.0014205688810232,0.001419260951634,0.0014193332663753,0.0014194864637865,0.0014195503243076,0.001419703316864,0.0469179912029904,0.046897256698738,0.0468755943202427,0.0468856544236506,0.046852939710381,0.0468691942667201,6500.916333504181,6500.916303599045,6500.916507038962,6500.916506568047,6500.916423904586,6500.91647534219,4.530901827536659,4.530547831610715,4.530786169744245,4.531096485924116,4.53159516013648,4.531691640920372,0.0028633507770392,0.0028584493374461,0.0028470435773863,0.0028547295476765,0.002964115769892,0.0028555093027103,1 ...
# <div>                            <div id="56cf6892-f736-4c27-9b79-fecd7fbba8ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56cf6892-f736-4c27-9b79-fecd7fbba8ef")) {                    Plotly.newPlot(                        "56cf6892-f736-4c27-9b79-fecd7fbba8ef",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","KNN","Mean/Mode","Random Forest","KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","VAE","Random Forest","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","Mean/Mode","KNN","GAIN","Discriminative DL","VAE","Mean/Mode","GAIN","VAE","Discriminative DL","KNN","Random Forest","Mean/Mode","GAIN","Random Forest","VAE","Discriminative DL","KNN","VAE","GAIN","Random Forest","KNN","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Discriminative DL","Mean/Mode","VAE","Random Forest","GAIN","KNN","Mean/Mode","Random Forest","KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","VAE","Random Forest","GAIN","VAE","Discriminative DL","Mean/Mode","GAIN","KNN","Random Forest","VAE","KNN","Discriminative DL","Random Forest","Mean/Mode","GAIN","GAIN","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","Mean/Mode","Random Forest","VAE","Discriminative DL","KNN","GAIN","KNN","Mean/Mode","Random Forest","Discriminative DL","VAE","GAIN","KNN","Random Forest","GAIN","Mean/Mode","VAE","Discriminative DL","GAIN","Mean/Mode","VAE","KNN","Discriminative DL","Random Forest"],"z":[0.3475472105660759,0.3633949369612558,0.3646257951394339,0.3476644094175374,0.3446821812281286,0.3425680935804764,20.767051667750373,20.76712078906265,20.76716454589447,20.7674609654983,20.766501278816207,20.768486827955368,0.7481229388762655,0.7483879931581868,0.7460549914896021,0.7468532139695295,0.7487893088770944,0.7478850801976863,0.2078263543936802,9.188800917082483,0.2098363961865913,0.2131619656148424,0.2147731658711472,0.2161695302639205,0.2165283467325459,9.185671563842504,9.18834699966355,9.193802971975964,9.192137566859538,9.188472790712732,0.0014346438131385,0.001422396405293,0.0014247266735343,0.001426978437208,0.0014271590706208,0.0014284226091489,0.0469347356850519,0.0469314383326731,0.0468833883803875,0.0469266312932642,0.0467732389407309,0.0468613812915377,6500.9161296715365,6500.913962825599,6500.916517795115,6500.916490576048,6500.916146305954,6500.916364306485,4.531383237506663,4.529459059310333,4.530829144686979,4.532074810400367,4.53280458592559,4.53441759116234,0.002957818164361,0.0028942036023498,0.0028711413457485,0.0028787536745523,0.0030017078591694,0.002887941306860 ...

# %%
df_heat_dif = downstream_results_rank_heatmap2.copy()
#df_heat_dif
# Out:
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 0                  GAIN    189          MAR             0.01    theta8
# 1         Random Forest    189          MAR             0.01    theta8
# 2             Mean/Mode    189          MAR             0.01    theta8
# 3                   VAE    189          MAR             0.01    theta8
# 4     Discriminative DL    189          MAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1337      Random Forest  42712         MNAR              0.5  humidity
# 1338                KNN  42712         MNAR              0.5  humidity
# 1339  Discriminative DL  42712         MNAR              0.5  humidity
# 1340                VAE  42712         MNAR              0.5  humidity
# 1341               GAIN  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks    0.204873        0.0
# 1     downstream_performance_mean  Regression Tasks    0.204919        0.0
# 2     downstream_performance_mean  Regression Tasks    0.204909        0.0
# 3     downstream_performance_mean  Regression Tasks    0.204895        0.0
# 4     downstream_performance_mean  Regression Tasks    0.204909        0.0
# ...                           ...               ...         ...        ...
# 1337  downstream_performance_mean  Regression Tasks  148.151741        0.0
# 1338  downstream_performance_mean  Regression Tasks  149.553233        0.0
# 1339  downstream_performance_mean  Regression Tasks  149.191945        0.0
# 1340  downstream_performance_mean  Regression Tasks  150.016976        0.0
# 1341  downstream_performance_mean  Regression Tasks  148.397969        0.0
#
#          Imputed  ...                 name MajorityClassSize  \
# 0       0.204926  ...               kin8nm               NaN
# 1       0.204999  ...               kin8nm               NaN
# 2       0.205023  ...               kin8nm               NaN
# 3       0.205026  ...               kin8nm               NaN
# 4       0.205028  ...               kin8nm               NaN
# ...          ...  ...                  ...               ...
# 1337  147.707377  ...  Bike_Sharing_Demand               NaN
# 1338  148.474038  ...  Bike_Sharing_Demand               NaN
# 1339  148.593887  ...  Bike_Sharing_Demand               NaN
# 1340  149.268209  ...  Bike_Sharing_Demand               NaN
# 1341  149.936478  ...  Bike_Sharing_Demand               NaN
#
#       MinorityClassSize  NumberOfFeatures  NumberOfInstances  \
# 0                   NaN               9.0             8192.0
# 1                   NaN               9.0             8192.0
# 2                   NaN               9.0             8192.0
# 3                   NaN               9.0             8192.0
# 4                   NaN               9.0             8192.0
# ...                 ...               ...                ...
# 1337                NaN              13.0            17379.0
# 1338                NaN              13.0            17379.0
# 1339                NaN              13.0            17379.0
# 1340                NaN              13.0            17379.0
# 1341                NaN              13.0            17379.0
#
#       NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                         9.0                          0.0              NaN
# 1                         9.0                          0.0              NaN
# 2                         9.0                          0.0              NaN
# 3                         9.0                          0.0              NaN
# 4                         9.0                          0.0              NaN
# ...                       ...                          ...              ...
# 1337                      9.0                          4.0              NaN
# 1338                      9.0                          4.0              NaN
# 1339                      9.0                          4.0              NaN
# 1340                      9.0                          4.0              NaN
# 1341                      9.0                          4.0              NaN
#
#       Downstream Performance Rank  Data_Constellation
# 0                             1.0          MAR - 0.01
# 1                             2.0          MAR - 0.01
# 2                             3.0          MAR - 0.01
# 3                             4.0          MAR - 0.01
# 4                             5.0          MAR - 0.01
# ...                           ...                 ...
# 1337                          2.0          MNAR - 0.5
# 1338                          3.0          MNAR - 0.5
# 1339                          4.0          MNAR - 0.5
# 1340                          5.0          MNAR - 0.5
# 1341                          6.0          MNAR - 0.5
#
# [1342 rows x 21 columns]

# %%
# Calculate Difference for every Imputation towards average best Imputation Method per Data Constellation
# Calculation for RMSE Differences in Percentage (RMSE alone not comparable over different datasets)

data = downstream_results_rank.copy()
data['Task'] = data['Task'].astype(str)
data['Data_Constellation_full'] = data['Data_Constellation'] + ' - ' + data['Task']

dc_unique = data.Data_Constellation_full.unique()
#print(dc_unique)

data_constellations = dc_unique.tolist()
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
heatmap_data_difference = pd.DataFrame()


for i in data_constellations:
    data_constel = data.loc[data['Data_Constellation_full'] == i]
    average_best = data_constel.loc[data_constel['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
    dataset_number = best_score.iloc[0]['Task']
    for i in methods:
        if ((data_constel['Imputation_Method'] == i).any()):
            current_score_row = data_constel.loc[data['Imputation_Method'] == i]
            current_score_int = current_score_row.iloc[0]['Imputed']
            average_best_int = average_best.iloc[0]['Imputed']
            calc_result = ((average_best_int - current_score_int)/current_score_int)

            current_score_row['Performance Difference to Average Best in Percent'] = calc_result
            heatmap_data_difference = heatmap_data_difference.append(current_score_row)  
        else:
            print("Imputation Method not here ---------------------")

heatmap_data_difference
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_21128\248245157.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 1         Random Forest    189          MAR             0.01    theta8
# 5                   KNN    189          MAR             0.01    theta8
# 2             Mean/Mode    189          MAR             0.01    theta8
# 3                   VAE    189          MAR             0.01    theta8
# 0                  GAIN    189          MAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1338                KNN  42712         MNAR              0.5  humidity
# 1336          Mean/Mode  42712         MNAR              0.5  humidity
# 1340                VAE  42712         MNAR              0.5  humidity
# 1341               GAIN  42712         MNAR              0.5  humidity
# 1339  Discriminative DL  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 1     downstream_performance_mean  Regression Tasks    0.204919        0.0
# 5     downstream_performance_mean  Regression Tasks    0.204892        0.0
# 2     downstream_performance_mean  Regression Tasks    0.204909        0.0
# 3     downstream_performance_mean  Regression Tasks    0.204895        0.0
# 0     downstream_performance_mean  Regression Tasks    0.204873        0.0
# ...                           ...               ...         ...        ...
# 1338  downstream_performance_mean  Regression Tasks  149.553233        0.0
# 1336  downstream_performance_mean  Regression Tasks  147.017846        0.0
# 1340  downstream_performance_mean  Regression Tasks  150.016976        0.0
# 1341  downstream_performance_mean  Regression Tasks  148.397969        0.0
# 1339  downstream_performance_mean  Regression Tasks  149.191945        0.0
#
#          Imputed  ...  MinorityClassSize NumberOfFeatures  NumberOfInstances  \
# 1       0.204999  ...                NaN              9.0             8192.0
# 5       0.205038  ...                NaN              9.0             8192.0
# 2       0.205023  ...                NaN              9.0             8192.0
# 3       0.205026  ...                NaN              9.0             8192.0
# 0       0.204926  ...                NaN              9.0             8192.0
# ...          ...  ...                ...              ...                ...
# 1338  148.474038  ...                NaN             13.0            17379.0
# 1336  146.311138  ...                NaN             13.0            17379.0
# 1340  149.268209  ...                NaN             13.0            17379.0
# 1341  149.936478  ...                NaN             13.0            17379.0
# 1339  148.593887  ...                NaN             13.0            17379.0
#
#       NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 1                         9.0                          0.0              NaN
# 5                         9.0                          0.0              NaN
# 2                         9.0                          0.0              NaN
# 3                         9.0                          0.0              NaN
# 0                         9.0                          0.0              NaN
# ...                       ...                          ...              ...
# 1338                      9.0                          4.0              NaN
# 1336                      9.0                          4.0              NaN
# 1340                      9.0                          4.0              NaN
# 1341                      9.0                          4.0              NaN
# 1339                      9.0                          4.0              NaN
#
#       Downstream Performance Rank  Data_Constellation  \
# 1                             2.0          MAR - 0.01
# 5                             6.0          MAR - 0.01
# 2                             3.0          MAR - 0.01
# 3                             4.0          MAR - 0.01
# 0                             1.0          MAR - 0.01
# ...                           ...                 ...
# 1338                          3.0          MNAR - 0.5
# 1336                          1.0          MNAR - 0.5
# 1340                          5.0          MNAR - 0.5
# 1341                          6.0          MNAR - 0.5
# 1339                          4.0          MNAR - 0.5
#
#       Data_Constellation_full  \
# 1            MAR - 0.01 - 189
# 5            MAR - 0.01 - 189
# 2            MAR - 0.01 - 189
# 3            MAR - 0.01 - 189
# 0            MAR - 0.01 - 189
# ...                       ...
# 1338       MNAR - 0.5 - 42712
# 1336       MNAR - 0.5 - 42712
# 1340       MNAR - 0.5 - 42712
# 1341       MNAR - 0.5 - 42712
# 1339       MNAR - 0.5 - 42712
#
#       Performance Difference to Average Best in Percent
# 1                                              0.000000
# 5                                             -0.000189
# 2                                             -0.000117
# 3                                             -0.000131
# 0                                              0.000356
# ...                                                 ...
# 1338                                          -0.005164
# 1336                                           0.009543
# 1340                                          -0.010457
# 1341                                          -0.014867
# 1339                                          -0.005966
#
# [1342 rows x 23 columns]

# %%
# Heatmap for RMSE differences in Percentage for each data constellation for each method relative to average best imputation method

heatmap_data_difference = heatmap_data_difference.astype({"Task":"string"})
data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']
for i in data_constellations:
    data_constel = heatmap_data_difference.loc[df_heat['Data_Constellation'] == i]

    ### uncomment whatever you want to investigate

    ## sort by amount datapoints (ascending)
    data_constel = data_constel.sort_values(by=['NumberOfInstances'])

    ## sort by amount of features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfFeatures'])

    ## sort by amount of datapoints and features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances', 'NumberOfFeatures'])

    ## sort by amount of categorical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfCategoricalFeatures', 'NumberOfInstances'])

    ## sort by amount of numerical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfNumericFeatures', 'NumberOfInstances'])
    
    Dataset_number = data_constel["Task"]
    Imputation_Method = data_constel["Imputation_Method"]
    Improvement = data_constel["Performance Difference to Average Best in Percent"]
    

    trace = go.Heatmap(
                   z=Improvement,
                   x=Dataset_number,
                   y=Imputation_Method,
                   type = 'heatmap',
                    autocolorscale= False,
                    colorscale = 'RdBu_r',
                    zmid=0,
                    zmin=(-0.1),
                    zmax=0.1,
                    )
    data = [trace]
    fig = go.Figure(data=data)
    fig.update_layout(
        title=i,
        xaxis_nticks=36)
    fig.show()
    fig.write_image("regression_heatmap_f1_score_improvement_to_avbest%s.pdf" %i)
# Out:
# <div>                            <div id="8fe5cca5-60bc-4961-891e-7288bad088b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fe5cca5-60bc-4961-891e-7288bad088b1")) {                    Plotly.newPlot(                        "8fe5cca5-60bc-4961-891e-7288bad088b1",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395"],"y":["Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Discriminative DL","KNN","Mean/Mode","VAE","Random Forest","GAIN","Random Forest","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Random Forest","Discriminative DL","KNN","GAIN","VAE","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","VAE","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","KNN","Random Forest","VAE","Mean/Mode","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","Mean/Mode","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","Random Forest","KNN","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Random Forest","KNN","Discriminative DL","Mean/Mode","VAE"],"z":[0.00133318005853701,4.468627946561373e-05,-0.005143257342307458,-0.001221586833613549,0.0015181818958599018,0.0,-1.3645963169525682e-07,5.6029382162230984e-08,1.2166553905780946e-06,2.7296314211929384e-07,0.0,9.617483589469948e-07,-3.4383130428327426e-05,0.0001559137295513676,-0.00011945622281241185,0.00022613650516848126,0.0,0.00019486405353850108,0.0,-0.00010268553877802771,-0.00018931687706570042,-0.00011693668947817608,-0.0001308746932320371,0.0003559493240421899,-0.00014364050364325237,0.0,-3.3673424298389273e-06,5.336277727253104e-06,-3.805211824601783e-05,-0.00010761819852323866,0.00023699575929974763,0.0,4.192554499887919e-05,0.00014879646218555394,0.00022999842422312137,-0.00015324418089647678,6.61156210129699e-06,-0.00016259498027943367,-3.232170602140422e-05,-2.410659231786785e-05,0.0,1.515268775438489e-05,0.0,-3.495807625422324e-10,-2.8781729043967174e-10,2.1034556166714962e-10,-5.901051197172538e-10,-1.271864587014005e-09,4.225196275662355e-06,0.0,-5.313164097904943e-07,6.747495378396353e-07,6.566124722420878e-06,2.810740086860287e-05,0.0,4.787363425927802e-05,-0.00012853615730671993,6.195453546695622e-06,0.00020748896180524217,0.0,-0.000128 ...
# <div>                            <div id="1080cdb4-c9c0-409a-b070-a1f8239d0592" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1080cdb4-c9c0-409a-b070-a1f8239d0592")) {                    Plotly.newPlot(                        "1080cdb4-c9c0-409a-b070-a1f8239d0592",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","VAE","GAIN","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","GAIN","GAIN","Discriminative DL","Mean/Mode","KNN","VAE","KNN","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","Mean/Mode","GAIN","Discriminative DL","VAE","Random Forest","KNN","KNN","Random Forest","Discriminative DL","Mean/Mode","GAIN","VAE","VAE","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","Discriminative DL","KNN","Mean/Mode","VAE","Random Forest","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","VAE","Discriminative DL","KNN","Random Forest","Mean/Mode","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.019717325254661404,-0.0007346193283601596,-0.004682704011475828,-0.04131525587410383,-0.005630109533026224,0.0,-1.0772812013598149e-06,-1.2072881058508837e-07,6.523159634886048e-05,-1.9762204932909765e-06,0.0,-0.0006482173062952848,-0.0022617974137177886,0.0,-0.000266185006332525,-0.0003708004621702563,-0.0009048531615561891,0.0,-0.0006625945178811658,0.0002696753017490068,0.0,-7.489009806600071e-05,-0.00073855997688743,-0.00039850007797553763,-0.0013600147634952864,-4.603576595984002e-05,0.0001884783781931364,-8.859957848525449e-05,-0.0002876222947774591,-0.0006286023835914572,-0.000621961599839329,-0.0002362615196528716,7.65088911655544e-05,-0.0006847858098788069,0.0,-0.0007569108193109583,-0.0007030504983271036,0.0006750641562636571,-0.0009757835745347234,0.0,-0.00014284998518091383,-2.2658579648891717e-09,0.0,6.864341043308508e-09,-3.9090193918081814e-09,2.0441827518387724e-08,-5.2732309692228745e-09,2.989515291257588e-05,0.0,3.02128636802422e-05,1.9685356002344536e-05,0.00014255370604443046,-2.88792613972232e-08,0.0001106850886817923,-0.0010358203538344045,-0.002090299571777431,-0.000381948 ...
# <div>                            <div id="f6ac71ce-17a4-46cd-bad6-4dfa957ee972" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6ac71ce-17a4-46cd-bad6-4dfa957ee972")) {                    Plotly.newPlot(                        "f6ac71ce-17a4-46cd-bad6-4dfa957ee972",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","VAE","GAIN","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.04961866180775563,-0.01606703649879018,-0.004540515652180724,-0.07071417475229538,-0.012765850802549833,0.0,7.2188556306899005e-06,1.2021798575716e-06,-6.04824810668686e-06,4.323041179163488e-05,0.0,-1.2460248629350016e-05,-0.0034487174846123793,-0.009186609454003458,0.0,0.0016154573434446107,-0.0012986855752105525,-0.00414983974429761,0.0,-0.0009433233429022767,0.0013043189853706593,0.002178435159074399,-0.001892210082292614,-0.002881624984050462,-0.0025251645739320125,0.0,0.00019492537594426935,-0.00043343171771217937,8.463496155066722e-05,-0.0007339465503628864,0.0006453122403651218,0.0,-0.0012619450442469976,-0.0005097952894459037,-0.0006991846790974762,-0.0021220831078406447,-0.00034238908472715,-0.0018275780239973103,0.0001828376176488086,-0.0012091006810929267,0.0,0.00015567498688495143,5.694019533913922e-09,0.0,-4.4281109659049285e-09,-4.798026392986443e-08,4.3671624405971035e-08,1.3098712821800128e-08,2.5136020985376415e-05,0.0,6.639467086102768e-06,-3.723627528961603e-05,-4.251257292795753e-05,-1.731651713512992e-05,-0.020001104308000252,-0.0030 ...
# <div>                            <div id="e01f4f0c-9214-4dd1-aa09-8f030a6c62cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e01f4f0c-9214-4dd1-aa09-8f030a6c62cc")) {                    Plotly.newPlot(                        "e01f4f0c-9214-4dd1-aa09-8f030a6c62cc",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","VAE","GAIN","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.040103406251579814,-0.14277682892587812,-0.0015286285221956465,-0.055767378034710074,-0.01628705676008579,0.0,8.206904939918377e-06,-1.1453203645098096e-05,-3.681184778023471e-05,0.0001631792726362832,0.0,-0.00010811306994463401,-0.00016803972815934178,-0.019617457751957324,0.0,0.0020502136850850798,0.0008059455720753569,-0.002420346106916428,0.0,0.0009503402056121974,0.00013557054777331524,0.00045727101070764585,-0.00029312610489825105,-0.0013044740498205148,0.0004888758269088557,0.0,0.00025923228600846526,-0.003308557582941592,-0.0016043229288869437,-0.002788456116681444,0.0004466305155870781,0.0,-6.351963600743274e-05,0.0006438435416676079,0.0003627147580674999,0.0009054435770463351,-0.0015095483072832371,-0.0027480381429896396,-0.0007945292194138921,-0.004890072774318255,0.0,-0.002391429374739243,9.597454612712018e-09,0.0,4.0582367924883514e-08,-1.0209831679728608e-07,4.9242795354877215e-08,3.700365226132532e-08,-7.000145031348019e-06,0.0,1.7227589442222635e-05,0.00012343484774928127,-0.0003885168525375829,-3.356625871151426e-06,-0.022395312784779603, ...
# <div>                            <div id="f49681cf-757e-449c-b12a-c42897be2434" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f49681cf-757e-449c-b12a-c42897be2434")) {                    Plotly.newPlot(                        "f49681cf-757e-449c-b12a-c42897be2434",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Discriminative DL","KNN","Mean/Mode","VAE","Random Forest","GAIN","Random Forest","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","Random Forest","GAIN","KNN","VAE","Mean/Mode","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","GAIN","Mean/Mode","KNN","Random Forest","Discriminative DL","VAE","Random Forest","KNN","Mean/Mode","Discriminative DL","VAE","KNN","Mean/Mode","VAE","Discriminative DL","Random Forest","GAIN","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","VAE","Discriminative DL","Mean/Mode","KNN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Random Forest","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN"],"z":[-0.0019634017010270633,0.0011761685113453914,0.0004496337262863346,-0.004040242472374423,0.0003287371009175294,0.0,-1.8479877708381055e-06,-1.5402213669289545e-06,-1.5193387599743677e-06,-3.332833982107753e-06,0.0,-1.0894095971345087e-06,-5.3464514153462476e-05,-0.00011074152543017645,-0.00010610033042035575,-2.872377775775318e-05,0.0,-4.8444473616795826e-05,0.0,7.537542889561948e-05,-3.159740649033626e-05,1.2853926840453016e-05,0.00017557176499974315,0.00025502703390346213,0.0005137682075920218,0.0,4.8866664994996504e-05,-2.051905682383314e-05,3.029219441331592e-05,9.285562581189255e-05,-5.109724533647706e-05,0.0,2.797128975082627e-06,-2.0554850968168635e-05,0.00010966863193180863,7.652225575647059e-05,-7.484628534760565e-05,1.1076564523362398e-05,-2.6525696782776732e-06,-1.9643986995168432e-06,0.0,2.1017986327714272e-05,-2.9680420992102244e-10,0.0,2.2472557042367776e-09,-1.0219752952583718e-09,-3.4739772368896723e-10,-6.761187383755384e-10,3.6880557911393105e-07,5.980861934322454e-06,6.134347413032881e-06,7.132285917711828e-06,0.0,-1.1290051651809654e-05,4.438197970426429e-05,-0.00018859410340551214,0.0,0.0003107113237765909,-0.0004237000 ...
# <div>                            <div id="3dfb7474-5840-4c76-9381-4bc2946679f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3dfb7474-5840-4c76-9381-4bc2946679f0")) {                    Plotly.newPlot(                        "3dfb7474-5840-4c76-9381-4bc2946679f0",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","Discriminative DL","VAE","Random Forest","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","KNN","Random Forest","Discriminative DL","Mean/Mode","GAIN","VAE","VAE","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","Discriminative DL","KNN","Mean/Mode","VAE","Random Forest","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","VAE","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","GAIN","Discriminative DL","VAE","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.02911829879710958,-0.0016839863592043264,-0.004062030012725142,-0.0250760333256754,-0.004186217829921389,0.0,1.6160475891172184e-05,2.11837946789583e-05,8.473008151809487e-06,1.6652213814380923e-05,0.0,1.879492648861382e-05,-0.0005518663393375952,0.0,0.00018929507265483288,-0.00018885460195024488,-0.0002914632704677655,-0.0005212594042008272,0.0,0.0002448496754261837,-0.0004356312517127128,-5.616351122621547e-05,0.0004945476032260238,-0.0002754910020585237,0.00045638062462291827,0.0,0.00023036431969522975,0.00012874196833180014,0.00016839779784840654,0.0003042058135772384,-0.0003592328912521472,0.0,-0.00014527046132231335,0.0001839208149653626,-0.0003281057262089793,0.0014216074295513204,-0.00012341436159687453,-0.00034411561992820483,-8.215430652954392e-05,-0.0002520724267234239,0.0,-0.00025701415224342594,7.562939859110001e-09,0.0,1.4565336105869352e-08,1.493127414128977e-08,3.0129064495317047e-09,2.2112349819892568e-08,6.424283788005853e-06,0.0,-2.2415017963483302e-05,1.0498527534962672e-05,-6.093152055283069e-05,2.553621850849349e-06,4.5286928959889054e-05,-0.0003 ...
# <div>                            <div id="8e9b428f-ff73-448d-99eb-c8d28ad8af11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e9b428f-ff73-448d-99eb-c8d28ad8af11")) {                    Plotly.newPlot(                        "8e9b428f-ff73-448d-99eb-c8d28ad8af11",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Mean/Mode","GAIN","VAE","Random Forest","Discriminative DL","KNN","Random Forest","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","GAIN","GAIN","Discriminative DL","Mean/Mode","KNN","VAE","KNN","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","Mean/Mode","GAIN","Discriminative DL","VAE","Random Forest","KNN","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","Discriminative DL","VAE","GAIN","KNN","Random Forest","Mean/Mode","GAIN","VAE","Mean/Mode","KNN","Random Forest","Discriminative DL"],"z":[-0.03749057318398401,-0.04684073791005149,-0.0006673398352257404,-0.0430860929051889,-0.008469742664636225,0.0,4.271982772272181e-05,5.0644991352803096e-05,-2.034089668060453e-05,5.5160605579126626e-05,0.0,-0.0021594456080860206,0.0026388967692500165,-0.00041358241621463655,0.0,-0.001373717184269562,-0.0021689110057062917,0.0,0.0007735293364542426,7.893729192112889e-05,0.0,0.00037814701824475164,0.000879080903204343,0.0006468694670683501,-0.0009834383157694554,7.345576733878085e-05,0.00020848369100365295,-0.00017344428708157488,-0.0013975199712710539,-0.00048425624805811617,-0.00027700597697289194,1.989454109048185e-05,0.00014323513236433677,-0.002239299648399304,0.0,0.00019027323429917964,-0.00120199677778199,-0.00010661906471863182,-0.00026763600804294475,0.0,2.0255191057673536e-05,1.0757653750503082e-08,0.0,8.523532917957941e-09,-6.970069202653958e-08,3.068276737629224e-08,4.169939329248068e-08,-1.4174113273106281e-05,0.0,-3.853346938525568e-05,-2.4332176220179345e-05,4.968435228427026e-05,1.8048003279093747e-07,-0.01574871990312708,-0.008901971362294963,0.0,-0.0011073972576361448,0 ...
# <div>                            <div id="c0b3d771-4b0f-4f73-8a10-ba1d9ff54a69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0b3d771-4b0f-4f73-8a10-ba1d9ff54a69")) {                    Plotly.newPlot(                        "c0b3d771-4b0f-4f73-8a10-ba1d9ff54a69",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Mean/Mode","GAIN","VAE","Random Forest","Discriminative DL","KNN","Random Forest","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","GAIN","GAIN","Discriminative DL","Mean/Mode","KNN","VAE","KNN","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","Mean/Mode","GAIN","Discriminative DL","VAE","Random Forest","KNN","KNN","Random Forest","GAIN","VAE","Mean/Mode","GAIN","VAE","Mean/Mode","KNN","Random Forest","Discriminative DL","KNN","Random Forest","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","VAE","Mean/Mode","GAIN","KNN","Random Forest","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Discriminative DL","Mean/Mode","VAE","KNN","Random Forest","VAE","Mean/Mode","KNN","Random Forest","Discriminative DL","GAIN"],"z":[-0.04234131107240851,-0.04491460286501291,-0.22094875496212638,-0.007531348949560933,-0.015256982461553449,0.0,-3.433210178955006e-06,-1.225523548643298e-06,-1.791129847860195e-05,-2.161475359197575e-05,0.0,-1.3581088685198095e-05,-0.0018256199411309513,-0.00010868051424468924,0.0,0.0017981987374329936,0.0005936742333613279,0.0,0.0007077691153308234,0.0007197943821655601,0.0,0.0007028774438906661,0.0009627002935622686,0.0004917354536744033,-0.0014032542733163431,7.77193832630958e-05,0.0003501420932898259,-0.0009250064945696253,-0.00018143058834150264,-0.0005032143780421874,-0.0003550550666654244,-6.815365497140813e-05,-0.0010039663224814684,-0.0004661836949256542,0.0,1.017333452021572e-05,0.0005604621990283939,-0.00018705450456276275,0.0001662274032170868,0.0,0.0001004798876720783,6.319966749747058e-08,0.0,1.0290074587042272e-07,8.82059549375832e-08,8.082261279150514e-08,-0.00046897913887009555,-3.367008079261711e-05,2.681405320856158e-05,-1.8500181563412995e-05,0.0,-5.311385089937711e-06,-0.002137139164440583,0.0,-0.009208862500218079,-0.07082937771366563,-0.00464212816595364,0.005618691677499037,0.0,-0.00758502 ...
# <div>                            <div id="0ed50e15-aaaa-4d88-b90b-01a7879c7355" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ed50e15-aaaa-4d88-b90b-01a7879c7355")) {                    Plotly.newPlot(                        "0ed50e15-aaaa-4d88-b90b-01a7879c7355",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Discriminative DL","KNN","Mean/Mode","VAE","Random Forest","GAIN","Random Forest","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Random Forest","GAIN","KNN","VAE","Mean/Mode","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.001612877768701208,-9.1716760585684e-05,-0.0016867747779491804,-0.0025730464112354553,-0.00034506538305246993,0.0,-6.928793704518123e-07,5.641919429557225e-07,4.288207778475625e-07,6.441188352666917e-07,0.0,7.618065655201396e-07,-0.00011775270914535246,6.583331112501608e-05,-0.00028841675572886967,-0.00028285100946607244,0.0,-0.0001340719138407809,0.0,2.3497764954725887e-05,8.135208006177774e-06,5.8380018169242654e-05,0.00016204080099960162,-0.00034250934540002115,-4.468314726567172e-05,0.0,-9.677538379876646e-07,2.61125553203849e-08,1.452976911191059e-05,2.510173103184214e-05,0.0002891502543898661,0.0,-4.490045924660218e-05,6.0911726892410975e-05,5.01065105670414e-05,-0.00019755762684853844,-2.2637214689473776e-05,-0.00029433212113806227,-0.00015783341054725547,-0.00013078169071089636,0.0,-1.576468563363848e-05,0.0,2.799183939621288e-10,-1.6093836547245477e-09,-2.6659628606498386e-09,-1.9709255240368203e-09,1.8289666021350798e-07,0.0,3.063325107481222e-08,-5.338275923130168e-06,5.030262524775881e-06,-1.5117134383826326e-06,0.0,0.00046899151039738954,-0.00017232775525670118,-0.00016789010101929354,-0.00026039009407632794,0.0,0.000467409 ...
# <div>                            <div id="36b10e6a-7974-4f18-ada8-5eab4e13d45b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36b10e6a-7974-4f18-ada8-5eab4e13d45b")) {                    Plotly.newPlot(                        "36b10e6a-7974-4f18-ada8-5eab4e13d45b",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Mean/Mode","GAIN","VAE","Random Forest","Discriminative DL","KNN","Random Forest","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","GAIN","GAIN","Discriminative DL","Mean/Mode","KNN","VAE","KNN","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","Mean/Mode","GAIN","Discriminative DL","VAE","Random Forest","KNN","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Discriminative DL","Mean/Mode","VAE","Random Forest","GAIN","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.05897979837504451,-0.02016508192167875,0.0016241723110905566,-0.09832655542131302,-0.00461984594275173,0.0,2.3084856594678165e-06,4.165270031992016e-06,-1.3323916856456106e-05,5.727994388708192e-06,0.0,-0.002252053422296971,-0.0015223941947003273,-0.0007922812449198085,0.0,-0.0011994004032753129,-0.0002612528172152545,0.0,-0.000518459761995506,0.001606024029337538,0.0,-0.00010991281220996563,-0.0005417380636697213,-0.00020381999236133565,0.0009286114210003554,-1.1212864339033747e-05,0.0017380646721359245,0.001789001979057382,0.0023431466711398047,0.0002762948204959575,0.00038779603860401905,0.0009878479879025313,-0.00042449383954916046,0.0007775382875498934,0.0,0.0002864023365149869,-0.00025379192781152694,-4.110265051768877e-05,-9.564746301258705e-05,0.0,-0.00042317808480787846,-6.34034660316766e-09,0.0,-2.3758593982472854e-08,-5.9919976822229424e-09,-2.9469910390987513e-08,-2.8345736063941968e-08,2.4475931770356203e-05,0.0,4.974880066538856e-05,9.03478952500076e-06,-0.00011029896706722591,9.300350701769351e-06,-0.006275067010196575,0.002074312794186004,0.0,0.0034493461353878427,0.00333243830612 ...
# <div>                            <div id="3c8dcc99-6fae-4759-8b10-cc35d4cc55fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c8dcc99-6fae-4759-8b10-cc35d4cc55fd")) {                    Plotly.newPlot(                        "3c8dcc99-6fae-4759-8b10-cc35d4cc55fd",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","VAE","GAIN","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.024717812253367576,-0.057775083782400684,0.008893799145605565,0.1601307142101959,-0.007112642345431671,0.0,9.287215198877783e-07,-3.5764317427012674e-06,-6.373815449499085e-05,1.8551296892245508e-05,0.0,-1.0839917251332903e-05,-0.0012560305426719306,0.0010473476778085399,0.0,0.0011125641468568337,-0.0013713677151255968,0.003167628242122031,0.0,-0.0011135251948242056,-0.0002277876377455832,0.00011121243014590645,-0.0052372640931152405,0.001082449341484332,0.0025894534743514117,0.0,0.00029249001338447665,-8.572982349659582e-05,-0.00016733915920666477,-0.0014580246220153642,-4.498644395088364e-05,0.0,0.00015889407246808904,-0.0001527453482174413,-0.0007619604027369085,0.00010793618019775272,0.00035119351181564734,-0.0002473977350516519,0.0006982424896244203,0.0002146128183286882,0.0,-0.0006892191782017481,7.243817517566982e-11,0.0,4.8757389480971815e-09,1.278810101628676e-08,3.1294037214232676e-08,2.669389538530532e-08,-0.00023111696626800126,0.0,-0.00025240228159590804,-7.812924212847997e-05,-5.260414519715081e-05,-0.00012108643351678954,-0.0366404268972453 ...
# <div>                            <div id="e2f5ac72-c7df-4a0c-92e9-8de0eff9e84b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2f5ac72-c7df-4a0c-92e9-8de0eff9e84b")) {                    Plotly.newPlot(                        "e2f5ac72-c7df-4a0c-92e9-8de0eff9e84b",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","VAE","GAIN","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0.04328769045396894,-0.046517240272072366,0.008652110122962823,0.0003372170683534101,0.014876796562677437,0.0,-2.107020037578769e-06,3.3284123996761254e-06,-6.577459898910366e-05,2.983219166884809e-05,0.0,-1.6380261227809812e-05,0.0013816185146641978,0.002453021196775568,0.0,-0.0012075875933166022,-0.0006719949613010878,-0.0003179406301007872,0.0,3.571065368809845e-05,-0.006459580085447203,-0.008106009618993134,0.033426037317229935,0.023526755959752586,0.0075585728985818786,0.0,4.940142323212109e-05,-0.00036298953891682726,-0.0005440680976879783,0.00034067767590309175,0.0010120488882268686,0.0,0.0008853522736961413,-0.004336410147679915,0.0025941366040628817,0.004236655712483205,0.0023549671169058118,-0.0010238329357179351,-0.0010940149958223468,-0.0009215004717994901,0.0,0.0004696210022681105,4.18695846121205e-09,0.0,2.3610306905886146e-08,3.9301697132213196e-07,5.714412452750932e-08,5.970290512059637e-08,-0.0002748555055908956,0.0,-0.0004358099276429157,-0.00012227895780217237,0.00030248322342811047,-0.0007913797975632458,-0.04096140943280289,0.0026513249 ...

# %%
#heatmap_data_difference.agg(['min', 'max'])
heatmap_data_difference.to_csv('heatmap_data_difference.csv')
heatmap_data_difference['Performance Difference to Average Best in Percent'].agg(['min', 'max'])
# Out:
# min   -0.220949
# max    0.160131
# Name: Performance Difference to Average Best in Percent, dtype: float64

# %%
heatmap_data_difference
heatmap_data_difference.to_csv('regression_imputed_full_info.csv', index=False)

# %% [markdown]
# ## Improvment Proportions for All Data Constellations and Methods Relative to Average Best Method

# %%
# data preprocessing here
df_quantiles = heatmap_data_difference.copy()
df_quantiles = df_quantiles.drop(df_quantiles[df_quantiles["Imputation_Method"] == AVERAGE_BEST_IMPUTATION_METHOD].index)

df_10 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] > (-0.09))].index)
df_09 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.09)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (-0.07))].index)
df_07 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.07)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (-0.05))].index)
df_05 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.05)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (-0.03))].index)
df_03 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.03)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (-0.01))].index)
df_01 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.01)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.01))].index)
df01 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.01)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.03))].index)
df03 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.03)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.05))].index)
df05 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.05)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.07))].index)
df07 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.07)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.09))].index)
df09 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.09))].index)

#df_quantiles
#df_quantiles.dtypes

# %%
len_df_10 = len(df_10.index)
len_df_09 = len(df_09.index)
len_df_07 = len(df_07.index)
len_df_05 = len(df_05.index)
len_df_03 = len(df_03.index)
len_df_01 = len(df_01.index)
len_df01 = len(df01.index)
len_df03 = len(df03.index)
len_df05 = len(df05.index)
len_df07 = len(df07.index)
len_df09 = len(df09.index)

quantile_freq = []
#quantile_freq.append()
quantile_freq.extend((len_df_10, len_df_09, len_df_07, len_df_05, len_df_03, len_df_01, len_df01, len_df03, len_df05, len_df07, len_df09))
print(quantile_freq)


quantiles = []
quantiles.extend(['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09'])
print(quantiles)

improvement_quantiles = pd.DataFrame(
    {'Improvement to Average Best in Percent': quantiles,
     'Amount': quantile_freq,
    })
# Out:
# [10, 6, 8, 20, 46, 1009, 12, 2, 0, 0, 1]
# ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03', '-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']

# %%
fig = px.bar(improvement_quantiles, x='Improvement to Average Best in Percent', y='Amount')
fig.show()
fig.write_image("improv_rel_to_av_all_DC_no_av_incl.pdf")
# Out:
# <div>                            <div id="2265c993-2558-40a3-a692-e2a86d440e5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2265c993-2558-40a3-a692-e2a86d440e5d")) {                    Plotly.newPlot(                        "2265c993-2558-40a3-a692-e2a86d440e5d",                        [{"alignmentgroup":"True","hovertemplate":"Improvement to Average Best in Percent=%{x}<br>Amount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"xaxis":"x","y":[10,6,8,20,46,1009,12,2,0,0,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay"," ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_10, df_09, df_07, df_05, df_03, df_01, df01, df03, df05, df07, df09]

methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
methods.remove(AVERAGE_BEST_IMPUTATION_METHOD)
print(methods)

forest_freq = []
knn_freq = []
mode_freq = []
dl_freq = []
vae_freq = []
gain_freq = []
#print(quantile_datasets)

for i in methods:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Imputation_Method'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'Random Forest'):
            forest_freq.append(df_temp_len)
        elif (i == 'KNN'):
            knn_freq.append(df_temp_len)                                       
        elif (i == 'Mean/Mode'):
            mode_freq.append(df_temp_len)                                                 
        elif (i == 'Discriminative DL'):
            dl_freq.append(df_temp_len)                                       
        elif (i == 'VAE'):
            vae_freq.append(df_temp_len)                                         
        elif (i == 'GAIN'):
            gain_freq.append(df_temp_len)                                          
                                       
print(forest_freq)
print(knn_freq)
print(mode_freq)
print(dl_freq)
print(vae_freq)
print(gain_freq)
# Out:
# ['KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
# []
# [0, 0, 0, 0, 3, 223, 2, 0, 0, 0, 0]
# [0, 1, 3, 7, 9, 205, 2, 1, 0, 0, 0]
# [0, 0, 0, 0, 3, 216, 3, 0, 0, 0, 0]
# [3, 3, 2, 4, 10, 203, 1, 1, 0, 0, 1]
# [7, 2, 3, 9, 21, 162, 4, 0, 0, 0, 0]

# %%
quantiles = ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']

fig = go.Figure(data=[
    go.Bar(name='Random Forest', x=quantiles, y=forest_freq),
    go.Bar(name='KNN', x=quantiles, y=knn_freq),
    go.Bar(name='Mean/Mode', x=quantiles, y=mode_freq),
    go.Bar(name='Discriminative DL', x=quantiles, y=dl_freq),
    go.Bar(name='VAE', x=quantiles, y=vae_freq),
    go.Bar(name='GAIN', x=quantiles, y=gain_freq)
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("improv_rel_to_av_all_DC_no_av_incl_per_method.pdf")
# Out:
# <div>                            <div id="cc3c56fb-25d3-41e2-b585-cf8c9e7b2159" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc3c56fb-25d3-41e2-b585-cf8c9e7b2159")) {                    Plotly.newPlot(                        "cc3c56fb-25d3-41e2-b585-cf8c9e7b2159",                        [{"name":"Random Forest","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[],"type":"bar"},{"name":"KNN","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,0,0,0,3,223,2,0,0,0,0],"type":"bar"},{"name":"Mean/Mode","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,1,3,7,9,205,2,1,0,0,0],"type":"bar"},{"name":"Discriminative DL","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,0,0,0,3,216,3,0,0,0,0],"type":"bar"},{"name":"VAE","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[3,3,2,4,10,203,1,1,0,0,1],"type":"bar"},{"name":"GAIN","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[7,2,3,9,21,162,4,0,0,0,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77 ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_10, df_09, df_07, df_05, df_03, df_01, df01, df03, df05, df07, df09]

fractions = ['0.01', '0.1', '0.3', '0.5']
#print(fractions)
#print(df_10)

freq_001 = []
freq_01 = []
freq_03 = []
freq_05 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Fraction'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == '0.01'):
            freq_001.append(df_temp_len)
        elif (i == '0.1'):
            freq_01.append(df_temp_len)                                       
        elif (i == '0.3'):
            freq_03.append(df_temp_len)                                                 
        elif (i == '0.5'):
            freq_05.append(df_temp_len)                                       
                                        
                                       
print(freq_001)
print(freq_01)
print(freq_03)
print(freq_05)
# Out:
# [0, 0, 0, 0, 0, 267, 0, 0, 0, 0, 0]
# [2, 0, 1, 1, 17, 259, 0, 0, 0, 0, 0]
# [3, 3, 5, 7, 12, 248, 5, 0, 0, 0, 1]
# [5, 3, 2, 12, 17, 235, 7, 2, 0, 0, 0]

# %%
quantiles = ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='1% Missing Data', x=quantiles, y=freq_001, marker_color='#FD3216'),
    go.Bar(name='10% Missing Data', x=quantiles, y=freq_01, marker_color='#00FE35'),
    go.Bar(name='30% Missing Data', x=quantiles, y=freq_03, marker_color='#511CFB'),
    go.Bar(name='50% Missing Data', x=quantiles, y=freq_05, marker_color='#FF7F0E'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("improv_rel_to_av_all_DC_no_av_incl_per_frac.pdf")
# Out:
# <div>                            <div id="c4438901-4d2f-40eb-bf12-900c459b8052" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4438901-4d2f-40eb-bf12-900c459b8052")) {                    Plotly.newPlot(                        "c4438901-4d2f-40eb-bf12-900c459b8052",                        [{"marker":{"color":"#FD3216"},"name":"1% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,0,0,0,0,267,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#00FE35"},"name":"10% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[2,0,1,1,17,259,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#511CFB"},"name":"30% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[3,3,5,7,12,248,5,0,0,0,1],"type":"bar"},{"marker":{"color":"#FF7F0E"},"name":"50% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[5,3,2,12,17,235,7,2,0,0,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d85 ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_10, df_09, df_07, df_05, df_03, df_01, df01, df03, df05, df07, df09]

fractions = ['MCAR', 'MAR', 'MNAR']
print(fractions)
#print(df_10)

freq_001 = []
freq_01 = []
freq_03 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Type'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'MCAR'):
            freq_001.append(df_temp_len)
        elif (i == 'MAR'):
            freq_01.append(df_temp_len)                                       
        elif (i == 'MNAR'):
            freq_03.append(df_temp_len)                                                 

                                       
print(freq_001)
print(freq_01)
print(freq_03)
# Out:
# ['MCAR', 'MAR', 'MNAR']
# [3, 4, 1, 8, 13, 341, 0, 0, 0, 0, 0]
# [4, 2, 1, 6, 19, 336, 3, 0, 0, 0, 0]
# [3, 0, 6, 6, 14, 332, 9, 2, 0, 0, 1]

# %%
quantiles = ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='MCAR', x=quantiles, y=freq_001, marker_color='#222A2A'),
    go.Bar(name='MAR', x=quantiles, y=freq_01, marker_color='#B68100'),
    go.Bar(name='MNAR', x=quantiles, y=freq_03, marker_color='#750D86'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("improv_rel_to_av_all_DC_no_av_incl_per_patt.pdf")
# Out:
# <div>                            <div id="7eaae14f-ea0d-4b7f-a24d-06f8c8c3d567" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7eaae14f-ea0d-4b7f-a24d-06f8c8c3d567")) {                    Plotly.newPlot(                        "7eaae14f-ea0d-4b7f-a24d-06f8c8c3d567",                        [{"marker":{"color":"#222A2A"},"name":"MCAR","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[3,4,1,8,13,341,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#B68100"},"name":"MAR","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[4,2,1,6,19,336,3,0,0,0,0],"type":"bar"},{"marker":{"color":"#750D86"},"name":"MNAR","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[3,0,6,6,14,332,9,2,0,0,1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{ ...

# %% [markdown]
# ## Improvment Proportions for the Best Imputation Method per Data Constellation Relative to Average Best Method

# %%
improv_to_av_bar = heatmap_data_difference.copy()

improv_to_av_bar = improv_to_av_bar.drop(improv_to_av_bar[improv_to_av_bar["Downstream Performance Rank"] != 1.0].index)

df_01 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (-0.01)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.01))].index)
df01 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.01)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.03))].index)
df03 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.03)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.05))].index)
df05 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.05)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.07))].index)
df07 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.07)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.09))].index)
df09 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.09))].index)

improv_to_av_bar
# Out:
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 0                  GAIN    189          MAR             0.01    theta8
# 6     Discriminative DL    189          MAR              0.1    theta8
# 12            Mean/Mode    189          MAR              0.3    theta8
# 18    Discriminative DL    189          MAR              0.5    theta8
# 24    Discriminative DL    189         MCAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1312      Random Forest  42712         MCAR              0.5  humidity
# 1318  Discriminative DL  42712         MNAR             0.01  humidity
# 1324  Discriminative DL  42712         MNAR              0.1  humidity
# 1330  Discriminative DL  42712         MNAR              0.3  humidity
# 1336          Mean/Mode  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks    0.204873        0.0
# 6     downstream_performance_mean  Regression Tasks    0.204813        0.0
# 12    downstream_performance_mean  Regression Tasks    0.204820        0.0
# 18    downstream_performance_mean  Regression Tasks    0.205841        0.0
# 24    downstream_performance_mean  Regression Tasks    0.205083        0.0
# ...                           ...               ...         ...        ...
# 1312  downstream_performance_mean  Regression Tasks  148.991778        0.0
# 1318  downstream_performance_mean  Regression Tasks  149.507994        0.0
# 1324  downstream_performance_mean  Regression Tasks  149.523046        0.0
# 1330  downstream_performance_mean  Regression Tasks  149.431371        0.0
# 1336  downstream_performance_mean  Regression Tasks  147.017846        0.0
#
#          Imputed  ...  MinorityClassSize NumberOfFeatures  NumberOfInstances  \
# 0       0.204926  ...                NaN              9.0             8192.0
# 6       0.204953  ...                NaN              9.0             8192.0
# 12      0.205069  ...                NaN              9.0             8192.0
# 18      0.205878  ...                NaN              9.0             8192.0
# 24      0.204972  ...                NaN              9.0             8192.0
# ...          ...  ...                ...              ...                ...
# 1312  148.880924  ...                NaN             13.0            17379.0
# 1318  149.475688  ...                NaN             13.0            17379.0
# 1324  149.372273  ...                NaN             13.0            17379.0
# 1330  149.346814  ...                NaN             13.0            17379.0
# 1336  146.311138  ...                NaN             13.0            17379.0
#
#       NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                         9.0                          0.0              NaN
# 6                         9.0                          0.0              NaN
# 12                        9.0                          0.0              NaN
# 18                        9.0                          0.0              NaN
# 24                        9.0                          0.0              NaN
# ...                       ...                          ...              ...
# 1312                      9.0                          4.0              NaN
# 1318                      9.0                          4.0              NaN
# 1324                      9.0                          4.0              NaN
# 1330                      9.0                          4.0              NaN
# 1336                      9.0                          4.0              NaN
#
#       Downstream Performance Rank  Data_Constellation  \
# 0                             1.0          MAR - 0.01
# 6                             1.0           MAR - 0.1
# 12                            1.0           MAR - 0.3
# 18                            1.0           MAR - 0.5
# 24                            1.0         MCAR - 0.01
# ...                           ...                 ...
# 1312                          1.0          MCAR - 0.5
# 1318                          1.0         MNAR - 0.01
# 1324                          1.0          MNAR - 0.1
# 1330                          1.0          MNAR - 0.3
# 1336                          1.0          MNAR - 0.5
#
#       Data_Constellation_full  \
# 0            MAR - 0.01 - 189
# 6             MAR - 0.1 - 189
# 12            MAR - 0.3 - 189
# 18            MAR - 0.5 - 189
# 24          MCAR - 0.01 - 189
# ...                       ...
# 1312       MCAR - 0.5 - 42712
# 1318      MNAR - 0.01 - 42712
# 1324       MNAR - 0.1 - 42712
# 1330       MNAR - 0.3 - 42712
# 1336       MNAR - 0.5 - 42712
#
#       Performance Difference to Average Best in Percent
# 0                                              0.000356
# 6                                              0.000270
# 12                                             0.002178
# 18                                             0.000489
# 24                                             0.000514
# ...                                                 ...
# 1312                                           0.000000
# 1318                                           0.000490
# 1324                                           0.002744
# 1330                                           0.004428
# 1336                                           0.009543
#
# [228 rows x 23 columns]

# %%
#improv_to_av_bar.agg(['min', 'max'])
# Out:
#      Imputation_Method   Task Missing Type Missing Fraction    Column  \
# min  Discriminative DL   1193          MAR             0.01  Material
# max                VAE  42712         MNAR              0.5        x6
#
#                      result_type            metric      Baseline  Corrupted  \
# min  downstream_performance_mean  Regression Tasks      0.001417        0.0
# max  downstream_performance_mean  Regression Tasks  72725.060283        0.0
#
#           Imputed  ...  MinorityClassSize NumberOfFeatures  NumberOfInstances  \
# min      0.001418  ...                NaN              6.0             4477.0
# max  72725.053954  ...                NaN             22.0            89640.0
#
#      NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# min                      3.0                          0.0              NaN
# max                     22.0                          7.0              NaN
#
#      Downstream Performance Rank  Data_Constellation  Data_Constellation_full  \
# min                          1.0          MAR - 0.01        MAR - 0.01 - 1193
# max                          1.0          MNAR - 0.5       MNAR - 0.5 - 42712
#
#      Performance Difference to Average Best in Percent
# min                                           0.000000
# max                                           0.160131
#
# [2 rows x 23 columns]

# %%
len_df_01 = len(df_01.index)
len_df01 = len(df01.index)
len_df03 = len(df03.index)
len_df05 = len(df05.index)
len_df07 = len(df07.index)
len_df09 = len(df09.index)

quantile_freq = []
quantile_freq.extend((len_df_01, len_df01, len_df03, len_df05, len_df07, len_df09))
print(quantile_freq)


quantiles = []
quantiles.extend(['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09'])
print(quantiles)

improvement_quantiles = pd.DataFrame(
    {'Improvement to Average Best in Percent': quantiles,
     'Amount': quantile_freq,
    })

fig = px.bar(improvement_quantiles, x='Improvement to Average Best in Percent', y='Amount')
fig.show()
fig.write_image("improv_rel_to_av_all_DC_no_av_incl_only_best.pdf")
# Out:
# [218, 7, 2, 0, 0, 1]
# ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']
# <div>                            <div id="97521d17-9655-4115-8188-99f1967d87ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97521d17-9655-4115-8188-99f1967d87ee")) {                    Plotly.newPlot(                        "97521d17-9655-4115-8188-99f1967d87ee",                        [{"alignmentgroup":"True","hovertemplate":"Improvement to Average Best in Percent=%{x}<br>Amount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"xaxis":"x","y":[218,7,2,0,0,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"o ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_01, df01, df03, df05, df07, df09]

methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
methods.remove(AVERAGE_BEST_IMPUTATION_METHOD)
print(methods)

forest_freq = []
knn_freq = []
mode_freq = []
dl_freq = []
vae_freq = []
gain_freq = []
#print(quantile_datasets)

for i in methods:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Imputation_Method'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'Random Forest'):
            forest_freq.append(df_temp_len)
        elif (i == 'KNN'):
            knn_freq.append(df_temp_len)                                       
        elif (i == 'Mean/Mode'):
            mode_freq.append(df_temp_len)                                                 
        elif (i == 'Discriminative DL'):
            dl_freq.append(df_temp_len)                                       
        elif (i == 'VAE'):
            vae_freq.append(df_temp_len)                                         
        elif (i == 'GAIN'):
            gain_freq.append(df_temp_len)                                          
                                       
print(forest_freq)
print(knn_freq)
print(mode_freq)
print(dl_freq)
print(vae_freq)
print(gain_freq)
# Out:
# ['KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
# []
# [23, 1, 0, 0, 0, 0]
# [47, 2, 1, 0, 0, 0]
# [35, 2, 0, 0, 0, 0]
# [29, 0, 1, 0, 0, 1]
# [36, 2, 0, 0, 0, 0]

# %%
quantiles = ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='Random Forest', x=quantiles, y=forest_freq),
    go.Bar(name='KNN', x=quantiles, y=knn_freq),
    go.Bar(name='Mean/Mode', x=quantiles, y=mode_freq),
    go.Bar(name='Discriminative DL', x=quantiles, y=dl_freq),
    go.Bar(name='VAE', x=quantiles, y=vae_freq),
    go.Bar(name='GAIN', x=quantiles, y=gain_freq)
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("improv_rel_to_av_all_DC_no_av_incl_only_best_per_method.pdf")
# Out:
# <div>                            <div id="914da0fa-acd4-471f-add1-a555449f21e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("914da0fa-acd4-471f-add1-a555449f21e6")) {                    Plotly.newPlot(                        "914da0fa-acd4-471f-add1-a555449f21e6",                        [{"name":"Random Forest","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[],"type":"bar"},{"name":"KNN","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[23,1,0,0,0,0],"type":"bar"},{"name":"Mean/Mode","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[47,2,1,0,0,0],"type":"bar"},{"name":"Discriminative DL","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[35,2,0,0,0,0],"type":"bar"},{"name":"VAE","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[29,0,1,0,0,1],"type":"bar"},{"name":"GAIN","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[36,2,0,0,0,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size" ...

# %%
# split barchart stacks into missingness fractions

quantile_datasets = [df_01, df01, df03, df05, df07, df09]

fractions = ['0.01', '0.1', '0.3', '0.5']
print(fractions)


freq_001 = []
freq_01 = []
freq_03 = []
freq_05 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Fraction'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == '0.01'):
            freq_001.append(df_temp_len)
        elif (i == '0.1'):
            freq_01.append(df_temp_len)                                       
        elif (i == '0.3'):
            freq_03.append(df_temp_len)                                                 
        elif (i == '0.5'):
            freq_05.append(df_temp_len)                                       
                                        
                                       
print(freq_001)
print(freq_01)
print(freq_03)
print(freq_05)
# Out:
# ['0.01', '0.1', '0.3', '0.5']
# [57, 0, 0, 0, 0, 0]
# [57, 0, 0, 0, 0, 0]
# [53, 3, 0, 0, 0, 1]
# [51, 4, 2, 0, 0, 0]

# %%
quantiles = ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='1% Missing Data', x=quantiles, y=freq_001, marker_color='#FD3216'),
    go.Bar(name='10% Missing Data', x=quantiles, y=freq_01, marker_color='#00FE35'),
    go.Bar(name='30% Missing Data', x=quantiles, y=freq_03, marker_color='#511CFB'),
    go.Bar(name='50% Missing Data', x=quantiles, y=freq_05, marker_color='#FF7F0E'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("improv_rel_to_av_all_DC_no_av_incl_only_best_per_frac.pdf")
# Out:
# <div>                            <div id="c00b6d7e-b9b5-414f-a508-a0df9235bf97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c00b6d7e-b9b5-414f-a508-a0df9235bf97")) {                    Plotly.newPlot(                        "c00b6d7e-b9b5-414f-a508-a0df9235bf97",                        [{"marker":{"color":"#FD3216"},"name":"1% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[57,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#00FE35"},"name":"10% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[57,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#511CFB"},"name":"30% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[53,3,0,0,0,1],"type":"bar"},{"marker":{"color":"#FF7F0E"},"name":"50% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[51,4,2,0,0,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"ty ...

# %%
# split barchart stacks into missingness fractions

quantile_datasets = [df_01, df01, df03, df05, df07, df09]

fractions = ['MCAR', 'MAR', 'MNAR']
print(fractions)


freq_001 = []
freq_01 = []
freq_03 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Type'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'MCAR'):
            freq_001.append(df_temp_len)
        elif (i == 'MAR'):
            freq_01.append(df_temp_len)                                       
        elif (i == 'MNAR'):
            freq_03.append(df_temp_len)                                                 

                                       
print(freq_001)
print(freq_01)
print(freq_03)
# Out:
# ['MCAR', 'MAR', 'MNAR']
# [76, 0, 0, 0, 0, 0]
# [73, 3, 0, 0, 0, 0]
# [69, 4, 2, 0, 0, 1]

# %%
quantiles = ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='MCAR', x=quantiles, y=freq_001, marker_color='#222A2A'),
    go.Bar(name='MAR', x=quantiles, y=freq_01, marker_color='#B68100'),
    go.Bar(name='MNAR', x=quantiles, y=freq_03, marker_color='#750D86'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("improv_rel_to_av_all_DC_no_av_incl_only_best_per_patt.pdf")
# Out:
# <div>                            <div id="45fb9573-79ca-4a77-a102-98d7008386cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45fb9573-79ca-4a77-a102-98d7008386cc")) {                    Plotly.newPlot(                        "45fb9573-79ca-4a77-a102-98d7008386cc",                        [{"marker":{"color":"#222A2A"},"name":"MCAR","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[76,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#B68100"},"name":"MAR","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[73,3,0,0,0,0],"type":"bar"},{"marker":{"color":"#750D86"},"name":"MNAR","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[69,4,2,0,0,1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay"," ...

# %% [markdown]
# ## Extract datasets for Automated Imputation Method Selection -> not used for thesis
#
# To Do: Explore the possibility, that the average best method replaces the best method for a data constellation, if the improvement gain for the best method is below 1%
#
# ### Potential Features:
# Missingess Pattern (Missing Type)
# Missing Fraction (Missing Fraction)
# Datapoints (NumberOfInstances)
# Features in total (NumberOfFeatures)
# Numeric Features (NumberOfNumericFeatures)
# Categorical Features (NumberOfCategoricalFeatures)
# Downstream Task Type -> Classification/Regression (metric)
#
#
#
# Label: Best Imputation Method (Imputation_Method)

# %%
# Use dataset with only the best method for each data constellation
rank_1_backup.to_csv('rank_1_backup.csv')
rank_1_backup
# Out:
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 0                  GAIN    189          MAR             0.01    theta8
# 6     Discriminative DL    189          MAR              0.1    theta8
# 12            Mean/Mode    189          MAR              0.3    theta8
# 18    Discriminative DL    189          MAR              0.5    theta8
# 24    Discriminative DL    189         MCAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1312      Random Forest  42712         MCAR              0.5  humidity
# 1318  Discriminative DL  42712         MNAR             0.01  humidity
# 1324  Discriminative DL  42712         MNAR              0.1  humidity
# 1330  Discriminative DL  42712         MNAR              0.3  humidity
# 1336          Mean/Mode  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks    0.204873        0.0
# 6     downstream_performance_mean  Regression Tasks    0.204813        0.0
# 12    downstream_performance_mean  Regression Tasks    0.204820        0.0
# 18    downstream_performance_mean  Regression Tasks    0.205841        0.0
# 24    downstream_performance_mean  Regression Tasks    0.205083        0.0
# ...                           ...               ...         ...        ...
# 1312  downstream_performance_mean  Regression Tasks  148.991778        0.0
# 1318  downstream_performance_mean  Regression Tasks  149.507994        0.0
# 1324  downstream_performance_mean  Regression Tasks  149.523046        0.0
# 1330  downstream_performance_mean  Regression Tasks  149.431371        0.0
# 1336  downstream_performance_mean  Regression Tasks  147.017846        0.0
#
#          Imputed  ...                 name MajorityClassSize  \
# 0       0.204926  ...               kin8nm               NaN
# 6       0.204953  ...               kin8nm               NaN
# 12      0.205069  ...               kin8nm               NaN
# 18      0.205878  ...               kin8nm               NaN
# 24      0.204972  ...               kin8nm               NaN
# ...          ...  ...                  ...               ...
# 1312  148.880924  ...  Bike_Sharing_Demand               NaN
# 1318  149.475688  ...  Bike_Sharing_Demand               NaN
# 1324  149.372273  ...  Bike_Sharing_Demand               NaN
# 1330  149.346814  ...  Bike_Sharing_Demand               NaN
# 1336  146.311138  ...  Bike_Sharing_Demand               NaN
#
#       MinorityClassSize  NumberOfFeatures  NumberOfInstances  \
# 0                   NaN               9.0             8192.0
# 6                   NaN               9.0             8192.0
# 12                  NaN               9.0             8192.0
# 18                  NaN               9.0             8192.0
# 24                  NaN               9.0             8192.0
# ...                 ...               ...                ...
# 1312                NaN              13.0            17379.0
# 1318                NaN              13.0            17379.0
# 1324                NaN              13.0            17379.0
# 1330                NaN              13.0            17379.0
# 1336                NaN              13.0            17379.0
#
#       NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                         9.0                          0.0              NaN
# 6                         9.0                          0.0              NaN
# 12                        9.0                          0.0              NaN
# 18                        9.0                          0.0              NaN
# 24                        9.0                          0.0              NaN
# ...                       ...                          ...              ...
# 1312                      9.0                          4.0              NaN
# 1318                      9.0                          4.0              NaN
# 1324                      9.0                          4.0              NaN
# 1330                      9.0                          4.0              NaN
# 1336                      9.0                          4.0              NaN
#
#       Downstream Performance Rank  Data_Constellation
# 0                             1.0          MAR - 0.01
# 6                             1.0           MAR - 0.1
# 12                            1.0           MAR - 0.3
# 18                            1.0           MAR - 0.5
# 24                            1.0         MCAR - 0.01
# ...                           ...                 ...
# 1312                          1.0          MCAR - 0.5
# 1318                          1.0         MNAR - 0.01
# 1324                          1.0          MNAR - 0.1
# 1330                          1.0          MNAR - 0.3
# 1336                          1.0          MNAR - 0.5
#
# [228 rows x 21 columns]

# %%
# Dataset for Training 
properties_train_dataset_8 = rank_1_backup.copy()
properties_train_dataset_8 = properties_train_dataset_8[['Imputation_Method','Missing Type','Missing Fraction',
                                                         'NumberOfInstances','NumberOfFeatures','NumberOfNumericFeatures',
                                                         'NumberOfCategoricalFeatures','metric']]

properties_train_dataset_8
# Out:
#       Imputation_Method Missing Type Missing Fraction  NumberOfInstances  \
# 0                  GAIN          MAR             0.01             8192.0
# 6     Discriminative DL          MAR              0.1             8192.0
# 12            Mean/Mode          MAR              0.3             8192.0
# 18    Discriminative DL          MAR              0.5             8192.0
# 24    Discriminative DL         MCAR             0.01             8192.0
# ...                 ...          ...              ...                ...
# 1312      Random Forest         MCAR              0.5            17379.0
# 1318  Discriminative DL         MNAR             0.01            17379.0
# 1324  Discriminative DL         MNAR              0.1            17379.0
# 1330  Discriminative DL         MNAR              0.3            17379.0
# 1336          Mean/Mode         MNAR              0.5            17379.0
#
#       NumberOfFeatures  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0                  9.0                      9.0                          0.0
# 6                  9.0                      9.0                          0.0
# 12                 9.0                      9.0                          0.0
# 18                 9.0                      9.0                          0.0
# 24                 9.0                      9.0                          0.0
# ...                ...                      ...                          ...
# 1312              13.0                      9.0                          4.0
# 1318              13.0                      9.0                          4.0
# 1324              13.0                      9.0                          4.0
# 1330              13.0                      9.0                          4.0
# 1336              13.0                      9.0                          4.0
#
#                 metric
# 0     Regression Tasks
# 6     Regression Tasks
# 12    Regression Tasks
# 18    Regression Tasks
# 24    Regression Tasks
# ...                ...
# 1312  Regression Tasks
# 1318  Regression Tasks
# 1324  Regression Tasks
# 1330  Regression Tasks
# 1336  Regression Tasks
#
# [228 rows x 8 columns]

# %%
# Dataset for Training 
properties_train_dataset_7 = rank_1_backup.copy()
properties_train_dataset_7 = properties_train_dataset_7[['Imputation_Method','Missing Type','Missing Fraction',
                                                         'NumberOfInstances','NumberOfFeatures','NumberOfNumericFeatures',
                                                         'NumberOfCategoricalFeatures']]

properties_train_dataset_7
properties_train_dataset_7.to_csv('properties_train_dataset_7.csv', index=False)
