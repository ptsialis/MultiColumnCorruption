# %% [markdown]
# # Visualize Results: Downstream Performance - Subset Binary Classification Corrupted Experiments -> Training and Test identically imputed
#
#
# [Set Average Best Imputation Method Manually](#Set-Average-Best-Imputation-Method-Manually)
#
#
# This notebook should answer the questions: *Does imputation lead to better downstream performances?*
#
# Data needs to be preprocessed with other notebook, her we only import two csv files with raw data regarding the results of the experiment and information about the used datasets!
#
# ## Notebook Structure
#
# * Application Scenario 2 - Downstream Performance
#    * Categorical  Columns (Classification)
#    * Numerical Columns (Regression)
#    * Heterogenous Columns (Classification and Regression Combined)

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import seaborn as sns
from pandas.api.types import CategoricalDtype
from pathlib import Path

import plotly as py
import plotly.express as px
import plotly.graph_objects as go
import xarray as xr


# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Settings

# %%
sns.set(style="whitegrid")
sns.set_context('paper', font_scale=1.5)
mpl.rcParams['lines.linewidth'] = '2'

# %%
CLF_METRIC = "Classification Tasks"
REG_METRIC = "Regression Tasks"

DOWNSTREAM_RESULT_TYPE = "downstream_performance_mean"
IMPUTE_RESULT_TYPE = "impute_performance_mean"

# %% [markdown]
# ## Data Preparation

# %%
# import preprocessed data from experiments
results = pd.read_csv('../binary_classification_corrupted_subset.csv')
results
# Out:
#                                experiment           imputer  task  \
# 0      corrupted_binary_experiment_subset  AutoKerasImputer  1046
# 1      corrupted_binary_experiment_subset  AutoKerasImputer  1046
# 2      corrupted_binary_experiment_subset  AutoKerasImputer  1046
# 3      corrupted_binary_experiment_subset  AutoKerasImputer  1046
# 4      corrupted_binary_experiment_subset  AutoKerasImputer  1046
# ...                                   ...               ...   ...
# 26659  corrupted_binary_experiment_subset        VAEImputer   923
# 26660  corrupted_binary_experiment_subset        VAEImputer   923
# 26661  corrupted_binary_experiment_subset        VAEImputer   923
# 26662  corrupted_binary_experiment_subset        VAEImputer   923
# 26663  corrupted_binary_experiment_subset        VAEImputer   923
#
#       missing_type  missing_fraction       strategy column  \
# 0              MAR              0.01  single_single    end
# 1              MAR              0.01  single_single    end
# 2              MAR              0.01  single_single    end
# 3              MAR              0.10  single_single    end
# 4              MAR              0.10  single_single    end
# ...            ...               ...            ...    ...
# 26659         MNAR              0.30  single_single   isns
# 26660         MNAR              0.30  single_single   isns
# 26661         MNAR              0.50  single_single   isns
# 26662         MNAR              0.50  single_single   isns
# 26663         MNAR              0.50  single_single   isns
#
#                        result_type       metric         train          test  \
# 0           impute_performance_std          MAE  1.137442e+05  3.887922e+04
# 1           impute_performance_std          MSE  5.654021e+10  2.603024e+10
# 2           impute_performance_std         RMSE  1.080402e+05  6.591475e+04
# 3           impute_performance_std          MAE  1.137216e+05  6.174183e+04
# 4           impute_performance_std          MSE  8.905253e+10  1.204022e+11
# ...                            ...          ...           ...           ...
# 26659  downstream_performance_mean     F1_macro           NaN           NaN
# 26660  downstream_performance_mean  F1_weighted           NaN           NaN
# 26661  downstream_performance_mean     F1_micro           NaN           NaN
# 26662  downstream_performance_mean     F1_macro           NaN           NaN
# 26663  downstream_performance_mean  F1_weighted           NaN           NaN
#
#        baseline  corrupted   imputed
# 0           NaN        NaN       NaN
# 1           NaN        NaN       NaN
# 2           NaN        NaN       NaN
# 3           NaN        NaN       NaN
# 4           NaN        NaN       NaN
# ...         ...        ...       ...
# 26659  0.964694        0.0  0.964655
# 26660  0.965209        0.0  0.965186
# 26661  0.947977        0.0  0.938343
# 26662  0.947272        0.0  0.937742
# 26663  0.947942        0.0  0.938387
#
# [26664 rows x 14 columns]

# %%
# Filtering the relevant data for downstream analysis

na_impute_results = results[
    (results["result_type"] == IMPUTE_RESULT_TYPE) & 
    (results["metric"].isin(["F1_macro", "RMSE"]))
]
na_impute_results.drop(["baseline", "corrupted", "imputed"], axis=1, inplace=True)
na_impute_results = na_impute_results[na_impute_results.isna().any(axis=1)]
na_impute_results.shape
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3401284833.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (0, 11)

# %%
# check if strategy type is correct!
STRATEGY_TYPE = "single_single"

downstream_results = results[
    (results["result_type"] == DOWNSTREAM_RESULT_TYPE) & 
    (results["metric"].isin(["F1_macro", "RMSE"]) &
    (results["strategy"] == STRATEGY_TYPE))
]

# remove experiments where imputation failed
downstream_results = downstream_results.merge(
    na_impute_results,
    how = "left",
    validate = "one_to_one",
    indicator = True,
    suffixes=("", "_imp"),
    on = ["experiment", "imputer", "task", "missing_type", "missing_fraction", "strategy", "column"]
)
downstream_results = downstream_results[downstream_results["_merge"]=="left_only"]

assert len(results["strategy"].unique()) == 1
downstream_results.drop(["experiment", "strategy", "result_type_imp", "metric_imp", "train", "test", "train_imp", "test_imp", "_merge"], axis=1, inplace=True)

downstream_results = downstream_results.rename(
    {
        "imputer": "Imputation_Method",
        "task": "Task",
        "missing_type": "Missing Type",
        "missing_fraction": "Missing Fraction",
        "column": "Column",
        "baseline": "Baseline",
        "imputed": "Imputed_Subset",
        "corrupted": "Corrupted"
    },
    axis = 1
)

# %%
rename_imputer_dict = {
    "ModeImputer": "Mean/Mode",
    "KNNImputer": "KNN",
    "ForestImputer": "Random Forest",
    "AutoKerasImputer": "Discriminative DL",
    "VAEImputer": "VAE",
    "GAINImputer": "GAIN"    
}

rename_metric_dict = {
    "F1_macro": CLF_METRIC,
    "RMSE": REG_METRIC
}

downstream_results = downstream_results.replace(rename_imputer_dict)
downstream_results = downstream_results.replace(rename_metric_dict)

downstream_results
# Out:
#       Imputation_Method  Task Missing Type  Missing Fraction Column  \
# 0     Discriminative DL  1046          MAR              0.01    end
# 1     Discriminative DL  1046          MAR              0.10    end
# 2     Discriminative DL  1046          MAR              0.30    end
# 3     Discriminative DL  1046         MCAR              0.01    end
# 4     Discriminative DL  1046         MCAR              0.30    end
# ...                 ...   ...          ...               ...    ...
# 2217                VAE   923         MCAR              0.50   isns
# 2218                VAE   923         MNAR              0.01   isns
# 2219                VAE   923         MNAR              0.10   isns
# 2220                VAE   923         MNAR              0.30   isns
# 2221                VAE   923         MNAR              0.50   isns
#
#                       result_type                metric  Baseline  Corrupted  \
# 0     downstream_performance_mean  Classification Tasks  0.803655        0.0
# 1     downstream_performance_mean  Classification Tasks  0.801405        0.0
# 2     downstream_performance_mean  Classification Tasks  0.805895        0.0
# 3     downstream_performance_mean  Classification Tasks  0.799632        0.0
# 4     downstream_performance_mean  Classification Tasks  0.785320        0.0
# ...                           ...                   ...       ...        ...
# 2217  downstream_performance_mean  Classification Tasks  0.848246        0.0
# 2218  downstream_performance_mean  Classification Tasks  0.964694        0.0
# 2219  downstream_performance_mean  Classification Tasks  0.964694        0.0
# 2220  downstream_performance_mean  Classification Tasks  0.964694        0.0
# 2221  downstream_performance_mean  Classification Tasks  0.947272        0.0
#
#       Imputed_Subset
# 0           0.803655
# 1           0.804529
# 2           0.799645
# 3           0.799632
# 4           0.794331
# ...              ...
# 2217        0.861480
# 2218        0.964694
# 2219        0.964694
# 2220        0.964655
# 2221        0.937742
#
# [2222 rows x 10 columns]

# %%
#downstream_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2222 entries, 0 to 2221
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Imputation_Method  2222 non-null   object
#  1   Task               2222 non-null   int64
#  2   Missing Type       2222 non-null   object
#  3   Missing Fraction   2222 non-null   float64
#  4   Column             2222 non-null   object
#  5   result_type        2222 non-null   object
#  6   metric             2222 non-null   object
#  7   Baseline           2222 non-null   float64
#  8   Corrupted          2222 non-null   float64
#  9   Imputed_Subset     2222 non-null   float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 191.0+ KB

# %% [markdown]
# ### Robustness: Check which Imputers Yielded `NaN`Values

# %%
for col in downstream_results.columns:
    na_sum = downstream_results[col].isna().sum()
    if na_sum > 0:
        print("-----" * 10)        
        print(col, na_sum)
        print("-----" * 10)        
        na_idx = downstream_results[col].isna()
        print(downstream_results.loc[na_idx, "Imputation Method"].value_counts(dropna=False))
        print("\n")

# %% [markdown]
# ## Adding Dataset Info, Sorting and Ranking

# %%
clf_row_idx = downstream_results["metric"] == CLF_METRIC
reg_row_idx = downstream_results["metric"] == REG_METRIC

# Sorting of data

#adjust order to fit the processing time -> fastest first
methods_order = CategoricalDtype(['Mean/Mode', 'KNN', 'Random Forest', 'VAE', 'GAIN', 'Discriminative DL'], ordered=True)
downstream_results_full_sort = downstream_results.copy()

downstream_results_full_sort['Imputation_Method'] = downstream_results_full_sort['Imputation_Method'].astype(methods_order)

downstream_results_full_sort = downstream_results_full_sort.sort_values(['Task', 'Missing Type',
                                                                         'Missing Fraction', 'Imputed_Subset','Imputation_Method'], ascending=[True, True, True, True, True])
downstream_results_full_sort
# Out:
#       Imputation_Method   Task Missing Type  Missing Fraction  \
# 31    Discriminative DL    137          MAR              0.01
# 1142                KNN    137          MAR              0.01
# 398       Random Forest    137          MAR              0.01
# 770                GAIN    137          MAR              0.01
# 1514          Mean/Mode    137          MAR              0.01
# ...                 ...    ...          ...               ...
# 1729          Mean/Mode  42493         MNAR              0.50
# 985                GAIN  42493         MNAR              0.50
# 613       Random Forest  42493         MNAR              0.50
# 1357                KNN  42493         MNAR              0.50
# 2101                VAE  42493         MNAR              0.50
#
#                  Column                  result_type                metric  \
# 31    top-middle-square  downstream_performance_mean  Classification Tasks
# 1142  top-middle-square  downstream_performance_mean  Classification Tasks
# 398   top-middle-square  downstream_performance_mean  Classification Tasks
# 770   top-middle-square  downstream_performance_mean  Classification Tasks
# 1514  top-middle-square  downstream_performance_mean  Classification Tasks
# ...                 ...                          ...                   ...
# 1729             Length  downstream_performance_mean  Classification Tasks
# 985              Length  downstream_performance_mean  Classification Tasks
# 613              Length  downstream_performance_mean  Classification Tasks
# 1357             Length  downstream_performance_mean  Classification Tasks
# 2101             Length  downstream_performance_mean  Classification Tasks
#
#       Baseline  Corrupted  Imputed_Subset
# 31    0.695789        0.0        0.694867
# 1142  0.698074        0.0        0.698074
# 398   0.698074        0.0        0.698074
# 770   0.698555        0.0        0.698555
# 1514  0.699217        0.0        0.699217
# ...        ...        ...             ...
# 1729  0.591024        0.0        0.592436
# 985   0.592603        0.0        0.592837
# 613   0.594657        0.0        0.595566
# 1357  0.612391        0.0        0.606716
# 2101  0.610725        0.0        0.611129
#
# [2222 rows x 10 columns]

# %%
#downstream_results_full_sort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2222 entries, 31 to 2101
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Imputation_Method  2222 non-null   category
#  1   Task               2222 non-null   int64
#  2   Missing Type       2222 non-null   object
#  3   Missing Fraction   2222 non-null   float64
#  4   Column             2222 non-null   object
#  5   result_type        2222 non-null   object
#  6   metric             2222 non-null   object
#  7   Baseline           2222 non-null   float64
#  8   Corrupted          2222 non-null   float64
#  9   Imputed_Subset     2222 non-null   float64
# dtypes: category(1), float64(4), int64(1), object(4)
# memory usage: 176.0+ KB

# %%
# add complete dataset information from other csv file
dataset_info = pd.read_csv('../datasets_information_overview.csv')
dataset_info = dataset_info.rename(columns={"did": "Task"})

downstream_results_full_sort = pd.merge(downstream_results_full_sort, dataset_info, on='Task')
#downstream_results_full_sort.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction             Column  \
# 0  Discriminative DL   137          MAR              0.01  top-middle-square
# 1                KNN   137          MAR              0.01  top-middle-square
# 2      Random Forest   137          MAR              0.01  top-middle-square
# 3               GAIN   137          MAR              0.01  top-middle-square
# 4          Mean/Mode   137          MAR              0.01  top-middle-square
#
#                    result_type                metric  Baseline  Corrupted  \
# 0  downstream_performance_mean  Classification Tasks  0.695789        0.0
# 1  downstream_performance_mean  Classification Tasks  0.698074        0.0
# 2  downstream_performance_mean  Classification Tasks  0.698074        0.0
# 3  downstream_performance_mean  Classification Tasks  0.698555        0.0
# 4  downstream_performance_mean  Classification Tasks  0.699217        0.0
#
#    Imputed_Subset  Unnamed: 0              name  MajorityClassSize  \
# 0        0.694867          34  BNG(tic-tac-toe)            25702.0
# 1        0.698074          34  BNG(tic-tac-toe)            25702.0
# 2        0.698074          34  BNG(tic-tac-toe)            25702.0
# 3        0.698555          34  BNG(tic-tac-toe)            25702.0
# 4        0.699217          34  BNG(tic-tac-toe)            25702.0
#
#    MinorityClassSize  NumberOfFeatures  NumberOfInstances  \
# 0            13664.0              10.0            39366.0
# 1            13664.0              10.0            39366.0
# 2            13664.0              10.0            39366.0
# 3            13664.0              10.0            39366.0
# 4            13664.0              10.0            39366.0
#
#    NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses
# 0                      0.0                         10.0              NaN
# 1                      0.0                         10.0              NaN
# 2                      0.0                         10.0              NaN
# 3                      0.0                         10.0              NaN
# 4                      0.0                         10.0              NaN

# %%
# Ranking of downstream performance per data constellation for every imputation method

EXPERIMENTAL_CONDITIONS = ["Task", "Missing Type", "Missing Fraction", "Column", "result_type"]

downstream_results_rank = downstream_results_full_sort.copy()
downstream_results_rank["Downstream Performance Rank Subset"] = downstream_results_rank.groupby(EXPERIMENTAL_CONDITIONS).rank(ascending=False, na_option="bottom", method="first")["Imputed_Subset"]


# create csv for detailled checks
downstream_results_rank.to_csv('downstream_results_binary_complete_overview.csv')
downstream_results_rank.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction             Column  \
# 0  Discriminative DL   137          MAR              0.01  top-middle-square
# 1                KNN   137          MAR              0.01  top-middle-square
# 2      Random Forest   137          MAR              0.01  top-middle-square
# 3               GAIN   137          MAR              0.01  top-middle-square
# 4          Mean/Mode   137          MAR              0.01  top-middle-square
#
#                    result_type                metric  Baseline  Corrupted  \
# 0  downstream_performance_mean  Classification Tasks  0.695789        0.0
# 1  downstream_performance_mean  Classification Tasks  0.698074        0.0
# 2  downstream_performance_mean  Classification Tasks  0.698074        0.0
# 3  downstream_performance_mean  Classification Tasks  0.698555        0.0
# 4  downstream_performance_mean  Classification Tasks  0.699217        0.0
#
#    Imputed_Subset  Unnamed: 0              name  MajorityClassSize  \
# 0        0.694867          34  BNG(tic-tac-toe)            25702.0
# 1        0.698074          34  BNG(tic-tac-toe)            25702.0
# 2        0.698074          34  BNG(tic-tac-toe)            25702.0
# 3        0.698555          34  BNG(tic-tac-toe)            25702.0
# 4        0.699217          34  BNG(tic-tac-toe)            25702.0
#
#    MinorityClassSize  NumberOfFeatures  NumberOfInstances  \
# 0            13664.0              10.0            39366.0
# 1            13664.0              10.0            39366.0
# 2            13664.0              10.0            39366.0
# 3            13664.0              10.0            39366.0
# 4            13664.0              10.0            39366.0
#
#    NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                      0.0                         10.0              NaN
# 1                      0.0                         10.0              NaN
# 2                      0.0                         10.0              NaN
# 3                      0.0                         10.0              NaN
# 4                      0.0                         10.0              NaN
#
#    Downstream Performance Rank Subset
# 0                                 6.0
# 1                                 4.0
# 2                                 5.0
# 3                                 3.0
# 4                                 2.0

# %%
# Adjust column type for Imputation_Method
downstream_results_rank['Imputation_Method'] = downstream_results_rank['Imputation_Method'].astype('object')

#downstream_results_rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2222 entries, 0 to 2221
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Imputation_Method                   2222 non-null   object
#  1   Task                                2222 non-null   int64
#  2   Missing Type                        2222 non-null   object
#  3   Missing Fraction                    2222 non-null   float64
#  4   Column                              2222 non-null   object
#  5   result_type                         2222 non-null   object
#  6   metric                              2222 non-null   object
#  7   Baseline                            2222 non-null   float64
#  8   Corrupted                           2222 non-null   float64
#  9   Imputed_Subset                      2222 non-null   float64
#  10  Unnamed: 0                          2222 non-null   int64
#  11  name                                2222 non-null   object
#  12  MajorityClassSize                   2222 non-null   float64
#  13  MinorityClassSize                   2222 non-null   float64
#  14  NumberOfFeatures                    2222 non-null   float64
#  15  NumberOfInstances                   2222 non-null   float64
#  16  NumberOfNumericFeatures             2222 non-null   float64
#  17  NumberOfCategoricalFeatures         2222 non-null   float64
#  18  NumberOfClasses                     0 non-null      float64
#  19  Downstream Performance Rank Subset  2222 non-null   float64
# dtypes: float64(12), int64(2), object(6)
# memory usage: 364.5+ KB

# %%
# Merge the two columns "Missing Type" and "Missing Fraction" 

downstream_results_rank['Missing Type'] = downstream_results_rank['Missing Type'].astype(str)
downstream_results_rank['Missing Fraction'] = downstream_results_rank['Missing Fraction'].astype(str)
#datatype_new = downstream_results_rank.dtypes

downstream_results_rank['Data_Constellation'] = downstream_results_rank['Missing Type'] + ' - ' + downstream_results_rank['Missing Fraction']
#downstream_results_rank.to_csv('downstream_results_rank_temp.csv')
downstream_results_rank_heatmap2 = downstream_results_rank.copy()
downstream_results_rank
# Out:
#       Imputation_Method   Task Missing Type Missing Fraction  \
# 0     Discriminative DL    137          MAR             0.01
# 1                   KNN    137          MAR             0.01
# 2         Random Forest    137          MAR             0.01
# 3                  GAIN    137          MAR             0.01
# 4             Mean/Mode    137          MAR             0.01
# ...                 ...    ...          ...              ...
# 2217          Mean/Mode  42493         MNAR              0.5
# 2218               GAIN  42493         MNAR              0.5
# 2219      Random Forest  42493         MNAR              0.5
# 2220                KNN  42493         MNAR              0.5
# 2221                VAE  42493         MNAR              0.5
#
#                  Column                  result_type                metric  \
# 0     top-middle-square  downstream_performance_mean  Classification Tasks
# 1     top-middle-square  downstream_performance_mean  Classification Tasks
# 2     top-middle-square  downstream_performance_mean  Classification Tasks
# 3     top-middle-square  downstream_performance_mean  Classification Tasks
# 4     top-middle-square  downstream_performance_mean  Classification Tasks
# ...                 ...                          ...                   ...
# 2217             Length  downstream_performance_mean  Classification Tasks
# 2218             Length  downstream_performance_mean  Classification Tasks
# 2219             Length  downstream_performance_mean  Classification Tasks
# 2220             Length  downstream_performance_mean  Classification Tasks
# 2221             Length  downstream_performance_mean  Classification Tasks
#
#       Baseline  Corrupted  Imputed_Subset  ...              name  \
# 0     0.695789        0.0        0.694867  ...  BNG(tic-tac-toe)
# 1     0.698074        0.0        0.698074  ...  BNG(tic-tac-toe)
# 2     0.698074        0.0        0.698074  ...  BNG(tic-tac-toe)
# 3     0.698555        0.0        0.698555  ...  BNG(tic-tac-toe)
# 4     0.699217        0.0        0.699217  ...  BNG(tic-tac-toe)
# ...        ...        ...             ...  ...               ...
# 2217  0.591024        0.0        0.592436  ...          airlines
# 2218  0.592603        0.0        0.592837  ...          airlines
# 2219  0.594657        0.0        0.595566  ...          airlines
# 2220  0.612391        0.0        0.606716  ...          airlines
# 2221  0.610725        0.0        0.611129  ...          airlines
#
#      MajorityClassSize  MinorityClassSize  NumberOfFeatures  \
# 0              25702.0            13664.0              10.0
# 1              25702.0            13664.0              10.0
# 2              25702.0            13664.0              10.0
# 3              25702.0            13664.0              10.0
# 4              25702.0            13664.0              10.0
# ...                ...                ...               ...
# 2217           14934.0            12035.0               8.0
# 2218           14934.0            12035.0               8.0
# 2219           14934.0            12035.0               8.0
# 2220           14934.0            12035.0               8.0
# 2221           14934.0            12035.0               8.0
#
#       NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0               39366.0                      0.0                         10.0
# 1               39366.0                      0.0                         10.0
# 2               39366.0                      0.0                         10.0
# 3               39366.0                      0.0                         10.0
# 4               39366.0                      0.0                         10.0
# ...                 ...                      ...                          ...
# 2217            26969.0                      2.0                          6.0
# 2218            26969.0                      2.0                          6.0
# 2219            26969.0                      2.0                          6.0
# 2220            26969.0                      2.0                          6.0
# 2221            26969.0                      2.0                          6.0
#
#       NumberOfClasses  Downstream Performance Rank Subset  Data_Constellation
# 0                 NaN                                 6.0          MAR - 0.01
# 1                 NaN                                 4.0          MAR - 0.01
# 2                 NaN                                 5.0          MAR - 0.01
# 3                 NaN                                 3.0          MAR - 0.01
# 4                 NaN                                 2.0          MAR - 0.01
# ...               ...                                 ...                 ...
# 2217              NaN                                 5.0          MNAR - 0.5
# 2218              NaN                                 4.0          MNAR - 0.5
# 2219              NaN                                 3.0          MNAR - 0.5
# 2220              NaN                                 2.0          MNAR - 0.5
# 2221              NaN                                 1.0          MNAR - 0.5
#
# [2222 rows x 21 columns]

# %% [markdown]
# ## Analyzing Performance Based on Rank per Data Constellation

# %%
data = downstream_results_rank.copy()

# Count amount of different Data constellations in column "Data_Constellation"
dc_unique = data.Data_Constellation.unique().size
print(dc_unique, "Data Constellations")
print("_____________________")
# Count amount of 1.0 Ranking result in column "Downstream Performance Rank" (Numbers must match)
rank_count = data['Downstream Performance Rank Subset'].value_counts()
print(rank_count)
print("_____________________")
# Filter for 1.0 Ranking -> Overview -> save as csv
rank_1 = data.loc[data['Downstream Performance Rank Subset'] == 1.0]
rank_1.to_csv('rank_1.csv')

print("_____________________")
# Count how often each Imputation Method is present -> most "wins"
rank_wins = rank_1['Imputation_Method'].value_counts()
print(rank_wins)
print("_____________________")



# BE AWARE THAT THE AVERAGE RANK DOES NOT CONSIDER MISSING RESULTS, WHICH RESULT IN THE WORST RANK BY DEFAULT
# Take initial overview and filter for each imputation method and calculate average rank
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
for i in methods:
    df_average_rank = data.loc[data['Imputation_Method'] == i]
    len_ar = len(df_average_rank)
    print(len_ar, "Amount of results available")
    rank_pos = df_average_rank['Downstream Performance Rank Subset'].value_counts().sort_index(ascending=True)
    print(rank_pos)
    average_rank = df_average_rank["Downstream Performance Rank Subset"].mean()
    print("Average Rank for", i, "is", average_rank)
    #average_improvement = df_average_rank["Imputed"].mean()
    #print("Average Improvement to baseline is", average_improvement)
    print("_____________________")
# Out:
# 12 Data Constellations
# _____________________
# 4.0    372
# 5.0    372
# 3.0    372
# 2.0    372
# 1.0    372
# 6.0    362
# Name: Downstream Performance Rank Subset, dtype: int64
# _____________________
# _____________________
# Mean/Mode            101
# Random Forest         68
# KNN                   66
# Discriminative DL     49
# VAE                   46
# GAIN                  42
# Name: Imputation_Method, dtype: int64
# _____________________
# 372 Amount of results available
# 1.0    68
# 2.0    60
# 3.0    88
# 4.0    52
# 5.0    58
# 6.0    46
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for Random Forest is 3.295698924731183
# _____________________
# 372 Amount of results available
# 1.0    66
# 2.0    88
# 3.0    70
# 4.0    55
# 5.0    53
# 6.0    40
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for KNN is 3.163978494623656
# _____________________
# 372 Amount of results available
# 1.0    101
# 2.0     88
# 3.0     52
# 4.0     56
# 5.0     41
# 6.0     34
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for Mean/Mode is 2.8655913978494625
# _____________________
# 372 Amount of results available
# 1.0    46
# 2.0    51
# 3.0    57
# 4.0    90
# 5.0    67
# 6.0    61
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for VAE is 3.7096774193548385
# _____________________
# 372 Amount of results available
# 1.0    42
# 2.0    39
# 3.0    51
# 4.0    62
# 5.0    95
# 6.0    83
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for GAIN is 4.016129032258065
# _____________________
# 362 Amount of results available
# 1.0    49
# 2.0    46
# 3.0    54
# 4.0    57
# 5.0    58
# 6.0    98
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for Discriminative DL is 3.8922651933701657
# _____________________

# %%
rank_1_backup = rank_1.copy()
rank_1
# Out:
#      Imputation_Method   Task Missing Type Missing Fraction  \
# 5                  VAE    137          MAR             0.01
# 11                 VAE    137          MAR              0.1
# 17                 VAE    137          MAR              0.3
# 23                 KNN    137          MAR              0.5
# 29                 KNN    137         MCAR             0.01
# ...                ...    ...          ...              ...
# 2197     Random Forest  42493         MCAR              0.5
# 2201         Mean/Mode  42493         MNAR             0.01
# 2208         Mean/Mode  42493         MNAR              0.1
# 2215         Mean/Mode  42493         MNAR              0.3
# 2221               VAE  42493         MNAR              0.5
#
#                  Column                  result_type                metric  \
# 5     top-middle-square  downstream_performance_mean  Classification Tasks
# 11    top-middle-square  downstream_performance_mean  Classification Tasks
# 17    top-middle-square  downstream_performance_mean  Classification Tasks
# 23    top-middle-square  downstream_performance_mean  Classification Tasks
# 29    top-middle-square  downstream_performance_mean  Classification Tasks
# ...                 ...                          ...                   ...
# 2197             Length  downstream_performance_mean  Classification Tasks
# 2201             Length  downstream_performance_mean  Classification Tasks
# 2208             Length  downstream_performance_mean  Classification Tasks
# 2215             Length  downstream_performance_mean  Classification Tasks
# 2221             Length  downstream_performance_mean  Classification Tasks
#
#       Baseline  Corrupted  Imputed_Subset  ...              name  \
# 5     0.699699        0.0        0.699699  ...  BNG(tic-tac-toe)
# 11    0.700844        0.0        0.700844  ...  BNG(tic-tac-toe)
# 17    0.702163        0.0        0.700799  ...  BNG(tic-tac-toe)
# 23    0.705702        0.0        0.706240  ...  BNG(tic-tac-toe)
# 29    0.699217        0.0        0.699217  ...  BNG(tic-tac-toe)
# ...        ...        ...             ...  ...               ...
# 2197  0.606068        0.0        0.606759  ...          airlines
# 2201  0.614237        0.0        0.614237  ...          airlines
# 2208  0.612068        0.0        0.614235  ...          airlines
# 2215  0.598213        0.0        0.600125  ...          airlines
# 2221  0.610725        0.0        0.611129  ...          airlines
#
#      MajorityClassSize  MinorityClassSize  NumberOfFeatures  \
# 5              25702.0            13664.0              10.0
# 11             25702.0            13664.0              10.0
# 17             25702.0            13664.0              10.0
# 23             25702.0            13664.0              10.0
# 29             25702.0            13664.0              10.0
# ...                ...                ...               ...
# 2197           14934.0            12035.0               8.0
# 2201           14934.0            12035.0               8.0
# 2208           14934.0            12035.0               8.0
# 2215           14934.0            12035.0               8.0
# 2221           14934.0            12035.0               8.0
#
#       NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 5               39366.0                      0.0                         10.0
# 11              39366.0                      0.0                         10.0
# 17              39366.0                      0.0                         10.0
# 23              39366.0                      0.0                         10.0
# 29              39366.0                      0.0                         10.0
# ...                 ...                      ...                          ...
# 2197            26969.0                      2.0                          6.0
# 2201            26969.0                      2.0                          6.0
# 2208            26969.0                      2.0                          6.0
# 2215            26969.0                      2.0                          6.0
# 2221            26969.0                      2.0                          6.0
#
#       NumberOfClasses  Downstream Performance Rank Subset  Data_Constellation
# 5                 NaN                                 1.0          MAR - 0.01
# 11                NaN                                 1.0           MAR - 0.1
# 17                NaN                                 1.0           MAR - 0.3
# 23                NaN                                 1.0           MAR - 0.5
# 29                NaN                                 1.0         MCAR - 0.01
# ...               ...                                 ...                 ...
# 2197              NaN                                 1.0          MCAR - 0.5
# 2201              NaN                                 1.0         MNAR - 0.01
# 2208              NaN                                 1.0          MNAR - 0.1
# 2215              NaN                                 1.0          MNAR - 0.3
# 2221              NaN                                 1.0          MNAR - 0.5
#
# [372 rows x 21 columns]

# %% [markdown]
# ## Set Average Best Imputation Method Manually

# %%
# SET AVERAGE BEST IMPUTATION METHOD HERE, BASED ON THE PREVIOUS RESULTS
# Alternatively you can define a baseline method here, which will be used instead, depending on your analysis goals

AVERAGE_BEST_IMPUTATION_METHOD = 'Mean/Mode'

# %% [markdown]
# ## Differences in Performance Relative to Average Best Imputation Method

# %%
av_best = data.loc[data['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
av_best['Task'] = av_best['Task'].astype(str)
av_best['Data_Constellation'] = av_best['Data_Constellation'] + ' - ' + av_best['Task']

av_best = av_best.rename(columns={'Imputation_Method':'Imputation_Method_average', 
                               'Imputed_Subset':'Imputed_average_Subset',
                                 'Downstream Performance Rank Subset':'Downstream Performance Rank Average Subset'})


rank_1['Task'] = rank_1['Task'].astype(str)
rank_1['Data_Constellation'] = rank_1['Data_Constellation'] + ' - ' + rank_1['Task']
rank_1 = rank_1[['Imputation_Method', 'Imputed_Subset', 'Data_Constellation', 'Downstream Performance Rank Subset']]
rank_1 = rank_1.rename(columns={'Imputation_Method':'Imputation_Method_best', 
                               'Imputed_Subset':'Imputed_best_Subset',
                               'Downstream Performance Rank Subset':'Downstream Performance Rank Best Subset'})

performance_difference = pd.merge(av_best, rank_1, on='Data_Constellation')
#performance_difference.head()
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\1434691341.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\1434691341.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\1434691341.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\1434691341.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Calculate the difference between the best imputation method for each data constellation to the average best imputation method in F1 score
performance_difference['Performance Difference Best to Average'] = performance_difference['Imputed_best_Subset'] - performance_difference['Imputed_average_Subset']
Average_Difference = performance_difference['Performance Difference Best to Average'].mean()
print("Average Difference in Improvement from best method to average best method for F1", Average_Difference)
# Out:
# Average Difference in Improvement from best method to average best method for F1 0.017610637359559676

# %%
performance_difference.to_csv('performance_difference.csv')
performance_difference.head()
# Out:
#   Imputation_Method_average Task Missing Type Missing Fraction  \
# 0                 Mean/Mode  137          MAR             0.01
# 1                 Mean/Mode  137          MAR              0.1
# 2                 Mean/Mode  137          MAR              0.3
# 3                 Mean/Mode  137          MAR              0.5
# 4                 Mean/Mode  137         MCAR             0.01
#
#               Column                  result_type                metric  \
# 0  top-middle-square  downstream_performance_mean  Classification Tasks
# 1  top-middle-square  downstream_performance_mean  Classification Tasks
# 2  top-middle-square  downstream_performance_mean  Classification Tasks
# 3  top-middle-square  downstream_performance_mean  Classification Tasks
# 4  top-middle-square  downstream_performance_mean  Classification Tasks
#
#    Baseline  Corrupted  Imputed_average_Subset  ...  NumberOfInstances  \
# 0  0.699217        0.0                0.699217  ...            39366.0
# 1  0.697587        0.0                0.697368  ...            39366.0
# 2  0.695953        0.0                0.697526  ...            39366.0
# 3  0.697094        0.0                0.697475  ...            39366.0
# 4  0.698074        0.0                0.698074  ...            39366.0
#
#   NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                     0.0                         10.0              NaN
# 1                     0.0                         10.0              NaN
# 2                     0.0                         10.0              NaN
# 3                     0.0                         10.0              NaN
# 4                     0.0                         10.0              NaN
#
#    Downstream Performance Rank Average Subset  Data_Constellation  \
# 0                                         2.0    MAR - 0.01 - 137
# 1                                         5.0     MAR - 0.1 - 137
# 2                                         5.0     MAR - 0.3 - 137
# 3                                         4.0     MAR - 0.5 - 137
# 4                                         2.0   MCAR - 0.01 - 137
#
#    Imputation_Method_best  Imputed_best_Subset  \
# 0                     VAE             0.699699
# 1                     VAE             0.700844
# 2                     VAE             0.700799
# 3                     KNN             0.706240
# 4                     KNN             0.699217
#
#    Downstream Performance Rank Best Subset  \
# 0                                      1.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
#
#    Performance Difference Best to Average
# 0                                0.000482
# 1                                0.003475
# 2                                0.003273
# 3                                0.008765
# 4                                0.001143
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Analysis and Ranking based on F1 Score

# %%
# Relative Difference in Percent -> Best Method to Average Best Method

data = downstream_results_rank.copy()
data['Task'] = data['Task'].astype(str)
data['Data_Constellation_full'] = data['Data_Constellation'] + ' - ' + data['Task']


dc_unique = data.Data_Constellation_full.unique()

data_constellations = dc_unique.tolist()
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
average_best_complete = pd.DataFrame()


for i in data_constellations:
    data_constel = data.loc[data['Data_Constellation_full'] == i]
    best_score = data_constel.loc[data_constel['Downstream Performance Rank Subset'] == 1.0]
    average_best = data_constel.loc[data_constel['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
    dataset_number = best_score.iloc[0]['Task']

    if (dataset_number != '4135'):
        best_score_int = best_score.iloc[0]['Imputed_Subset']
        average_best_int = average_best.iloc[0]['Imputed_Subset']

        calc_result = ((best_score_int - average_best_int)/average_best_int)
        average_best['Performance Difference to Best to Average in Percent'] = calc_result
        average_best_complete = average_best_complete.append(average_best)  
    else:
        print("4135 else ---------------------")

average_best_complete
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# ...
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\915740057.py:27: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#      Imputation_Method   Task Missing Type Missing Fraction  \
# 4            Mean/Mode    137          MAR             0.01
# 7            Mean/Mode    137          MAR              0.1
# 13           Mean/Mode    137          MAR              0.3
# 20           Mean/Mode    137          MAR              0.5
# 27           Mean/Mode    137         MCAR             0.01
# ...                ...    ...          ...              ...
# 2196         Mean/Mode  42493         MCAR              0.5
# 2201         Mean/Mode  42493         MNAR             0.01
# 2208         Mean/Mode  42493         MNAR              0.1
# 2215         Mean/Mode  42493         MNAR              0.3
# 2217         Mean/Mode  42493         MNAR              0.5
#
#                  Column                  result_type                metric  \
# 4     top-middle-square  downstream_performance_mean  Classification Tasks
# 7     top-middle-square  downstream_performance_mean  Classification Tasks
# 13    top-middle-square  downstream_performance_mean  Classification Tasks
# 20    top-middle-square  downstream_performance_mean  Classification Tasks
# 27    top-middle-square  downstream_performance_mean  Classification Tasks
# ...                 ...                          ...                   ...
# 2196             Length  downstream_performance_mean  Classification Tasks
# 2201             Length  downstream_performance_mean  Classification Tasks
# 2208             Length  downstream_performance_mean  Classification Tasks
# 2215             Length  downstream_performance_mean  Classification Tasks
# 2217             Length  downstream_performance_mean  Classification Tasks
#
#       Baseline  Corrupted  Imputed_Subset  ...  MinorityClassSize  \
# 4     0.699217        0.0        0.699217  ...            13664.0
# 7     0.697587        0.0        0.697368  ...            13664.0
# 13    0.695953        0.0        0.697526  ...            13664.0
# 20    0.697094        0.0        0.697475  ...            13664.0
# 27    0.698074        0.0        0.698074  ...            13664.0
# ...        ...        ...             ...  ...                ...
# 2196  0.599894        0.0        0.600162  ...            12035.0
# 2201  0.614237        0.0        0.614237  ...            12035.0
# 2208  0.612068        0.0        0.614235  ...            12035.0
# 2215  0.598213        0.0        0.600125  ...            12035.0
# 2217  0.591024        0.0        0.592436  ...            12035.0
#
#      NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 4                10.0            39366.0                      0.0
# 7                10.0            39366.0                      0.0
# 13               10.0            39366.0                      0.0
# 20               10.0            39366.0                      0.0
# 27               10.0            39366.0                      0.0
# ...               ...                ...                      ...
# 2196              8.0            26969.0                      2.0
# 2201              8.0            26969.0                      2.0
# 2208              8.0            26969.0                      2.0
# 2215              8.0            26969.0                      2.0
# 2217              8.0            26969.0                      2.0
#
#       NumberOfCategoricalFeatures  NumberOfClasses  \
# 4                            10.0              NaN
# 7                            10.0              NaN
# 13                           10.0              NaN
# 20                           10.0              NaN
# 27                           10.0              NaN
# ...                           ...              ...
# 2196                          6.0              NaN
# 2201                          6.0              NaN
# 2208                          6.0              NaN
# 2215                          6.0              NaN
# 2217                          6.0              NaN
#
#       Downstream Performance Rank Subset  Data_Constellation  \
# 4                                    2.0          MAR - 0.01
# 7                                    5.0           MAR - 0.1
# 13                                   5.0           MAR - 0.3
# 20                                   4.0           MAR - 0.5
# 27                                   2.0         MCAR - 0.01
# ...                                  ...                 ...
# 2196                                 2.0          MCAR - 0.5
# 2201                                 1.0         MNAR - 0.01
# 2208                                 1.0          MNAR - 0.1
# 2215                                 1.0          MNAR - 0.3
# 2217                                 5.0          MNAR - 0.5
#
#       Data_Constellation_full  \
# 4            MAR - 0.01 - 137
# 7             MAR - 0.1 - 137
# 13            MAR - 0.3 - 137
# 20            MAR - 0.5 - 137
# 27          MCAR - 0.01 - 137
# ...                       ...
# 2196       MCAR - 0.5 - 42493
# 2201      MNAR - 0.01 - 42493
# 2208       MNAR - 0.1 - 42493
# 2215       MNAR - 0.3 - 42493
# 2217       MNAR - 0.5 - 42493
#
#       Performance Difference to Best to Average in Percent
# 4                                              0.000689
# 7                                              0.004983
# 13                                             0.004693
# 20                                             0.012567
# 27                                             0.001638
# ...                                                 ...
# 2196                                           0.010993
# 2201                                           0.000000
# 2208                                           0.000000
# 2215                                           0.000000
# 2217                                           0.031553
#
# [360 rows x 23 columns]

# %%
#Difference in Percentage
average_difference = average_best_complete['Performance Difference to Best to Average in Percent'].mean()
print(average_difference, "average difference in Percent")
# Out:
# 0.02865669221543993 average difference in Percent

# %% [markdown]
# ## Heatmap to Show Detailled Performance of Each Imputation Method for Each Data Constellation

# %%
df_heat = downstream_results_rank.copy()
df_heat.drop(["Missing Type", "Missing Fraction", "Column", "result_type", "metric", "Baseline", "Corrupted", "Unnamed: 0", "Unnamed: 0", "name", "NumberOfClasses", "MajorityClassSize", "MinorityClassSize"], axis=1, inplace=True)
df_heat
# Out:
#       Imputation_Method   Task  Imputed_Subset  NumberOfFeatures  \
# 0     Discriminative DL    137        0.694867              10.0
# 1                   KNN    137        0.698074              10.0
# 2         Random Forest    137        0.698074              10.0
# 3                  GAIN    137        0.698555              10.0
# 4             Mean/Mode    137        0.699217              10.0
# ...                 ...    ...             ...               ...
# 2217          Mean/Mode  42493        0.592436               8.0
# 2218               GAIN  42493        0.592837               8.0
# 2219      Random Forest  42493        0.595566               8.0
# 2220                KNN  42493        0.606716               8.0
# 2221                VAE  42493        0.611129               8.0
#
#       NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0               39366.0                      0.0                         10.0
# 1               39366.0                      0.0                         10.0
# 2               39366.0                      0.0                         10.0
# 3               39366.0                      0.0                         10.0
# 4               39366.0                      0.0                         10.0
# ...                 ...                      ...                          ...
# 2217            26969.0                      2.0                          6.0
# 2218            26969.0                      2.0                          6.0
# 2219            26969.0                      2.0                          6.0
# 2220            26969.0                      2.0                          6.0
# 2221            26969.0                      2.0                          6.0
#
#       Downstream Performance Rank Subset Data_Constellation
# 0                                    6.0         MAR - 0.01
# 1                                    4.0         MAR - 0.01
# 2                                    5.0         MAR - 0.01
# 3                                    3.0         MAR - 0.01
# 4                                    2.0         MAR - 0.01
# ...                                  ...                ...
# 2217                                 5.0         MNAR - 0.5
# 2218                                 4.0         MNAR - 0.5
# 2219                                 3.0         MNAR - 0.5
# 2220                                 2.0         MNAR - 0.5
# 2221                                 1.0         MNAR - 0.5
#
# [2222 rows x 9 columns]

# %%
# Heatmap for total F1 score for each data constellation for each method

df_heat = df_heat.astype({"Task":"string"})

data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MCAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']


for i in data_constellations:
    data_constel = df_heat.loc[df_heat['Data_Constellation'] == i]

    ### uncomment whatever you want to investigate

    ## sort by amount datapoints (ascending)
    data_constel = data_constel.sort_values(by=['NumberOfInstances'])

    ## sort by amount of features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfFeatures'])

    ## sort by amount of datapoints and features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances', 'NumberOfFeatures'])

    ## sort by amount of categorical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfCategoricalFeatures', 'NumberOfInstances'])

    ## sort by amount of numerical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfNumericFeatures', 'NumberOfInstances'])
    
    Dataset_number = data_constel["Task"]
    Imputation_Method = data_constel["Imputation_Method"]
    F1_Score = data_constel["Imputed_Subset"]
    

    trace = go.Heatmap(
                   z=F1_Score,
                   x=Dataset_number,
                   y=Imputation_Method,
                   type = 'heatmap',
                    autocolorscale= False,
                    colorscale = 'Reds',
                    zmin=0,
                    )
    data = [trace]
    fig = go.Figure(data=data)
    fig.update_layout(
        title=i,
        xaxis_nticks=36)
    fig.show()
# Out:
# <div>                            <div id="d07e6ee2-a62a-4781-8d00-614043fe35fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d07e6ee2-a62a-4781-8d00-614043fe35fb")) {                    Plotly.newPlot(                        "d07e6ee2-a62a-4781-8d00-614043fe35fb",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","Discriminative DL","VAE","GAIN","Mean/Mode","Random Forest","KNN","VAE","GAIN","Mean/Mode","Random Forest","Discriminative DL","KNN","Mean/Mode","Random Forest","KNN","Discriminative DL","VAE","GAIN","Mean/Mode","GAIN","Random Forest","Discriminative DL","VAE","KNN","Mean/Mode","GAIN","KNN","Discriminative DL","VAE","Random Forest","Discriminative DL","GAIN","Mean/Mode","KNN","VAE","Random Forest","Mean/Mode","Discriminative DL","VAE","KNN","Random Forest","GAIN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","VAE","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Mean/Mode","KNN","GAIN","Random Forest","VAE","Mean/Mode","KNN","KNN","Random Forest","VAE","GAIN","Discriminative DL","GAIN","Discriminative DL","Mean/Mode","VAE","Random Forest","Mean/Mode","Discriminative DL","VAE","KNN","GAIN","Random Forest","Mean/Mode","Discriminative DL","VAE","GAIN","KNN","Random Forest","Discriminative DL","VAE","Random Forest","KNN","Mean/Mode","GAIN","Mean/Mode","KNN","Random Forest","GAIN","Discriminative DL","VAE","Discriminative DL","GAIN","VAE","Random Forest","KNN","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","Random Forest","GAIN","VAE","KNN","Mean/Mode","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Mean/Mode","Random Forest","VAE","Discriminative DL","GAIN","KNN","Mean/Mode","Discriminative DL","VAE","Random Forest","GAIN","KNN","KNN","Mean/Mode","VAE","Random Forest","GAIN","Discriminative DL","Discriminative DL","Mean/Mode","GAIN","Random Forest","KNN","VAE","Random Forest","VAE","Mean/Mode","GAIN","Discriminative DL","KNN","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","KNN","Mean/Mode","KNN","Random Forest","GAIN","VAE","Discriminative DL","VAE","GAIN","KNN","Mean/Mode","Discriminative DL","Random Forest","Discrimina ...
# <div>                            <div id="bb855935-4792-4af6-8fc9-5e98253881f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb855935-4792-4af6-8fc9-5e98253881f4")) {                    Plotly.newPlot(                        "bb855935-4792-4af6-8fc9-5e98253881f4",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["Mean/Mode","Discriminative DL","Random Forest","GAIN","KNN","VAE","Discriminative DL","Random Forest","KNN","GAIN","Mean/Mode","VAE","Mean/Mode","GAIN","VAE","Random Forest","Discriminative DL","KNN","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","GAIN","Mean/Mode","Random Forest","VAE","Discriminative DL","KNN","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","Random Forest","GAIN","Mean/Mode","VAE","KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","GAIN","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","KNN","GAIN","KNN","Random Forest","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","VAE","Random Forest","KNN","VAE","GAIN","Mean/Mode","Discriminative DL","Random Forest","GAIN","Mean/Mode","VAE","KNN","Discriminative DL","Random Forest","Discriminative DL","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","KNN","Random Forest","VAE","Mean/Mode","GAIN","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","VAE","Random Forest","Mean/Mode","KNN","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","GAIN","Discriminative DL","GAIN","Discriminative DL","Mean/Mode","Random Forest","VAE","KNN","KNN","Random Forest","VAE","Discriminative DL","Mean/Mode","GAIN","Random Forest","VAE","KNN","GAIN","Discriminative DL","Mean/Mode","VAE","Random Forest","KNN","Mean/Mode","GAIN","Random Forest","Discriminative DL","KNN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","VAE","GAIN","Mean/Mode","KNN","Discriminative DL","GAIN","Random Forest","Mean/Mode","Discriminative DL","VAE","KNN","VAE","Discriminative DL","Mean/Mode","KNN","Random Forest","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","GAIN"," ...
# <div>                            <div id="4f9835fe-fb1f-4c4e-8b21-528c5fd1cb93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f9835fe-fb1f-4c4e-8b21-528c5fd1cb93")) {                    Plotly.newPlot(                        "4f9835fe-fb1f-4c4e-8b21-528c5fd1cb93",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["GAIN","Discriminative DL","Random Forest","Mean/Mode","VAE","KNN","VAE","KNN","GAIN","Mean/Mode","Discriminative DL","Random Forest","Mean/Mode","Discriminative DL","GAIN","Random Forest","VAE","KNN","Mean/Mode","GAIN","KNN","Discriminative DL","Random Forest","VAE","GAIN","KNN","Discriminative DL","Mean/Mode","VAE","Random Forest","VAE","Mean/Mode","KNN","Random Forest","Discriminative DL","GAIN","KNN","GAIN","Discriminative DL","Random Forest","Mean/Mode","VAE","Discriminative DL","VAE","KNN","Random Forest","Mean/Mode","GAIN","Mean/Mode","GAIN","KNN","Random Forest","Discriminative DL","VAE","KNN","Random Forest","Discriminative DL","VAE","Mean/Mode","GAIN","VAE","GAIN","Mean/Mode","Discriminative DL","KNN","Random Forest","GAIN","Random Forest","VAE","Random Forest","Mean/Mode","KNN","KNN","Mean/Mode","Discriminative DL","GAIN","VAE","Discriminative DL","Random Forest","VAE","Mean/Mode","KNN","GAIN","Discriminative DL","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","Random Forest","Random Forest","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","VAE","Random Forest","GAIN","KNN","Mean/Mode","Discriminative DL","Discriminative DL","KNN","GAIN","VAE","Random Forest","Mean/Mode","Random Forest","Discriminative DL","Mean/Mode","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","VAE","GAIN","KNN","GAIN","Discriminative DL","Mean/Mode","Random Forest","KNN","VAE","KNN","Random Forest","VAE","Mean/Mode","GAIN","Discriminative DL","VAE","Discriminative DL","GAIN","KNN","Mean/Mode","Random Forest","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","GAIN","GAIN","KNN","Discriminative DL","Random Forest","Mean/Mode","VAE","Mean/Mode","VAE","KNN","Discriminative DL","Random Forest","GAIN","GAIN","Mean/Mode","Discriminative DL","KNN","VAE","Random Forest","Random Forest","KNN","GAIN","VAE","Mean/Mode","Discriminative DL","VAE","KNN","Mean/Mode","Discriminative DL","GAIN"," ...
# <div>                            <div id="89beca01-fbdb-4060-9ed6-b9aa2a90ddd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89beca01-fbdb-4060-9ed6-b9aa2a90ddd2")) {                    Plotly.newPlot(                        "89beca01-fbdb-4060-9ed6-b9aa2a90ddd2",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["Mean/Mode","KNN","VAE","Discriminative DL","Random Forest","GAIN","GAIN","Discriminative DL","KNN","Random Forest","VAE","Mean/Mode","KNN","GAIN","VAE","Random Forest","Discriminative DL","Mean/Mode","Random Forest","Mean/Mode","VAE","Discriminative DL","GAIN","KNN","Random Forest","KNN","GAIN","Discriminative DL","VAE","Mean/Mode","Discriminative DL","GAIN","KNN","Random Forest","VAE","Mean/Mode","VAE","Mean/Mode","Discriminative DL","GAIN","KNN","Random Forest","Random Forest","Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Discriminative DL","Random Forest","KNN","VAE","GAIN","Mean/Mode","GAIN","KNN","VAE","Discriminative DL","Mean/Mode","Random Forest","VAE","Discriminative DL","KNN","GAIN","Random Forest","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","VAE","GAIN","KNN","Random Forest","Mean/Mode","GAIN","KNN","VAE","Discriminative DL","Random Forest","Discriminative DL","Random Forest","GAIN","KNN","VAE","Mean/Mode","VAE","KNN","Random Forest","GAIN","Mean/Mode","Mean/Mode","KNN","Random Forest","Discriminative DL","VAE","GAIN","KNN","Random Forest","Discriminative DL","VAE","GAIN","Mean/Mode","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","KNN","VAE","Mean/Mode","Random Forest","KNN","GAIN","VAE","Discriminative DL","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","Random Forest","GAIN","KNN","Mean/Mode","Discriminative DL","KNN","Mean/Mode","Discriminative DL","GAIN","VAE","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","GAIN","Random Forest","Mean/Mode","KNN","VAE","Discriminative DL","Discriminat ...
# <div>                            <div id="eb70d043-53d1-4eae-96b1-c5088f3efd68" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb70d043-53d1-4eae-96b1-c5088f3efd68")) {                    Plotly.newPlot(                        "eb70d043-53d1-4eae-96b1-c5088f3efd68",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["Mean/Mode","GAIN","Random Forest","KNN","VAE","Discriminative DL","Random Forest","VAE","KNN","GAIN","Discriminative DL","Mean/Mode","Mean/Mode","GAIN","VAE","Random Forest","Discriminative DL","KNN","KNN","Random Forest","VAE","Discriminative DL","GAIN","Mean/Mode","GAIN","KNN","Discriminative DL","Mean/Mode","VAE","Random Forest","VAE","KNN","Discriminative DL","Random Forest","Mean/Mode","GAIN","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","Mean/Mode","Discriminative DL","Random Forest","GAIN","KNN","VAE","GAIN","Mean/Mode","VAE","KNN","Discriminative DL","Random Forest","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Mean/Mode","Random Forest","VAE","KNN","GAIN","Discriminative DL","Mean/Mode","KNN","GAIN","KNN","Random Forest","VAE","Discriminative DL","GAIN","Discriminative DL","Mean/Mode","VAE","Random Forest","Random Forest","GAIN","KNN","Mean/Mode","Discriminative DL","VAE","Random Forest","VAE","GAIN","Mean/Mode","Discriminative DL","KNN","KNN","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","KNN","Random Forest","GAIN","Mean/Mode","VAE","Discriminative DL","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Random Forest","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","Discriminative DL","Mean/Mode","VAE","Random Forest","KNN","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","Random Forest","GAIN","Mean/Mode","Random Forest","VAE","GAIN","Discriminative DL","KNN","Random Forest","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","Mean/Mode","Random Forest","KNN","VAE","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","GAIN","Discriminative DL","KNN","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","GAIN","Mean/Mode","Discriminative DL","KNN","VAE","Random Forest","Mean/Mode","KNN","Random Forest","VAE","GAIN","Discriminative DL","VAE","Random Forest","GAIN","Discriminative DL","KN ...
# <div>                            <div id="7a256a14-fbd4-4d4a-9bc3-a1e88714d7c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a256a14-fbd4-4d4a-9bc3-a1e88714d7c3")) {                    Plotly.newPlot(                        "7a256a14-fbd4-4d4a-9bc3-a1e88714d7c3",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","GAIN","Mean/Mode","GAIN","Discriminative DL","KNN","Random Forest","VAE","KNN","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","VAE","GAIN","Discriminative DL","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","KNN","VAE","Random Forest","GAIN","GAIN","VAE","Mean/Mode","Random Forest","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","KNN","Discriminative DL","GAIN","VAE","Random Forest","Mean/Mode","VAE","KNN","Discriminative DL","GAIN","Random Forest","GAIN","KNN","VAE","Mean/Mode","VAE","Discriminative DL","Mean/Mode","GAIN","KNN","Random Forest","KNN","Random Forest","KNN","Random Forest","VAE","Mean/Mode","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Mean/Mode","VAE","KNN","Discriminative DL","GAIN","GAIN","Mean/Mode","VAE","Discriminative DL","KNN","Random Forest","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","VAE","Mean/Mode","Random Forest","GAIN","KNN","Discriminative DL","VAE","GAIN","KNN","Random Forest","Mean/Mode","VAE","KNN","Discriminative DL","Random Forest","VAE","Mean/Mode","GAIN","Mean/Mode","VAE","GAIN","KNN","Random Forest","Discriminative DL","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Mean/Mode","Random Forest","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","VAE","Discriminative DL","KNN","Random Forest","GAIN","Mean/Mode","GAIN","Discriminative DL","VAE","Random Forest","VAE","KNN","Random Forest","Mean/Mode","KNN","GAIN","Discriminative DL","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","GAIN","Discriminative DL","Random Forest","KNN","VAE","Mean/Mode","Mean/Mode","Random Forest","VAE","GAIN","Discriminative DL","KNN","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","KNN","Random Forest","Discriminative  ...
# <div>                            <div id="1d2a1ec0-ea34-4735-af58-d4a2f335431e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d2a1ec0-ea34-4735-af58-d4a2f335431e")) {                    Plotly.newPlot(                        "1d2a1ec0-ea34-4735-af58-d4a2f335431e",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["Random Forest","Mean/Mode","VAE","Discriminative DL","GAIN","KNN","KNN","GAIN","Random Forest","Mean/Mode","VAE","Discriminative DL","Discriminative DL","VAE","Random Forest","KNN","GAIN","Mean/Mode","GAIN","VAE","Random Forest","Discriminative DL","Mean/Mode","KNN","Mean/Mode","Discriminative DL","Random Forest","GAIN","VAE","KNN","VAE","Mean/Mode","GAIN","Random Forest","KNN","Discriminative DL","VAE","Discriminative DL","Mean/Mode","KNN","Random Forest","GAIN","GAIN","Mean/Mode","Discriminative DL","VAE","Random Forest","KNN","GAIN","Discriminative DL","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","KNN","VAE","Random Forest","Mean/Mode","GAIN","VAE","Discriminative DL","KNN","GAIN","Mean/Mode","Random Forest","Random Forest","KNN","Discriminative DL","Random Forest","GAIN","KNN","GAIN","Discriminative DL","Mean/Mode","VAE","VAE","Mean/Mode","Mean/Mode","Random Forest","KNN","Discriminative DL","GAIN","VAE","GAIN","Discriminative DL","VAE","Mean/Mode","Random Forest","KNN","GAIN","Mean/Mode","Random Forest","KNN","Discriminative DL","VAE","Random Forest","KNN","VAE","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","Discriminative DL","Mean/Mode","GAIN","VAE","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","GAIN","Mean/Mode","Random Forest","Discriminative DL","KNN","VAE","GAIN","GAIN","Discriminative DL","Random Forest","VAE","KNN","Mean/Mode","KNN","Mean/Mode","Random Forest","GAIN","Discriminative DL","VAE","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","Random Forest","Random Forest","Mean/Mode","GAIN","VAE","KNN","GAIN","Discriminative DL","Random Forest","VAE","KNN","Mean/Mode","Discriminative DL","KNN","GAIN","Mean/Mode","VAE","Discriminative DL","Random Forest","GAIN","Random Forest","Mean/Mode","VAE","KNN","Discriminative DL","Random Forest","GAIN","KNN","VAE","Discriminative DL","Mean/Mode","VAE","Random Forest","Mean/Mode","Discriminative DL ...
# <div>                            <div id="32bd48cf-3057-4a67-ba9b-17a3f5c68d4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32bd48cf-3057-4a67-ba9b-17a3f5c68d4d")) {                    Plotly.newPlot(                        "32bd48cf-3057-4a67-ba9b-17a3f5c68d4d",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["Mean/Mode","KNN","VAE","Discriminative DL","Random Forest","GAIN","GAIN","Discriminative DL","KNN","Random Forest","VAE","Mean/Mode","KNN","GAIN","VAE","Random Forest","Discriminative DL","Mean/Mode","Random Forest","Mean/Mode","VAE","Discriminative DL","GAIN","KNN","Random Forest","KNN","GAIN","Discriminative DL","VAE","Mean/Mode","Discriminative DL","GAIN","KNN","Random Forest","VAE","Mean/Mode","VAE","Mean/Mode","Discriminative DL","GAIN","KNN","Random Forest","Random Forest","Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Discriminative DL","Random Forest","KNN","VAE","GAIN","Mean/Mode","GAIN","KNN","VAE","Discriminative DL","Mean/Mode","Random Forest","VAE","Discriminative DL","KNN","GAIN","Random Forest","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","VAE","GAIN","KNN","Random Forest","Mean/Mode","GAIN","KNN","VAE","Discriminative DL","Random Forest","Discriminative DL","Random Forest","GAIN","KNN","VAE","Mean/Mode","VAE","KNN","Random Forest","GAIN","Mean/Mode","Mean/Mode","KNN","Random Forest","Discriminative DL","VAE","GAIN","KNN","Random Forest","Discriminative DL","VAE","GAIN","Mean/Mode","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","Mean/Mode","Discriminative DL","VAE","GAIN","Random Forest","KNN","VAE","Mean/Mode","Random Forest","KNN","GAIN","VAE","Discriminative DL","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","Random Forest","GAIN","KNN","Mean/Mode","Discriminative DL","KNN","Mean/Mode","Discriminative DL","GAIN","VAE","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","GAIN","Random Forest","Mean/Mode","KNN","VAE","Discriminative DL","Discriminat ...
# <div>                            <div id="8b8c1a4b-1e4b-4a7d-8508-3fa95c0ca5a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b8c1a4b-1e4b-4a7d-8508-3fa95c0ca5a3")) {                    Plotly.newPlot(                        "8b8c1a4b-1e4b-4a7d-8508-3fa95c0ca5a3",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1496","1496","1507","1496","1496","1496","1496","1507","1507","1507","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","901","901","901","901","901","881","901","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["Discriminative DL","Random Forest","KNN","VAE","GAIN","Mean/Mode","Discriminative DL","Random Forest","GAIN","Mean/Mode","VAE","KNN","Mean/Mode","GAIN","VAE","Random Forest","Discriminative DL","KNN","KNN","Random Forest","VAE","Discriminative DL","GAIN","Mean/Mode","KNN","Mean/Mode","GAIN","Discriminative DL","VAE","Random Forest","Discriminative DL","KNN","GAIN","Mean/Mode","VAE","Random Forest","GAIN","VAE","Mean/Mode","KNN","Random Forest","VAE","GAIN","KNN","Discriminative DL","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Mean/Mode","Random Forest","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Discriminative DL","Mean/Mode","Mean/Mode","KNN","Random Forest","VAE","Discriminative DL","GAIN","KNN","VAE","Random Forest","GAIN","KNN","Mean/Mode","Random Forest","VAE","Discriminative DL","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","Random Forest","Discriminative DL","GAIN","VAE","KNN","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","Discriminative DL","Mean/Mode","VAE","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","KNN","KNN","Discriminative DL","Mean/Mode","VAE","Random Forest","GAIN","Mean/Mode","VAE","Discriminative DL","KNN","GAIN","Random Forest","Random Forest","VAE","GAIN","Mean/Mode","Discriminative DL","KNN","Mean/Mode","Random Forest","VAE","GAIN","Discriminative DL","KNN","VAE","KNN","Mean/Mode","GAIN","Discriminative DL","Random Forest","Mean/Mode","Discriminative DL","KNN","Random Forest","VAE","Random Forest","GAIN","Mean/Mode","GAIN","VAE","Discriminative DL","KNN","KNN","VAE","Random Forest","GAIN","Mean/Mode","VAE","Discriminative DL","Mean/Mode","KNN","GAIN","Discriminative DL","Random Forest","Mean/Mode","KNN","Random Forest","VAE","GAIN","VAE","Discriminative DL","Mean/Mode","KNN","GAIN","Random Forest","Random Forest","KNN","GAIN","Mean/Mode" ...
# <div>                            <div id="0cf22eed-450b-4823-9a95-36bea19375ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cf22eed-450b-4823-9a95-36bea19375ea")) {                    Plotly.newPlot(                        "0cf22eed-450b-4823-9a95-36bea19375ea",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["VAE","Discriminative DL","GAIN","KNN","Mean/Mode","Random Forest","VAE","Mean/Mode","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","GAIN","Random Forest","GAIN","Mean/Mode","Discriminative DL","KNN","VAE","VAE","KNN","Discriminative DL","Mean/Mode","GAIN","Random Forest","VAE","GAIN","KNN","Discriminative DL","Random Forest","Mean/Mode","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","GAIN","Random Forest","Discriminative DL","Mean/Mode","KNN","VAE","Random Forest","Discriminative DL","VAE","KNN","Mean/Mode","GAIN","Mean/Mode","GAIN","Discriminative DL","KNN","Random Forest","VAE","VAE","GAIN","Discriminative DL","KNN","Mean/Mode","Random Forest","GAIN","Mean/Mode","Discriminative DL","Mean/Mode","Random Forest","GAIN","Discriminative DL","VAE","VAE","KNN","Random Forest","KNN","Discriminative DL","Mean/Mode","GAIN","KNN","Random Forest","VAE","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","Random Forest","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Discriminative DL","KNN","Mean/Mode","VAE","GAIN","VAE","KNN","Discriminative DL","Random Forest","GAIN","Mean/Mode","VAE","Mean/Mode","KNN","Random Forest","GAIN","Discriminative DL","Discriminative DL","KNN","Random Forest","VAE","GAIN","Mean/Mode","Mean/Mode","Random Forest","VAE","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","Discriminative DL","KNN","Random Forest","GAIN","Mean/Mode","Random Forest","KNN","VAE","GAIN","VAE","Discriminative DL","Mean/Mode","KNN","Discriminative DL","GAIN","Random Forest","Mean/Mode","Discriminative DL","KNN","Random Forest","GAIN","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","KNN","VAE","Random Forest","Discriminative DL","Mean/Mode","VAE","GAIN","KNN","VAE","KNN","Discriminative DL","Random Forest","Mea ...
# <div>                            <div id="7656c1f7-fc74-419e-975d-ef5ed7319e1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7656c1f7-fc74-419e-975d-ef5ed7319e1a")) {                    Plotly.newPlot(                        "7656c1f7-fc74-419e-975d-ef5ed7319e1a",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1496","1496","1496","1496","1496","1507","1507","1507","1496","1507","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["GAIN","Discriminative DL","VAE","KNN","Random Forest","Mean/Mode","GAIN","Mean/Mode","Random Forest","VAE","KNN","Discriminative DL","KNN","GAIN","VAE","Mean/Mode","Discriminative DL","Random Forest","Discriminative DL","VAE","KNN","Mean/Mode","GAIN","Random Forest","Random Forest","KNN","GAIN","Mean/Mode","VAE","Discriminative DL","Mean/Mode","GAIN","KNN","VAE","Discriminative DL","Random Forest","KNN","GAIN","Random Forest","Mean/Mode","VAE","Mean/Mode","VAE","Discriminative DL","Random Forest","GAIN","KNN","GAIN","VAE","KNN","Discriminative DL","Random Forest","Mean/Mode","KNN","Discriminative DL","VAE","Mean/Mode","Random Forest","GAIN","VAE","Discriminative DL","KNN","GAIN","Mean/Mode","Random Forest","Discriminative DL","KNN","Random Forest","VAE","Mean/Mode","Random Forest","Mean/Mode","Discriminative DL","GAIN","GAIN","VAE","KNN","VAE","KNN","Mean/Mode","Discriminative DL","Random Forest","GAIN","KNN","Random Forest","VAE","Mean/Mode","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","VAE","GAIN","Mean/Mode","KNN","Random Forest","GAIN","Mean/Mode","VAE","Discriminative DL","VAE","GAIN","KNN","Random Forest","Mean/Mode","KNN","Mean/Mode","Discriminative DL","Random Forest","VAE","GAIN","Random Forest","Mean/Mode","VAE","GAIN","KNN","Discriminative DL","Discriminative DL","VAE","Random Forest","KNN","Mean/Mode","GAIN","KNN","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Discriminative DL","VAE","Random Forest","Mean/Mode","GAIN","KNN","Mean/Mode","VAE","Random Forest","GAIN","KNN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","Discriminative DL","KNN","KNN","Mean/Mode","Random Forest","VAE","Discriminative DL","GAIN","GAIN","Mean/Mode","KNN","VAE","Discriminative DL","Random Forest","VAE","Mean/Mode","GAIN","Discriminative DL","KNN","Random Forest","VAE","Discriminative DL","Random Forest","GAIN","KNN","Mean/Mode","Mean/Mode","VAE","GAIN","KNN","Discrimi ...
# <div>                            <div id="adb2887e-749c-45bc-8c53-ff1d1e262f67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adb2887e-749c-45bc-8c53-ff1d1e262f67")) {                    Plotly.newPlot(                        "adb2887e-749c-45bc-8c53-ff1d1e262f67",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["Mean/Mode","VAE","Discriminative DL","Random Forest","GAIN","KNN","GAIN","Discriminative DL","Mean/Mode","VAE","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","Mean/Mode","VAE","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","Discriminative DL","KNN","GAIN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Random Forest","Discriminative DL","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","VAE","Random Forest","GAIN","KNN","Discriminative DL","VAE","Random Forest","Mean/Mode","Mean/Mode","GAIN","VAE","KNN","Discriminative DL","Random Forest","Discriminative DL","KNN","KNN","GAIN","Mean/Mode","Discriminative DL","GAIN","VAE","VAE","Random Forest","Random Forest","Mean/Mode","VAE","Random Forest","GAIN","Mean/Mode","KNN","Discriminative DL","GAIN","Discriminative DL","KNN","Random Forest","Mean/Mode","VAE","Random Forest","Mean/Mode","KNN","VAE","Discriminative DL","GAIN","Discriminative DL","GAIN","KNN","Mean/Mode","VAE","Random Forest","VAE","Mean/Mode","Discriminative DL","KNN","Random Forest","GAIN","Mean/Mode","Discriminative DL","Random Forest","GAIN","KNN","VAE","KNN","Random Forest","Mean/Mode","GAIN","Discriminative DL","VAE","Discriminative DL","Mean/Mode","GAIN","Random Forest","VAE","KNN","KNN","VAE","GAIN","Mean/Mode","Random Forest","Discriminative DL","VAE","Random Forest","GAIN","Mean/Mode","Discriminative DL","KNN","Random Forest","Discriminative DL","VAE","KNN","Mean/Mode","GAIN","GAIN","Mean/Mode","Random Forest","VAE","KNN","Discriminative DL","Mean/Mode","KNN","VAE","GAIN","Random Forest","Discriminative DL","VAE","Discriminative DL","Mean/Mode","Random Forest","GAIN","KNN","Discriminative DL","VAE","GAIN","KNN","Mean/Mode","Random Forest","Discriminative DL","Mean/Mode","KNN","GAIN","VAE"," ...

# %%
#downstream_results_rank_heatmap2
df_heat_dif = downstream_results_rank_heatmap2.copy()

# %%
# Calculate Difference for every Imputation towards average best Imputation Method per Data Constellation
# Calculation for F1 Score Differences (not Percentage)

data = downstream_results_rank.copy()
data['Task'] = data['Task'].astype(str)
data['Data_Constellation_full'] = data['Data_Constellation'] + ' - ' + data['Task']

dc_unique = data.Data_Constellation_full.unique()
#print(dc_unique)

data_constellations = dc_unique.tolist()
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
heatmap_data_difference = pd.DataFrame()


for i in data_constellations:
    data_constel = data.loc[data['Data_Constellation_full'] == i]
    average_best = data_constel.loc[data_constel['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
    dataset_number = best_score.iloc[0]['Task']
    for i in methods:
        if ((data_constel['Imputation_Method'] == i).any()):
            if average_best.empty:#dataset_number != '4135'
                print("No average best result for", dataset_number)
                #print(dataset_number)  
            else:
                current_score_row = data_constel.loc[data['Imputation_Method'] == i]
                current_score_int = current_score_row.iloc[0]['Imputed_Subset']
                average_best_int = average_best.iloc[0]['Imputed_Subset']
                calc_result = (current_score_int - average_best_int)
            
                current_score_row['Performance Difference to Average Best'] = calc_result
                heatmap_data_difference = heatmap_data_difference.append(current_score_row)               
    
        else:
            print(dataset_number,"Imputation Method not here ---------------------")



heatmap_data_difference['Missing Type'] = heatmap_data_difference['Missing Type'].astype(str)
heatmap_data_difference['Missing Fraction'] = heatmap_data_difference['Missing Fraction'].astype(str)
heatmap_data_difference
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# ...
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_9036\3538753210.py:32: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#       Imputation_Method   Task Missing Type Missing Fraction  \
# 2         Random Forest    137          MAR             0.01
# 1                   KNN    137          MAR             0.01
# 4             Mean/Mode    137          MAR             0.01
# 5                   VAE    137          MAR             0.01
# 3                  GAIN    137          MAR             0.01
# ...                 ...    ...          ...              ...
# 2220                KNN  42493         MNAR              0.5
# 2217          Mean/Mode  42493         MNAR              0.5
# 2221                VAE  42493         MNAR              0.5
# 2218               GAIN  42493         MNAR              0.5
# 2216  Discriminative DL  42493         MNAR              0.5
#
#                  Column                  result_type                metric  \
# 2     top-middle-square  downstream_performance_mean  Classification Tasks
# 1     top-middle-square  downstream_performance_mean  Classification Tasks
# 4     top-middle-square  downstream_performance_mean  Classification Tasks
# 5     top-middle-square  downstream_performance_mean  Classification Tasks
# 3     top-middle-square  downstream_performance_mean  Classification Tasks
# ...                 ...                          ...                   ...
# 2220             Length  downstream_performance_mean  Classification Tasks
# 2217             Length  downstream_performance_mean  Classification Tasks
# 2221             Length  downstream_performance_mean  Classification Tasks
# 2218             Length  downstream_performance_mean  Classification Tasks
# 2216             Length  downstream_performance_mean  Classification Tasks
#
#       Baseline  Corrupted  Imputed_Subset  ...  MinorityClassSize  \
# 2     0.698074        0.0        0.698074  ...            13664.0
# 1     0.698074        0.0        0.698074  ...            13664.0
# 4     0.699217        0.0        0.699217  ...            13664.0
# 5     0.699699        0.0        0.699699  ...            13664.0
# 3     0.698555        0.0        0.698555  ...            13664.0
# ...        ...        ...             ...  ...                ...
# 2220  0.612391        0.0        0.606716  ...            12035.0
# 2217  0.591024        0.0        0.592436  ...            12035.0
# 2221  0.610725        0.0        0.611129  ...            12035.0
# 2218  0.592603        0.0        0.592837  ...            12035.0
# 2216  0.589875        0.0        0.588734  ...            12035.0
#
#      NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 2                10.0            39366.0                      0.0
# 1                10.0            39366.0                      0.0
# 4                10.0            39366.0                      0.0
# 5                10.0            39366.0                      0.0
# 3                10.0            39366.0                      0.0
# ...               ...                ...                      ...
# 2220              8.0            26969.0                      2.0
# 2217              8.0            26969.0                      2.0
# 2221              8.0            26969.0                      2.0
# 2218              8.0            26969.0                      2.0
# 2216              8.0            26969.0                      2.0
#
#       NumberOfCategoricalFeatures  NumberOfClasses  \
# 2                            10.0              NaN
# 1                            10.0              NaN
# 4                            10.0              NaN
# 5                            10.0              NaN
# 3                            10.0              NaN
# ...                           ...              ...
# 2220                          6.0              NaN
# 2217                          6.0              NaN
# 2221                          6.0              NaN
# 2218                          6.0              NaN
# 2216                          6.0              NaN
#
#       Downstream Performance Rank Subset  Data_Constellation  \
# 2                                    5.0          MAR - 0.01
# 1                                    4.0          MAR - 0.01
# 4                                    2.0          MAR - 0.01
# 5                                    1.0          MAR - 0.01
# 3                                    3.0          MAR - 0.01
# ...                                  ...                 ...
# 2220                                 2.0          MNAR - 0.5
# 2217                                 5.0          MNAR - 0.5
# 2221                                 1.0          MNAR - 0.5
# 2218                                 4.0          MNAR - 0.5
# 2216                                 6.0          MNAR - 0.5
#
#       Data_Constellation_full  Performance Difference to Average Best
# 2            MAR - 0.01 - 137                               -0.001143
# 1            MAR - 0.01 - 137                               -0.001143
# 4            MAR - 0.01 - 137                                0.000000
# 5            MAR - 0.01 - 137                                0.000482
# 3            MAR - 0.01 - 137                               -0.000662
# ...                       ...                                     ...
# 2220       MNAR - 0.5 - 42493                                0.014281
# 2217       MNAR - 0.5 - 42493                                0.000000
# 2221       MNAR - 0.5 - 42493                                0.018693
# 2218       MNAR - 0.5 - 42493                                0.000401
# 2216       MNAR - 0.5 - 42493                               -0.003702
#
# [2222 rows x 23 columns]

# %%
# Heatmap for F1 score differences for each data constellation for each method relative to average best imputation method

heatmap_data_difference = heatmap_data_difference.astype({"Task":"string"})
data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']

for i in data_constellations:
    data_constel = heatmap_data_difference.loc[df_heat['Data_Constellation'] == i]

    ### uncomment whatever you want to investigate

    ## sort by amount datapoints (ascending)
    data_constel = data_constel.sort_values(by=['NumberOfInstances'])

    ## sort by amount of features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfFeatures'])

    ## sort by amount of datapoints and features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances', 'NumberOfFeatures'])

    ## sort by amount of categorical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfCategoricalFeatures', 'NumberOfInstances'])

    ## sort by amount of numerical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfNumericFeatures', 'NumberOfInstances'])
    
    Dataset_number = data_constel["Task"]
    Imputation_Method = data_constel["Imputation_Method"]
    Improvement = data_constel["Performance Difference to Average Best"]
    

    trace = go.Heatmap(
                   z=Improvement,
                   x=Dataset_number,
                   y=Imputation_Method,
                   type = 'heatmap',
                    autocolorscale= False,
                    colorscale = 'RdBu_r',
                    zmid=0,
                    zmin=(-0.11),
                    zmax=0.11,
                    )
    data = [trace]
    fig = go.Figure(data=data)
    fig.update_layout(
        title=i,
        xaxis_nticks=36)
    fig.show()
    fig.write_image("binary_subset_heatmap_f1_score_improvement_to_avbest%s.pdf" %i)
# Out:
# <div>                            <div id="3caa3117-e029-4cc0-ad88-df40fec8022e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3caa3117-e029-4cc0-ad88-df40fec8022e")) {                    Plotly.newPlot(                        "3caa3117-e029-4cc0-ad88-df40fec8022e",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","KNN","Random Forest","Mean/Mode","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","VAE","Mean/Mode","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","VAE","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","VAE","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Discriminative DL","VAE" ...
# <div>                            <div id="5f6ebf2e-b769-45db-b328-3d06f86595ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f6ebf2e-b769-45db-b328-3d06f86595ff")) {                    Plotly.newPlot(                        "5f6ebf2e-b769-45db-b328-3d06f86595ff",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest" ...
# <div>                            <div id="0c2fdc91-8d5c-41e5-8776-926251a36954" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c2fdc91-8d5c-41e5-8776-926251a36954")) {                    Plotly.newPlot(                        "0c2fdc91-8d5c-41e5-8776-926251a36954",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest" ...
# <div>                            <div id="50a8a779-cf1d-47ad-9e2c-71841b0b724e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50a8a779-cf1d-47ad-9e2c-71841b0b724e")) {                    Plotly.newPlot(                        "50a8a779-cf1d-47ad-9e2c-71841b0b724e",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","881","901","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","KNN","GAIN","VAE","Mean/Mode","Discriminative DL","Random Forest","KNN","KNN","Mean/Mode","Random Forest","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","KNN","KNN","Discriminative DL","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","VAE","Discriminative DL","KNN","GAIN","Random Forest","KN ...
# <div>                            <div id="aed9bcfb-3dc5-4ae2-a9c0-bbbb09ad7464" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aed9bcfb-3dc5-4ae2-a9c0-bbbb09ad7464")) {                    Plotly.newPlot(                        "aed9bcfb-3dc5-4ae2-a9c0-bbbb09ad7464",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest" ...
# <div>                            <div id="a3ea2b3d-3406-44f9-9993-640258c21f91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3ea2b3d-3406-44f9-9993-640258c21f91")) {                    Plotly.newPlot(                        "a3ea2b3d-3406-44f9-9993-640258c21f91",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","VAE","Mean/Mode","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","VAE","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","VAE","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Discriminative DL","VAE","Mean/Mode","KNN","GAIN"," ...
# <div>                            <div id="fe4db0e5-64c9-4b46-a408-f714c5c1003b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe4db0e5-64c9-4b46-a408-f714c5c1003b")) {                    Plotly.newPlot(                        "fe4db0e5-64c9-4b46-a408-f714c5c1003b",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest" ...
# <div>                            <div id="aa3b7bb9-a3a3-4128-bad2-40dcc266280d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa3b7bb9-a3a3-4128-bad2-40dcc266280d")) {                    Plotly.newPlot(                        "aa3b7bb9-a3a3-4128-bad2-40dcc266280d",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","GAIN","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","VAE","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Discriminative DL","VAE", ...
# <div>                            <div id="f1ab3734-4811-402e-ba9d-cd2305cea42e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1ab3734-4811-402e-ba9d-cd2305cea42e")) {                    Plotly.newPlot(                        "f1ab3734-4811-402e-ba9d-cd2305cea42e",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1496","1496","1507","1496","1496","1496","1496","1507","1507","1507","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","901","901","901","901","901","881","901","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Random Forest","GAIN","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","GAIN","VAE","Random Forest","KNN","Mean/Mode","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","KNN","GAIN","Discriminative DL","VAE","GAIN","Discriminative DL","Random Forest","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","KNN","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","Discriminative DL","VAE","Mean/Mode","KNN","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","Mean/Mode","KNN","VAE","Me ...
# <div>                            <div id="3c6c33fa-b7a1-489b-8cb2-31cab9725163" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c6c33fa-b7a1-489b-8cb2-31cab9725163")) {                    Plotly.newPlot(                        "3c6c33fa-b7a1-489b-8cb2-31cab9725163",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest" ...
# <div>                            <div id="aad2858e-c238-4922-a22c-a9db1d1eff36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aad2858e-c238-4922-a22c-a9db1d1eff36")) {                    Plotly.newPlot(                        "aad2858e-c238-4922-a22c-a9db1d1eff36",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1496","1496","1496","1496","1496","1507","1507","1507","1496","1507","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Random Forest","GAIN","Discriminative DL","VAE","Mean/Mode","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","GAIN","VAE","Random Forest","KNN","Mean/Mode","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","GAIN","Discriminative DL","VAE","VAE","Random Forest","Mean/Mode","KNN","Discriminative DL","VAE","GAIN","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","Mean/Mode","KNN","Random Forest","VAE","VAE","Discriminative DL","Random Forest","KNN","Mean/Mode","GAIN","GAIN","VAE","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","Discriminative DL","GAIN","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","KNN","Random Forest","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","Discriminative DL","VAE","Mean/Mode","KNN","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","Discriminative DL","VAE","Mean/Mode","KNN","GAIN","KN ...
# <div>                            <div id="449178a5-aae4-4028-8b2e-13042ed77a39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("449178a5-aae4-4028-8b2e-13042ed77a39")) {                    Plotly.newPlot(                        "449178a5-aae4-4028-8b2e-13042ed77a39",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["737","737","737","737","737","737","871","871","871","871","871","871","728","728","728","728","728","728","1558","1558","1558","1558","1558","1558","40983","40983","40983","40983","40983","40983","40701","40701","40701","40701","40701","40701","41146","41146","41146","41146","41146","41146","42192","42192","42192","42192","42192","42192","1489","1489","1489","1489","1489","1489","847","847","847","847","847","847","803","803","803","803","803","803","1507","1507","1496","1496","1496","1496","1507","1507","1496","1496","1507","1507","725","725","725","725","725","725","923","923","923","923","923","923","310","310","310","310","310","310","1471","1471","1471","1471","1471","1471","1046","1046","1046","1046","1046","1046","1120","1120","1120","1120","1120","1120","823","823","823","823","823","823","42493","42493","42493","42493","42493","42493","42477","42477","42477","42477","42477","42477","4135","4135","4135","4135","4135","4135","251","251","251","251","251","137","251","137","137","137","137","137","1220","1220","1220","1220","1220","1220","901","901","901","901","901","901","881","881","881","881","881","881","151","151","151","151","151","151","40922","40922","40922","40922","40922","40922","23517","23517","23517","23517","23517","23517"],"y":["KNN","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Random Forest","KNN","Random Forest","GAIN","VAE","Mean/Mode","Discriminative DL","KNN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","KNN","Discriminative DL","Random Forest","GAIN","VAE","KNN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","KNN","Discriminative DL","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","VAE","Discriminative DL","GAIN","Mean/Mode","Random Forest","KNN","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","KNN","GAIN","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Discriminative DL","Random Forest","VAE","Mean/Mode","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Mean/Mode","Discriminative DL","GAIN","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Random Forest","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","GAIN","VAE","Mean/Mode","KNN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest" ...

# %%
#heatmap_data_difference.agg(['min', 'max'])
# Out:
#      Imputation_Method  Task Missing Type Missing Fraction  \
# min  Discriminative DL  1046          MAR             0.01
# max                VAE   923         MNAR              0.5
#
#                     Column                  result_type                metric  \
# min  Cell_Shape_Uniformity  downstream_performance_mean  Classification Tasks
# max                   year  downstream_performance_mean  Classification Tasks
#
#      Baseline  Corrupted  Imputed_Subset  ...  MinorityClassSize  \
# min  0.335870        0.0        0.331796  ...              260.0
# max  0.994156        0.0        0.994156  ...            47662.0
#
#     NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# min              5.0             3107.0                      0.0
# max             24.0            96320.0                     23.0
#
#      NumberOfCategoricalFeatures  NumberOfClasses  \
# min                          1.0              NaN
# max                         10.0              NaN
#
#      Downstream Performance Rank Subset  Data_Constellation  \
# min                                 1.0          MAR - 0.01
# max                                 6.0          MNAR - 0.5
#
#      Data_Constellation_full  Performance Difference to Average Best
# min        MAR - 0.01 - 1046                               -0.208714
# max         MNAR - 0.5 - 923                                0.232155
#
# [2 rows x 23 columns]

# %% [markdown]
# ## Improvment Proportions for All Data Constellations and Methods Relative to Average Best Method

# %%
heatmap_data_difference
heatmap_data_difference.to_csv('binary_subset_full_info.csv', index=False)

# %%
# sorting data by total improvement
df_quantiles = heatmap_data_difference.copy()

df_quantiles = df_quantiles.drop(df_quantiles[df_quantiles["Imputation_Method"] == AVERAGE_BEST_IMPUTATION_METHOD].index)


df_10 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] > (-0.09))].index)
df_09 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (-0.09)) | (df_quantiles["Performance Difference to Average Best"] > (-0.07))].index)
df_07 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (-0.07)) | (df_quantiles["Performance Difference to Average Best"] > (-0.05))].index)
df_05 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (-0.05)) | (df_quantiles["Performance Difference to Average Best"] > (-0.03))].index)
df_03 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (-0.03)) | (df_quantiles["Performance Difference to Average Best"] > (-0.01))].index)
df_01 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (-0.01)) | (df_quantiles["Performance Difference to Average Best"] > (0.01))].index)
df01 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (0.01)) | (df_quantiles["Performance Difference to Average Best"] > (0.03))].index)
df03 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (0.03)) | (df_quantiles["Performance Difference to Average Best"] > (0.05))].index)
df05 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (0.05)) | (df_quantiles["Performance Difference to Average Best"] > (0.07))].index)
df07 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (0.07)) | (df_quantiles["Performance Difference to Average Best"] > (0.09))].index)
df09 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best"] <= (0.09))].index)

#df_quantiles
#df_quantiles.dtypes

# %%
len_df_10 = len(df_10.index)
len_df_09 = len(df_09.index)
len_df_07 = len(df_07.index)
len_df_05 = len(df_05.index)
len_df_03 = len(df_03.index)
len_df_01 = len(df_01.index)
len_df01 = len(df01.index)
len_df03 = len(df03.index)
len_df05 = len(df05.index)
len_df07 = len(df07.index)
len_df09 = len(df09.index)

quantile_freq = []
#quantile_freq.append()
quantile_freq.extend((len_df_10, len_df_09, len_df_07, len_df_05, len_df_03, len_df_01, len_df01, len_df03, len_df05, len_df07, len_df09))
print(quantile_freq)


quantiles = []
quantiles.extend(['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09'])
print(quantiles)

improvement_quantiles = pd.DataFrame(
    {'Improvement to Average Best': quantiles,
     'Amount': quantile_freq,
    })
# Out:
# [32, 16, 41, 98, 204, 1170, 166, 47, 28, 11, 37]
# ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03', '-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']

# %%
fig = px.bar(improvement_quantiles, x='Improvement to Average Best', y='Amount')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl.pdf")
# Out:
# <div>                            <div id="18cdedbe-2a41-4b69-a3ca-67ec38ea4ac6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18cdedbe-2a41-4b69-a3ca-67ec38ea4ac6")) {                    Plotly.newPlot(                        "18cdedbe-2a41-4b69-a3ca-67ec38ea4ac6",                        [{"alignmentgroup":"True","hovertemplate":"Improvement to Average Best=%{x}<br>Amount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"xaxis":"x","y":[32,16,41,98,204,1170,166,47,28,11,37],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","siz ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_10, df_09, df_07, df_05, df_03, df_01, df01, df03, df05, df07, df09]

methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
methods.remove(AVERAGE_BEST_IMPUTATION_METHOD)
print(methods)

forest_freq = []
knn_freq = []
mode_freq = []
dl_freq = []
vae_freq = []
gain_freq = []
#print(quantile_datasets)

for i in methods:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Imputation_Method'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'Random Forest'):
            forest_freq.append(df_temp_len)
        elif (i == 'KNN'):
            knn_freq.append(df_temp_len)                                       
        elif (i == 'Mean/Mode'):
            mode_freq.append(df_temp_len)                                                 
        elif (i == 'Discriminative DL'):
            dl_freq.append(df_temp_len)                                       
        elif (i == 'VAE'):
            vae_freq.append(df_temp_len)                                         
        elif (i == 'GAIN'):
            gain_freq.append(df_temp_len)                                          
                                       
print(forest_freq)
print(knn_freq)
print(mode_freq)
print(dl_freq)
print(vae_freq)
print(gain_freq)
# Out:
# ['Random Forest', 'KNN', 'VAE', 'GAIN', 'Discriminative DL']
# [4, 3, 9, 13, 43, 224, 44, 11, 9, 3, 9]
# [6, 3, 10, 22, 36, 233, 37, 10, 3, 2, 10]
# []
# [8, 4, 7, 16, 38, 235, 35, 7, 3, 3, 6]
# [6, 4, 8, 21, 44, 238, 29, 4, 10, 2, 6]
# [8, 2, 7, 26, 43, 240, 21, 15, 3, 1, 6]

# %%
quantiles = ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']

fig = go.Figure(data=[
    go.Bar(name='Random Forest', x=quantiles, y=forest_freq),
    go.Bar(name='KNN', x=quantiles, y=knn_freq),
    go.Bar(name='Mean/Mode', x=quantiles, y=mode_freq),
    go.Bar(name='Discriminative DL', x=quantiles, y=dl_freq),
    go.Bar(name='VAE', x=quantiles, y=vae_freq),
    go.Bar(name='GAIN', x=quantiles, y=gain_freq)
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_per_method.pdf")
# Out:
# <div>                            <div id="9cba4205-f0f1-4368-b9ba-fc2bb79c0aeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cba4205-f0f1-4368-b9ba-fc2bb79c0aeb")) {                    Plotly.newPlot(                        "9cba4205-f0f1-4368-b9ba-fc2bb79c0aeb",                        [{"name":"Random Forest","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[4,3,9,13,43,224,44,11,9,3,9],"type":"bar"},{"name":"KNN","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[6,3,10,22,36,233,37,10,3,2,10],"type":"bar"},{"name":"Mean/Mode","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[],"type":"bar"},{"name":"Discriminative DL","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[8,4,7,16,38,235,35,7,3,3,6],"type":"bar"},{"name":"VAE","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[6,4,8,21,44,238,29,4,10,2,6],"type":"bar"},{"name":"GAIN","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[8,2,7,26,43,240,21,15,3,1,6],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_10, df_09, df_07, df_05, df_03, df_01, df01, df03, df05, df07, df09]

fractions = ['0.01', '0.1', '0.3', '0.5']
print(fractions)
#print(df_10)

freq_001 = []
freq_01 = []
freq_03 = []
freq_05 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Fraction'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == '0.01'):
            freq_001.append(df_temp_len)
        elif (i == '0.1'):
            freq_01.append(df_temp_len)                                       
        elif (i == '0.3'):
            freq_03.append(df_temp_len)                                                 
        elif (i == '0.5'):
            freq_05.append(df_temp_len)                                       
                                        
                                       
print(freq_001)
print(freq_01)
print(freq_03)
print(freq_05)
# Out:
# ['0.01', '0.1', '0.3', '0.5']
# [3, 4, 1, 10, 19, 371, 28, 5, 6, 1, 14]
# [11, 3, 10, 22, 38, 320, 43, 7, 0, 1, 8]
# [11, 2, 14, 29, 78, 254, 43, 16, 9, 1, 6]
# [7, 7, 16, 37, 69, 225, 52, 19, 13, 8, 9]

# %%
quantiles = ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='1% Missing Data', x=quantiles, y=freq_001, marker_color='#FD3216'),
    go.Bar(name='10% Missing Data', x=quantiles, y=freq_01, marker_color='#00FE35'),
    go.Bar(name='30% Missing Data', x=quantiles, y=freq_03, marker_color='#511CFB'),
    go.Bar(name='50% Missing Data', x=quantiles, y=freq_05, marker_color='#FF7F0E'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_per_frac.pdf")
# Out:
# <div>                            <div id="775b4689-2a0c-4aef-8b81-be8f0f7cbd7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("775b4689-2a0c-4aef-8b81-be8f0f7cbd7c")) {                    Plotly.newPlot(                        "775b4689-2a0c-4aef-8b81-be8f0f7cbd7c",                        [{"marker":{"color":"#FD3216"},"name":"1% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[3,4,1,10,19,371,28,5,6,1,14],"type":"bar"},{"marker":{"color":"#00FE35"},"name":"10% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[11,3,10,22,38,320,43,7,0,1,8],"type":"bar"},{"marker":{"color":"#511CFB"},"name":"30% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[11,2,14,29,78,254,43,16,9,1,6],"type":"bar"},{"marker":{"color":"#FF7F0E"},"name":"50% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[7,7,16,37,69,225,52,19,13,8,9],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_10, df_09, df_07, df_05, df_03, df_01, df01, df03, df05, df07, df09]

fractions = ['MCAR', 'MAR', 'MNAR']
print(fractions)
#print(df_10)

freq_001 = []
freq_01 = []
freq_03 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Type'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'MCAR'):
            freq_001.append(df_temp_len)
        elif (i == 'MAR'):
            freq_01.append(df_temp_len)                                       
        elif (i == 'MNAR'):
            freq_03.append(df_temp_len)                                                 

                                       
print(freq_001)
print(freq_01)
print(freq_03)
# Out:
# ['MCAR', 'MAR', 'MNAR']
# [12, 5, 18, 40, 79, 393, 40, 15, 6, 0, 9]
# [9, 2, 13, 25, 63, 387, 64, 17, 11, 9, 17]
# [11, 9, 10, 33, 62, 390, 62, 15, 11, 2, 11]

# %%
quantiles = ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='MCAR', x=quantiles, y=freq_001, marker_color='#222A2A'),
    go.Bar(name='MAR', x=quantiles, y=freq_01, marker_color='#B68100'),
    go.Bar(name='MNAR', x=quantiles, y=freq_03, marker_color='#750D86'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_per_patt.pdf")
# Out:
# <div>                            <div id="cfd1c2f4-38c8-4610-b089-c45bfde9e356" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfd1c2f4-38c8-4610-b089-c45bfde9e356")) {                    Plotly.newPlot(                        "cfd1c2f4-38c8-4610-b089-c45bfde9e356",                        [{"marker":{"color":"#222A2A"},"name":"MCAR","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[12,5,18,40,79,393,40,15,6,0,9],"type":"bar"},{"marker":{"color":"#B68100"},"name":"MAR","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[9,2,13,25,63,387,64,17,11,9,17],"type":"bar"},{"marker":{"color":"#750D86"},"name":"MNAR","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[11,9,10,33,62,390,62,15,11,2,11],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"p ...

# %% [markdown]
# ## Improvment Proportions for the Best Imputation Method per Data Constellation Relative to Average Best Method

# %%
improv_to_av_bar = heatmap_data_difference.copy()

improv_to_av_bar = improv_to_av_bar.drop(improv_to_av_bar[improv_to_av_bar["Downstream Performance Rank Subset"] != 1.0].index)

df_01 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best"] <= (-0.01)) | (improv_to_av_bar["Performance Difference to Average Best"] > (0.01))].index)
df01 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best"] <= (0.01)) | (improv_to_av_bar["Performance Difference to Average Best"] > (0.03))].index)
df03 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best"] <= (0.03)) | (improv_to_av_bar["Performance Difference to Average Best"] > (0.05))].index)
df05 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best"] <= (0.05)) | (improv_to_av_bar["Performance Difference to Average Best"] > (0.07))].index)
df07 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best"] <= (0.07)) | (improv_to_av_bar["Performance Difference to Average Best"] > (0.09))].index)
df09 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best"] <= (0.09))].index)

improv_to_av_bar
# Out:
#      Imputation_Method   Task Missing Type Missing Fraction  \
# 5                  VAE    137          MAR             0.01
# 11                 VAE    137          MAR              0.1
# 17                 VAE    137          MAR              0.3
# 23                 KNN    137          MAR              0.5
# 29                 KNN    137         MCAR             0.01
# ...                ...    ...          ...              ...
# 2197     Random Forest  42493         MCAR              0.5
# 2201         Mean/Mode  42493         MNAR             0.01
# 2208         Mean/Mode  42493         MNAR              0.1
# 2215         Mean/Mode  42493         MNAR              0.3
# 2221               VAE  42493         MNAR              0.5
#
#                  Column                  result_type                metric  \
# 5     top-middle-square  downstream_performance_mean  Classification Tasks
# 11    top-middle-square  downstream_performance_mean  Classification Tasks
# 17    top-middle-square  downstream_performance_mean  Classification Tasks
# 23    top-middle-square  downstream_performance_mean  Classification Tasks
# 29    top-middle-square  downstream_performance_mean  Classification Tasks
# ...                 ...                          ...                   ...
# 2197             Length  downstream_performance_mean  Classification Tasks
# 2201             Length  downstream_performance_mean  Classification Tasks
# 2208             Length  downstream_performance_mean  Classification Tasks
# 2215             Length  downstream_performance_mean  Classification Tasks
# 2221             Length  downstream_performance_mean  Classification Tasks
#
#       Baseline  Corrupted  Imputed_Subset  ...  MinorityClassSize  \
# 5     0.699699        0.0        0.699699  ...            13664.0
# 11    0.700844        0.0        0.700844  ...            13664.0
# 17    0.702163        0.0        0.700799  ...            13664.0
# 23    0.705702        0.0        0.706240  ...            13664.0
# 29    0.699217        0.0        0.699217  ...            13664.0
# ...        ...        ...             ...  ...                ...
# 2197  0.606068        0.0        0.606759  ...            12035.0
# 2201  0.614237        0.0        0.614237  ...            12035.0
# 2208  0.612068        0.0        0.614235  ...            12035.0
# 2215  0.598213        0.0        0.600125  ...            12035.0
# 2221  0.610725        0.0        0.611129  ...            12035.0
#
#      NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 5                10.0            39366.0                      0.0
# 11               10.0            39366.0                      0.0
# 17               10.0            39366.0                      0.0
# 23               10.0            39366.0                      0.0
# 29               10.0            39366.0                      0.0
# ...               ...                ...                      ...
# 2197              8.0            26969.0                      2.0
# 2201              8.0            26969.0                      2.0
# 2208              8.0            26969.0                      2.0
# 2215              8.0            26969.0                      2.0
# 2221              8.0            26969.0                      2.0
#
#       NumberOfCategoricalFeatures  NumberOfClasses  \
# 5                            10.0              NaN
# 11                           10.0              NaN
# 17                           10.0              NaN
# 23                           10.0              NaN
# 29                           10.0              NaN
# ...                           ...              ...
# 2197                          6.0              NaN
# 2201                          6.0              NaN
# 2208                          6.0              NaN
# 2215                          6.0              NaN
# 2221                          6.0              NaN
#
#       Downstream Performance Rank Subset  Data_Constellation  \
# 5                                    1.0          MAR - 0.01
# 11                                   1.0           MAR - 0.1
# 17                                   1.0           MAR - 0.3
# 23                                   1.0           MAR - 0.5
# 29                                   1.0         MCAR - 0.01
# ...                                  ...                 ...
# 2197                                 1.0          MCAR - 0.5
# 2201                                 1.0         MNAR - 0.01
# 2208                                 1.0          MNAR - 0.1
# 2215                                 1.0          MNAR - 0.3
# 2221                                 1.0          MNAR - 0.5
#
#       Data_Constellation_full  Performance Difference to Average Best
# 5            MAR - 0.01 - 137                                0.000482
# 11            MAR - 0.1 - 137                                0.003475
# 17            MAR - 0.3 - 137                                0.003273
# 23            MAR - 0.5 - 137                                0.008765
# 29          MCAR - 0.01 - 137                                0.001143
# ...                       ...                                     ...
# 2197       MCAR - 0.5 - 42493                                0.006597
# 2201      MNAR - 0.01 - 42493                                0.000000
# 2208       MNAR - 0.1 - 42493                                0.000000
# 2215       MNAR - 0.3 - 42493                                0.000000
# 2221       MNAR - 0.5 - 42493                                0.018693
#
# [372 rows x 23 columns]

# %%
len_df_01 = len(df_01.index)
len_df01 = len(df01.index)
len_df03 = len(df03.index)
len_df05 = len(df05.index)
len_df07 = len(df07.index)
len_df09 = len(df09.index)

quantile_freq = []
quantile_freq.extend((len_df_01, len_df01, len_df03, len_df05, len_df07, len_df09))
print(quantile_freq)


quantiles = []
quantiles.extend(['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09'])
print(quantiles)

improvement_quantiles = pd.DataFrame(
    {'Improvement to Average Best': quantiles,
     'Amount': quantile_freq,
    })

fig = px.bar(improvement_quantiles, x='Improvement to Average Best', y='Amount')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_only_best.pdf")
# Out:
# [243, 67, 23, 15, 6, 18]
# ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']
# <div>                            <div id="c87d7e2b-b11e-4144-8779-1e8e559287d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c87d7e2b-b11e-4144-8779-1e8e559287d3")) {                    Plotly.newPlot(                        "c87d7e2b-b11e-4144-8779-1e8e559287d3",                        [{"alignmentgroup":"True","hovertemplate":"Improvement to Average Best=%{x}<br>Amount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"xaxis":"x","y":[243,67,23,15,6,18],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinew ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_01, df01, df03, df05, df07, df09]

methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
methods.remove(AVERAGE_BEST_IMPUTATION_METHOD)
print(methods)

forest_freq = []
knn_freq = []
mode_freq = []
dl_freq = []
vae_freq = []
gain_freq = []
#print(quantile_datasets)

for i in methods:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Imputation_Method'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'Random Forest'):
            forest_freq.append(df_temp_len)
        elif (i == 'KNN'):
            knn_freq.append(df_temp_len)                                       
        elif (i == 'Mean/Mode'):
            mode_freq.append(df_temp_len)                                                 
        elif (i == 'Discriminative DL'):
            dl_freq.append(df_temp_len)                                       
        elif (i == 'VAE'):
            vae_freq.append(df_temp_len)                                         
        elif (i == 'GAIN'):
            gain_freq.append(df_temp_len)                                          
                                       
print(forest_freq)
print(knn_freq)
print(mode_freq)
print(dl_freq)
print(vae_freq)
print(gain_freq)
# Out:
# ['Random Forest', 'KNN', 'VAE', 'GAIN', 'Discriminative DL']
# [29, 18, 8, 5, 2, 6]
# [34, 19, 3, 2, 0, 8]
# []
# [27, 15, 4, 1, 1, 1]
# [26, 9, 1, 7, 2, 1]
# [26, 6, 7, 0, 1, 2]

# %%
quantiles = ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='Random Forest', x=quantiles, y=forest_freq),
    go.Bar(name='KNN', x=quantiles, y=knn_freq),
    go.Bar(name='Mean/Mode', x=quantiles, y=mode_freq),
    go.Bar(name='Discriminative DL', x=quantiles, y=dl_freq),
    go.Bar(name='VAE', x=quantiles, y=vae_freq),
    go.Bar(name='GAIN', x=quantiles, y=gain_freq)
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_only_best_per_method.pdf")
# Out:
# <div>                            <div id="9d260adb-8689-465f-be12-9e8f1cc90b0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d260adb-8689-465f-be12-9e8f1cc90b0a")) {                    Plotly.newPlot(                        "9d260adb-8689-465f-be12-9e8f1cc90b0a",                        [{"name":"Random Forest","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[29,18,8,5,2,6],"type":"bar"},{"name":"KNN","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[34,19,3,2,0,8],"type":"bar"},{"name":"Mean/Mode","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[],"type":"bar"},{"name":"Discriminative DL","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[27,15,4,1,1,1],"type":"bar"},{"name":"VAE","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[26,9,1,7,2,1],"type":"bar"},{"name":"GAIN","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[26,6,7,0,1,2],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","si ...

# %%
# split barchart stacks into missingness fractions

quantile_datasets = [df_01, df01, df03, df05, df07, df09]

fractions = ['0.01', '0.1', '0.3', '0.5']
print(fractions)


freq_001 = []
freq_01 = []
freq_03 = []
freq_05 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Fraction'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == '0.01'):
            freq_001.append(df_temp_len)
        elif (i == '0.1'):
            freq_01.append(df_temp_len)                                       
        elif (i == '0.3'):
            freq_03.append(df_temp_len)                                                 
        elif (i == '0.5'):
            freq_05.append(df_temp_len)                                       
                                        
                                       
print(freq_001)
print(freq_01)
print(freq_03)
print(freq_05)
# Out:
# ['0.01', '0.1', '0.3', '0.5']
# [71, 12, 1, 2, 0, 7]
# [61, 24, 4, 0, 0, 4]
# [58, 16, 7, 8, 1, 3]
# [53, 15, 11, 5, 5, 4]

# %%
quantiles = ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='1% Missing Data', x=quantiles, y=freq_001, marker_color='#FD3216'),
    go.Bar(name='10% Missing Data', x=quantiles, y=freq_01, marker_color='#00FE35'),
    go.Bar(name='30% Missing Data', x=quantiles, y=freq_03, marker_color='#511CFB'),
    go.Bar(name='50% Missing Data', x=quantiles, y=freq_05, marker_color='#FF7F0E'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_only_best_per_frac.pdf")
# Out:
# <div>                            <div id="c4e7f4c1-1310-4819-af53-6eb74486811e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4e7f4c1-1310-4819-af53-6eb74486811e")) {                    Plotly.newPlot(                        "c4e7f4c1-1310-4819-af53-6eb74486811e",                        [{"marker":{"color":"#FD3216"},"name":"1% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[71,12,1,2,0,7],"type":"bar"},{"marker":{"color":"#00FE35"},"name":"10% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[61,24,4,0,0,4],"type":"bar"},{"marker":{"color":"#511CFB"},"name":"30% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[58,16,7,8,1,3],"type":"bar"},{"marker":{"color":"#FF7F0E"},"name":"50% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[53,15,11,5,5,4],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl": ...

# %%
# split barchart stacks into missingness fractions

quantile_datasets = [df_01, df01, df03, df05, df07, df09]

fractions = ['MCAR', 'MAR', 'MNAR']
print(fractions)


freq_001 = []
freq_01 = []
freq_03 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Type'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'MCAR'):
            freq_001.append(df_temp_len)
        elif (i == 'MAR'):
            freq_01.append(df_temp_len)                                       
        elif (i == 'MNAR'):
            freq_03.append(df_temp_len)                                                                                    
                                        
                                       
print(freq_001)
print(freq_01)
print(freq_03)
# Out:
# ['MCAR', 'MAR', 'MNAR']
# [92, 17, 6, 3, 0, 6]
# [70, 26, 9, 5, 5, 9]
# [81, 24, 8, 7, 1, 3]

# %%
quantiles = ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='MCAR', x=quantiles, y=freq_001, marker_color='#222A2A'),
    go.Bar(name='MAR', x=quantiles, y=freq_01, marker_color='#B68100'),
    go.Bar(name='MNAR', x=quantiles, y=freq_03, marker_color='#750D86'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_only_best_per_patt.pdf")
# Out:
# <div>                            <div id="b5f3bb49-aff0-4dec-9a4c-d895c4bcc21a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5f3bb49-aff0-4dec-9a4c-d895c4bcc21a")) {                    Plotly.newPlot(                        "b5f3bb49-aff0-4dec-9a4c-d895c4bcc21a",                        [{"marker":{"color":"#222A2A"},"name":"MCAR","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[92,17,6,3,0,6],"type":"bar"},{"marker":{"color":"#B68100"},"name":"MAR","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[70,26,9,5,5,9],"type":"bar"},{"marker":{"color":"#750D86"},"name":"MNAR","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[81,24,8,7,1,3],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay ...

# %% [markdown]
# ## Extract datasets for Automated Imputation Method Selection -> not used in this theses
#
# To Do: Explore the possibility, that the average best method replaces the best method for a data constellation, if the improvement gain for the best method is below 1%
#
# ### Potential Features:
# Missingess Pattern (Missing Type)
# Missing Fraction (Missing Fraction)
# Datapoints (NumberOfInstances)
# Features in total (NumberOfFeatures)
# Numeric Features (NumberOfNumericFeatures)
# Categorical Features (NumberOfCategoricalFeatures)
# Downstream Task Type -> Classification/Regression (metric)
#
#
#
# Label: Best Imputation Method (Imputation_Method)

# %%
# Use dataset with only the best method for each data constellation
rank_1_backup.to_csv('rank_1_backup.csv')
rank_1_backup
# Out:
#      Imputation_Method   Task Missing Type Missing Fraction  \
# 5                  VAE    137          MAR             0.01
# 11                 VAE    137          MAR              0.1
# 17                 VAE    137          MAR              0.3
# 23                 KNN    137          MAR              0.5
# 29                 KNN    137         MCAR             0.01
# ...                ...    ...          ...              ...
# 2197     Random Forest  42493         MCAR              0.5
# 2201         Mean/Mode  42493         MNAR             0.01
# 2208         Mean/Mode  42493         MNAR              0.1
# 2215         Mean/Mode  42493         MNAR              0.3
# 2221               VAE  42493         MNAR              0.5
#
#                  Column                  result_type                metric  \
# 5     top-middle-square  downstream_performance_mean  Classification Tasks
# 11    top-middle-square  downstream_performance_mean  Classification Tasks
# 17    top-middle-square  downstream_performance_mean  Classification Tasks
# 23    top-middle-square  downstream_performance_mean  Classification Tasks
# 29    top-middle-square  downstream_performance_mean  Classification Tasks
# ...                 ...                          ...                   ...
# 2197             Length  downstream_performance_mean  Classification Tasks
# 2201             Length  downstream_performance_mean  Classification Tasks
# 2208             Length  downstream_performance_mean  Classification Tasks
# 2215             Length  downstream_performance_mean  Classification Tasks
# 2221             Length  downstream_performance_mean  Classification Tasks
#
#       Baseline  Corrupted  Imputed_Subset  ...              name  \
# 5     0.699699        0.0        0.699699  ...  BNG(tic-tac-toe)
# 11    0.700844        0.0        0.700844  ...  BNG(tic-tac-toe)
# 17    0.702163        0.0        0.700799  ...  BNG(tic-tac-toe)
# 23    0.705702        0.0        0.706240  ...  BNG(tic-tac-toe)
# 29    0.699217        0.0        0.699217  ...  BNG(tic-tac-toe)
# ...        ...        ...             ...  ...               ...
# 2197  0.606068        0.0        0.606759  ...          airlines
# 2201  0.614237        0.0        0.614237  ...          airlines
# 2208  0.612068        0.0        0.614235  ...          airlines
# 2215  0.598213        0.0        0.600125  ...          airlines
# 2221  0.610725        0.0        0.611129  ...          airlines
#
#      MajorityClassSize  MinorityClassSize  NumberOfFeatures  \
# 5              25702.0            13664.0              10.0
# 11             25702.0            13664.0              10.0
# 17             25702.0            13664.0              10.0
# 23             25702.0            13664.0              10.0
# 29             25702.0            13664.0              10.0
# ...                ...                ...               ...
# 2197           14934.0            12035.0               8.0
# 2201           14934.0            12035.0               8.0
# 2208           14934.0            12035.0               8.0
# 2215           14934.0            12035.0               8.0
# 2221           14934.0            12035.0               8.0
#
#       NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 5               39366.0                      0.0                         10.0
# 11              39366.0                      0.0                         10.0
# 17              39366.0                      0.0                         10.0
# 23              39366.0                      0.0                         10.0
# 29              39366.0                      0.0                         10.0
# ...                 ...                      ...                          ...
# 2197            26969.0                      2.0                          6.0
# 2201            26969.0                      2.0                          6.0
# 2208            26969.0                      2.0                          6.0
# 2215            26969.0                      2.0                          6.0
# 2221            26969.0                      2.0                          6.0
#
#       NumberOfClasses  Downstream Performance Rank Subset  Data_Constellation
# 5                 NaN                                 1.0          MAR - 0.01
# 11                NaN                                 1.0           MAR - 0.1
# 17                NaN                                 1.0           MAR - 0.3
# 23                NaN                                 1.0           MAR - 0.5
# 29                NaN                                 1.0         MCAR - 0.01
# ...               ...                                 ...                 ...
# 2197              NaN                                 1.0          MCAR - 0.5
# 2201              NaN                                 1.0         MNAR - 0.01
# 2208              NaN                                 1.0          MNAR - 0.1
# 2215              NaN                                 1.0          MNAR - 0.3
# 2221              NaN                                 1.0          MNAR - 0.5
#
# [372 rows x 21 columns]

# %%
# Dataset for Training 
properties_train_dataset_1 = rank_1_backup.copy()
properties_train_dataset_1 = properties_train_dataset_1[['Imputation_Method','Missing Type','Missing Fraction',
                                                         'NumberOfInstances','NumberOfFeatures','NumberOfNumericFeatures',
                                                         'NumberOfCategoricalFeatures','metric']]

properties_train_dataset_1
# Out:
#      Imputation_Method Missing Type Missing Fraction  NumberOfInstances  \
# 5                  VAE          MAR             0.01            39366.0
# 11                 VAE          MAR              0.1            39366.0
# 17                 VAE          MAR              0.3            39366.0
# 23                 KNN          MAR              0.5            39366.0
# 29                 KNN         MCAR             0.01            39366.0
# ...                ...          ...              ...                ...
# 2197     Random Forest         MCAR              0.5            26969.0
# 2201         Mean/Mode         MNAR             0.01            26969.0
# 2208         Mean/Mode         MNAR              0.1            26969.0
# 2215         Mean/Mode         MNAR              0.3            26969.0
# 2221               VAE         MNAR              0.5            26969.0
#
#       NumberOfFeatures  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 5                 10.0                      0.0                         10.0
# 11                10.0                      0.0                         10.0
# 17                10.0                      0.0                         10.0
# 23                10.0                      0.0                         10.0
# 29                10.0                      0.0                         10.0
# ...                ...                      ...                          ...
# 2197               8.0                      2.0                          6.0
# 2201               8.0                      2.0                          6.0
# 2208               8.0                      2.0                          6.0
# 2215               8.0                      2.0                          6.0
# 2221               8.0                      2.0                          6.0
#
#                     metric
# 5     Classification Tasks
# 11    Classification Tasks
# 17    Classification Tasks
# 23    Classification Tasks
# 29    Classification Tasks
# ...                    ...
# 2197  Classification Tasks
# 2201  Classification Tasks
# 2208  Classification Tasks
# 2215  Classification Tasks
# 2221  Classification Tasks
#
# [372 rows x 8 columns]

# %%
# Dataset for Training 
properties_train_dataset_7 = rank_1_backup.copy()
properties_train_dataset_7 = properties_train_dataset_7[['Imputation_Method','Missing Type','Missing Fraction',
                                                         'NumberOfInstances','NumberOfFeatures','NumberOfNumericFeatures',
                                                         'NumberOfCategoricalFeatures']]

properties_train_dataset_7
properties_train_dataset_7.to_csv('binary_properties_train_dataset_7.csv', index=False)

# %%
# Dataset for Training

# %%
# Dataset for Training
