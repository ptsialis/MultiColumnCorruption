# %% [markdown]
# # Visualize Results: Downstream Performance - Subset Regression Corrupted Experiments - Training and Test identically imputed
#
# This notebook should answer the questions: *Does imputation lead to better downstream performances?*
#
# Data needs to be preprocessed with other notebook, her we only import two csv files with raw data regarding the results of the experiment and information about the used datasets!
#
# ## Notebook Structure
#
# * Application Scenario 2 - Downstream Performance
#    * Categorical  Columns (Classification)
#    * Numerical Columns (Regression)
#    * Heterogenous Columns (Classification and Regression Combined)

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import seaborn as sns
from pandas.api.types import CategoricalDtype
from pathlib import Path

import plotly as py
import plotly.express as px
import plotly.graph_objects as go
import xarray as xr


# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Settings

# %%
sns.set(style="whitegrid")
sns.set_context('paper', font_scale=1.5)
mpl.rcParams['lines.linewidth'] = '2'

# %%
CLF_METRIC = "Classification Tasks"
REG_METRIC = "Regression Tasks"

DOWNSTREAM_RESULT_TYPE = "downstream_performance_mean"
IMPUTE_RESULT_TYPE = "impute_performance_mean"

# %% [markdown]
# ## Data Preparation

# %%
# import preprocessed data from experiments
results = pd.read_csv('../regression_corrupted_subset.csv')
results
# Out:
#                                    experiment           imputer   task  \
# 0      corrupted_regression_experiment_subset  AutoKerasImputer   1193
# 1      corrupted_regression_experiment_subset  AutoKerasImputer   1193
# 2      corrupted_regression_experiment_subset  AutoKerasImputer   1193
# 3      corrupted_regression_experiment_subset  AutoKerasImputer   1193
# 4      corrupted_regression_experiment_subset  AutoKerasImputer   1193
# ...                                       ...               ...    ...
# 16351  corrupted_regression_experiment_subset        VAEImputer  42712
# 16352  corrupted_regression_experiment_subset        VAEImputer  42712
# 16353  corrupted_regression_experiment_subset        VAEImputer  42712
# 16354  corrupted_regression_experiment_subset        VAEImputer  42712
# 16355  corrupted_regression_experiment_subset        VAEImputer  42712
#
#       missing_type  missing_fraction       strategy    column  \
# 0              MAR              0.01  single_single        UI
# 1              MAR              0.01  single_single        UI
# 2              MAR              0.01  single_single        UI
# 3              MAR              0.10  single_single        UI
# 4              MAR              0.10  single_single        UI
# ...            ...               ...            ...       ...
# 16351         MNAR              0.30  single_single  humidity
# 16352         MNAR              0.30  single_single  humidity
# 16353         MNAR              0.50  single_single  humidity
# 16354         MNAR              0.50  single_single  humidity
# 16355         MNAR              0.50  single_single  humidity
#
#                        result_type       metric     train      test  \
# 0           impute_performance_std     F1_micro  0.104859  0.166667
# 1           impute_performance_std     F1_macro  0.030502  0.331787
# 2           impute_performance_std  F1_weighted  0.132946  0.233392
# 3           impute_performance_std     F1_micro  0.022208  0.018624
# 4           impute_performance_std     F1_macro  0.018480  0.005607
# ...                            ...          ...       ...       ...
# 16351  downstream_performance_mean          MSE       NaN       NaN
# 16352  downstream_performance_mean         RMSE       NaN       NaN
# 16353  downstream_performance_mean          MAE       NaN       NaN
# 16354  downstream_performance_mean          MSE       NaN       NaN
# 16355  downstream_performance_mean         RMSE       NaN       NaN
#
#            baseline  corrupted       imputed
# 0               NaN        NaN           NaN
# 1               NaN        NaN           NaN
# 2               NaN        NaN           NaN
# 3               NaN        NaN           NaN
# 4               NaN        NaN           NaN
# ...             ...        ...           ...
# 16351  41260.047742        0.0  41161.709063
# 16352    203.125694        0.0    202.883274
# 16353    142.297340        0.0    142.566134
# 16354  42233.843610        0.0  42104.473121
# 16355    205.508743        0.0    205.193612
#
# [16356 rows x 14 columns]

# %%
# Filtering the relevant data for downstream analysis

na_impute_results = results[
    (results["result_type"] == IMPUTE_RESULT_TYPE) & 
    (results["metric"].isin(["F1_macro", "RMSE"]))
]
na_impute_results.drop(["baseline", "corrupted", "imputed"], axis=1, inplace=True)
na_impute_results = na_impute_results[na_impute_results.isna().any(axis=1)]
na_impute_results.shape
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3401284833.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (0, 11)

# %%
# check if strategy type is correct!
STRATEGY_TYPE = "single_single"

downstream_results = results[
    (results["result_type"] == DOWNSTREAM_RESULT_TYPE) & 
    (results["metric"].isin(["F1_macro", "RMSE"]) &
    (results["strategy"] == STRATEGY_TYPE))
]

# remove experiments where imputation failed
downstream_results = downstream_results.merge(
    na_impute_results,
    how = "left",
    validate = "one_to_one",
    indicator = True,
    suffixes=("", "_imp"),
    on = ["experiment", "imputer", "task", "missing_type", "missing_fraction", "strategy", "column"]
)
downstream_results = downstream_results[downstream_results["_merge"]=="left_only"]

assert len(results["strategy"].unique()) == 1
downstream_results.drop(["experiment", "strategy", "result_type_imp", "metric_imp", "train", "test", "train_imp", "test_imp", "_merge"], axis=1, inplace=True)

downstream_results = downstream_results.rename(
    {
        "imputer": "Imputation_Method",
        "task": "Task",
        "missing_type": "Missing Type",
        "missing_fraction": "Missing Fraction",
        "column": "Column",
        "baseline": "Baseline",
        "imputed": "Imputed_Subset",
        "corrupted": "Corrupted"
    },
    axis = 1
)

# %%
rename_imputer_dict = {
    "ModeImputer": "Mean/Mode",
    "KNNImputer": "KNN",
    "ForestImputer": "Random Forest",
    "AutoKerasImputer": "Discriminative DL",
    "VAEImputer": "VAE",
    "GAINImputer": "GAIN"    
}

rename_metric_dict = {
    "F1_macro": CLF_METRIC,
    "RMSE": REG_METRIC
}

downstream_results = downstream_results.replace(rename_imputer_dict)
downstream_results = downstream_results.replace(rename_metric_dict)

downstream_results
# Out:
#       Imputation_Method   Task Missing Type  Missing Fraction    Column  \
# 0     Discriminative DL   1193          MAR              0.01        UI
# 1     Discriminative DL   1193          MAR              0.10        UI
# 2     Discriminative DL   1193          MAR              0.30        UI
# 3     Discriminative DL   1193          MAR              0.50        UI
# 4     Discriminative DL   1193         MCAR              0.01        UI
# ...                 ...    ...          ...               ...       ...
# 1358                VAE  42712         MCAR              0.50  humidity
# 1359                VAE  42712         MNAR              0.01  humidity
# 1360                VAE  42712         MNAR              0.10  humidity
# 1361                VAE  42712         MNAR              0.30  humidity
# 1362                VAE  42712         MNAR              0.50  humidity
#
#                       result_type            metric     Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks  2613.702746        0.0
# 1     downstream_performance_mean  Regression Tasks  2612.665083        0.0
# 2     downstream_performance_mean  Regression Tasks  2612.800424        0.0
# 3     downstream_performance_mean  Regression Tasks  2602.835281        0.0
# 4     downstream_performance_mean  Regression Tasks  2613.753370        0.0
# ...                           ...               ...          ...        ...
# 1358  downstream_performance_mean  Regression Tasks   207.034176        0.0
# 1359  downstream_performance_mean  Regression Tasks   205.240220        0.0
# 1360  downstream_performance_mean  Regression Tasks   206.106059        0.0
# 1361  downstream_performance_mean  Regression Tasks   203.125694        0.0
# 1362  downstream_performance_mean  Regression Tasks   205.508743        0.0
#
#       Imputed_Subset
# 0        2613.755498
# 1        2612.399437
# 2        2611.966134
# 3        2603.440521
# 4        2613.789726
# ...              ...
# 1358      206.944226
# 1359      205.369466
# 1360      206.459887
# 1361      202.883274
# 1362      205.193612
#
# [1363 rows x 10 columns]

# %% [markdown]
# ### Robustness: check which imputers yielded `NaN`values

# %%
for col in downstream_results.columns:
    na_sum = downstream_results[col].isna().sum()
    if na_sum > 0:
        print("-----" * 10)        
        print(col, na_sum)
        print("-----" * 10)        
        na_idx = downstream_results[col].isna()
        print(downstream_results.loc[na_idx, "Imputation Method"].value_counts(dropna=False))
        print("\n")

# %% [markdown]
# ## Adding Dataset Info, Sorting and Ranking

# %%
clf_row_idx = downstream_results["metric"] == CLF_METRIC
reg_row_idx = downstream_results["metric"] == REG_METRIC

# Sorting of data

#adjust order to fit the processing time -> fastest first
methods_order = CategoricalDtype(['Mean/Mode', 'KNN', 'Random Forest', 'VAE', 'GAIN', 'Discriminative DL'], ordered=True)
downstream_results_full_sort = downstream_results.copy()

downstream_results_full_sort['Imputation_Method'] = downstream_results_full_sort['Imputation_Method'].astype(methods_order)
downstream_results_full_sort = downstream_results_full_sort.sort_values(['Task', 'Missing Type',
                                                                         'Missing Fraction', 'Imputed_Subset','Imputation_Method'], ascending=[True, True, True, True, True])


downstream_results.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction Column  \
# 0  Discriminative DL  1193          MAR              0.01     UI
# 1  Discriminative DL  1193          MAR              0.10     UI
# 2  Discriminative DL  1193          MAR              0.30     UI
# 3  Discriminative DL  1193          MAR              0.50     UI
# 4  Discriminative DL  1193         MCAR              0.01     UI
#
#                    result_type            metric     Baseline  Corrupted  \
# 0  downstream_performance_mean  Regression Tasks  2613.702746        0.0
# 1  downstream_performance_mean  Regression Tasks  2612.665083        0.0
# 2  downstream_performance_mean  Regression Tasks  2612.800424        0.0
# 3  downstream_performance_mean  Regression Tasks  2602.835281        0.0
# 4  downstream_performance_mean  Regression Tasks  2613.753370        0.0
#
#    Imputed_Subset
# 0     2613.755498
# 1     2612.399437
# 2     2611.966134
# 3     2603.440521
# 4     2613.789726

# %%
#downstream_results_full_sort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1363 entries, 955 to 906
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Imputation_Method  1363 non-null   category
#  1   Task               1363 non-null   int64
#  2   Missing Type       1363 non-null   object
#  3   Missing Fraction   1363 non-null   float64
#  4   Column             1363 non-null   object
#  5   result_type        1363 non-null   object
#  6   metric             1363 non-null   object
#  7   Baseline           1363 non-null   float64
#  8   Corrupted          1363 non-null   float64
#  9   Imputed_Subset     1363 non-null   float64
# dtypes: category(1), float64(4), int64(1), object(4)
# memory usage: 108.0+ KB

# %%
# add dataset information from other csv file
dataset_info = pd.read_csv('../datasets_information_overview.csv')
dataset_info = dataset_info.rename(columns={"did": "Task"})


downstream_results_full_sort = pd.merge(downstream_results_full_sort, dataset_info, on='Task')
downstream_results_full_sort.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction  Column  \
# 0          Mean/Mode   189          MAR              0.01  theta8
# 1                KNN   189          MAR              0.01  theta8
# 2                VAE   189          MAR              0.01  theta8
# 3  Discriminative DL   189          MAR              0.01  theta8
# 4               GAIN   189          MAR              0.01  theta8
#
#                    result_type            metric  Baseline  Corrupted  \
# 0  downstream_performance_mean  Regression Tasks  0.225185        0.0
# 1  downstream_performance_mean  Regression Tasks  0.225176        0.0
# 2  downstream_performance_mean  Regression Tasks  0.225180        0.0
# 3  downstream_performance_mean  Regression Tasks  0.225196        0.0
# 4  downstream_performance_mean  Regression Tasks  0.225167        0.0
#
#    Imputed_Subset  Unnamed: 0    name  MajorityClassSize  MinorityClassSize  \
# 0        0.224662          67  kin8nm                NaN                NaN
# 1        0.224708          67  kin8nm                NaN                NaN
# 2        0.225196          67  kin8nm                NaN                NaN
# 3        0.225248          67  kin8nm                NaN                NaN
# 4        0.225407          67  kin8nm                NaN                NaN
#
#    NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0               9.0             8192.0                      9.0
# 1               9.0             8192.0                      9.0
# 2               9.0             8192.0                      9.0
# 3               9.0             8192.0                      9.0
# 4               9.0             8192.0                      9.0
#
#    NumberOfCategoricalFeatures  NumberOfClasses
# 0                          0.0              NaN
# 1                          0.0              NaN
# 2                          0.0              NaN
# 3                          0.0              NaN
# 4                          0.0              NaN

# %%
# Ranking of downstream performance per data constellation for every imputation method

EXPERIMENTAL_CONDITIONS = ["Task", "Missing Type", "Missing Fraction", "Column", "result_type"]

downstream_results_rank = downstream_results_full_sort.copy()

downstream_results_rank["Downstream Performance Rank Subset"] = downstream_results_rank.groupby(EXPERIMENTAL_CONDITIONS).rank(ascending=True, na_option="bottom", method="first")["Imputed_Subset"]
# create csv for detailled checks
downstream_results_rank.to_csv('downstream_results_complete_overview.csv')
downstream_results_rank.head()
# Out:
#    Imputation_Method  Task Missing Type  Missing Fraction  Column  \
# 0          Mean/Mode   189          MAR              0.01  theta8
# 1                KNN   189          MAR              0.01  theta8
# 2                VAE   189          MAR              0.01  theta8
# 3  Discriminative DL   189          MAR              0.01  theta8
# 4               GAIN   189          MAR              0.01  theta8
#
#                    result_type            metric  Baseline  Corrupted  \
# 0  downstream_performance_mean  Regression Tasks  0.225185        0.0
# 1  downstream_performance_mean  Regression Tasks  0.225176        0.0
# 2  downstream_performance_mean  Regression Tasks  0.225180        0.0
# 3  downstream_performance_mean  Regression Tasks  0.225196        0.0
# 4  downstream_performance_mean  Regression Tasks  0.225167        0.0
#
#    Imputed_Subset  Unnamed: 0    name  MajorityClassSize  MinorityClassSize  \
# 0        0.224662          67  kin8nm                NaN                NaN
# 1        0.224708          67  kin8nm                NaN                NaN
# 2        0.225196          67  kin8nm                NaN                NaN
# 3        0.225248          67  kin8nm                NaN                NaN
# 4        0.225407          67  kin8nm                NaN                NaN
#
#    NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0               9.0             8192.0                      9.0
# 1               9.0             8192.0                      9.0
# 2               9.0             8192.0                      9.0
# 3               9.0             8192.0                      9.0
# 4               9.0             8192.0                      9.0
#
#    NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                          0.0              NaN
# 1                          0.0              NaN
# 2                          0.0              NaN
# 3                          0.0              NaN
# 4                          0.0              NaN
#
#    Downstream Performance Rank Subset
# 0                                 1.0
# 1                                 2.0
# 2                                 3.0
# 3                                 4.0
# 4                                 5.0

# %%
# Adjust column type for Imputation_Method
downstream_results_rank['Imputation_Method'] = downstream_results_rank['Imputation_Method'].astype('object')

#downstream_results_rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1363 entries, 0 to 1362
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Imputation_Method                   1363 non-null   object
#  1   Task                                1363 non-null   int64
#  2   Missing Type                        1363 non-null   object
#  3   Missing Fraction                    1363 non-null   float64
#  4   Column                              1363 non-null   object
#  5   result_type                         1363 non-null   object
#  6   metric                              1363 non-null   object
#  7   Baseline                            1363 non-null   float64
#  8   Corrupted                           1363 non-null   float64
#  9   Imputed_Subset                      1363 non-null   float64
#  10  Unnamed: 0                          1363 non-null   int64
#  11  name                                1363 non-null   object
#  12  MajorityClassSize                   0 non-null      float64
#  13  MinorityClassSize                   0 non-null      float64
#  14  NumberOfFeatures                    1363 non-null   float64
#  15  NumberOfInstances                   1363 non-null   float64
#  16  NumberOfNumericFeatures             1363 non-null   float64
#  17  NumberOfCategoricalFeatures         1363 non-null   float64
#  18  NumberOfClasses                     0 non-null      float64
#  19  Downstream Performance Rank Subset  1363 non-null   float64
# dtypes: float64(12), int64(2), object(6)
# memory usage: 223.6+ KB

# %%
# Merge the two columns "Missing Type" and "Missing Fraction"

downstream_results_rank['Missing Type'] = downstream_results_rank['Missing Type'].astype(str)
downstream_results_rank['Missing Fraction'] = downstream_results_rank['Missing Fraction'].astype(str)
#datatype_new = downstream_results_rank.dtypes

downstream_results_rank['Data_Constellation'] = downstream_results_rank['Missing Type'] + ' - ' + downstream_results_rank['Missing Fraction']
#downstream_results_rank.to_csv('downstream_results_rank_temp.csv')
downstream_results_rank_heatmap2 = downstream_results_rank.copy()
downstream_results_rank.head()
# Out:
#    Imputation_Method  Task Missing Type Missing Fraction  Column  \
# 0          Mean/Mode   189          MAR             0.01  theta8
# 1                KNN   189          MAR             0.01  theta8
# 2                VAE   189          MAR             0.01  theta8
# 3  Discriminative DL   189          MAR             0.01  theta8
# 4               GAIN   189          MAR             0.01  theta8
#
#                    result_type            metric  Baseline  Corrupted  \
# 0  downstream_performance_mean  Regression Tasks  0.225185        0.0
# 1  downstream_performance_mean  Regression Tasks  0.225176        0.0
# 2  downstream_performance_mean  Regression Tasks  0.225180        0.0
# 3  downstream_performance_mean  Regression Tasks  0.225196        0.0
# 4  downstream_performance_mean  Regression Tasks  0.225167        0.0
#
#    Imputed_Subset  ...    name MajorityClassSize  MinorityClassSize  \
# 0        0.224662  ...  kin8nm               NaN                NaN
# 1        0.224708  ...  kin8nm               NaN                NaN
# 2        0.225196  ...  kin8nm               NaN                NaN
# 3        0.225248  ...  kin8nm               NaN                NaN
# 4        0.225407  ...  kin8nm               NaN                NaN
#
#    NumberOfFeatures  NumberOfInstances  NumberOfNumericFeatures  \
# 0               9.0             8192.0                      9.0
# 1               9.0             8192.0                      9.0
# 2               9.0             8192.0                      9.0
# 3               9.0             8192.0                      9.0
# 4               9.0             8192.0                      9.0
#
#    NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                          0.0              NaN
# 1                          0.0              NaN
# 2                          0.0              NaN
# 3                          0.0              NaN
# 4                          0.0              NaN
#
#    Downstream Performance Rank Subset  Data_Constellation
# 0                                 1.0          MAR - 0.01
# 1                                 2.0          MAR - 0.01
# 2                                 3.0          MAR - 0.01
# 3                                 4.0          MAR - 0.01
# 4                                 5.0          MAR - 0.01
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Analyzing Performance based on Rank per Data Constellation

# %%
data = downstream_results_rank.copy()

# Count amount of different Data constellations in column "Data_Constellation"
dc_unique = data.Data_Constellation.unique().size
print(dc_unique, "Data Constellations")
print("_____________________")
# Count amount of 1.0 Ranking result in column "Downstream Performance Rank" (Numbers must match)
rank_count = data['Downstream Performance Rank Subset'].value_counts()
print(rank_count)
print("_____________________")
# Filter for 1.0 Ranking -> Overview -> save as csv
rank_1 = data.loc[data['Downstream Performance Rank Subset'] == 1.0]
rank_1.to_csv('rank_1.csv')

print("_____________________")
# Count how often each Imputation Method is present -> most "wins"
rank_wins = rank_1['Imputation_Method'].value_counts()
print(rank_wins)
print("_____________________")
# Take initial overview and filter for each imputation method and calculate average rank
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
for i in methods:
    df_average_rank = data.loc[data['Imputation_Method'] == i]
    len_ar = len(df_average_rank)
    print(len_ar, "Amount of results available")
    rank_pos = df_average_rank['Downstream Performance Rank Subset'].value_counts().sort_index(ascending=True)
    print(rank_pos)
    average_rank = df_average_rank["Downstream Performance Rank Subset"].mean()
    print("Average Rank for", i, "is", average_rank)
# Out:
# 12 Data Constellations
# _____________________
# 1.0    228
# 2.0    228
# 3.0    228
# 4.0    228
# 5.0    228
# 6.0    223
# Name: Downstream Performance Rank Subset, dtype: int64
# _____________________
# _____________________
# Random Forest        47
# VAE                  45
# Mean/Mode            40
# KNN                  34
# Discriminative DL    31
# GAIN                 31
# Name: Imputation_Method, dtype: int64
# _____________________
# 228 Amount of results available
# 1.0    47
# 2.0    44
# 3.0    35
# 4.0    45
# 5.0    29
# 6.0    28
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for Random Forest is 3.2149122807017543
# _____________________
# 228 Amount of results available
# 1.0    34
# 2.0    42
# 3.0    39
# 4.0    40
# 5.0    45
# 6.0    28
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for KNN is 3.456140350877193
# _____________________
# 228 Amount of results available
# 1.0    40
# 2.0    36
# 3.0    33
# 4.0    47
# 5.0    37
# 6.0    35
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for Mean/Mode is 3.482456140350877
# _____________________
# 228 Amount of results available
# 1.0    45
# 2.0    39
# 3.0    23
# 4.0    23
# 5.0    52
# 6.0    46
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for VAE is 3.5964912280701755
# _____________________
# 228 Amount of results available
# 1.0    31
# 2.0    25
# 3.0    38
# 4.0    38
# 5.0    33
# 6.0    63
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for GAIN is 3.9035087719298245
# _____________________
# 223 Amount of results available
# 1.0    31
# 2.0    42
# 3.0    60
# 4.0    35
# 5.0    32
# 6.0    23
# Name: Downstream Performance Rank Subset, dtype: int64
# Average Rank for Discriminative DL is 3.286995515695067
# _____________________

# %%
rank_1_backup = rank_1.copy()
rank_1
# Out:
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 0             Mean/Mode    189          MAR             0.01    theta8
# 6     Discriminative DL    189          MAR              0.1    theta8
# 12                  KNN    189          MAR              0.3    theta8
# 18    Discriminative DL    189          MAR              0.5    theta8
# 24    Discriminative DL    189         MCAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1333      Random Forest  42712         MCAR              0.5  humidity
# 1339      Random Forest  42712         MNAR             0.01  humidity
# 1345      Random Forest  42712         MNAR              0.1  humidity
# 1351                VAE  42712         MNAR              0.3  humidity
# 1357      Random Forest  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks    0.225185        0.0
# 6     downstream_performance_mean  Regression Tasks    0.225352        0.0
# 12    downstream_performance_mean  Regression Tasks    0.226497        0.0
# 18    downstream_performance_mean  Regression Tasks    0.225885        0.0
# 24    downstream_performance_mean  Regression Tasks    0.225430        0.0
# ...                           ...               ...         ...        ...
# 1333  downstream_performance_mean  Regression Tasks  204.349055        0.0
# 1339  downstream_performance_mean  Regression Tasks  205.186741        0.0
# 1345  downstream_performance_mean  Regression Tasks  205.419418        0.0
# 1351  downstream_performance_mean  Regression Tasks  203.125694        0.0
# 1357  downstream_performance_mean  Regression Tasks  203.690837        0.0
#
#       Imputed_Subset  ...                 name MajorityClassSize  \
# 0           0.224662  ...               kin8nm               NaN
# 6           0.224106  ...               kin8nm               NaN
# 12          0.223568  ...               kin8nm               NaN
# 18          0.223194  ...               kin8nm               NaN
# 24          0.225247  ...               kin8nm               NaN
# ...              ...  ...                  ...               ...
# 1333      204.639271  ...  Bike_Sharing_Demand               NaN
# 1339      205.211177  ...  Bike_Sharing_Demand               NaN
# 1345      205.400159  ...  Bike_Sharing_Demand               NaN
# 1351      202.883274  ...  Bike_Sharing_Demand               NaN
# 1357      202.581392  ...  Bike_Sharing_Demand               NaN
#
#       MinorityClassSize  NumberOfFeatures  NumberOfInstances  \
# 0                   NaN               9.0             8192.0
# 6                   NaN               9.0             8192.0
# 12                  NaN               9.0             8192.0
# 18                  NaN               9.0             8192.0
# 24                  NaN               9.0             8192.0
# ...                 ...               ...                ...
# 1333                NaN              13.0            17379.0
# 1339                NaN              13.0            17379.0
# 1345                NaN              13.0            17379.0
# 1351                NaN              13.0            17379.0
# 1357                NaN              13.0            17379.0
#
#       NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                         9.0                          0.0              NaN
# 6                         9.0                          0.0              NaN
# 12                        9.0                          0.0              NaN
# 18                        9.0                          0.0              NaN
# 24                        9.0                          0.0              NaN
# ...                       ...                          ...              ...
# 1333                      9.0                          4.0              NaN
# 1339                      9.0                          4.0              NaN
# 1345                      9.0                          4.0              NaN
# 1351                      9.0                          4.0              NaN
# 1357                      9.0                          4.0              NaN
#
#       Downstream Performance Rank Subset  Data_Constellation
# 0                                    1.0          MAR - 0.01
# 6                                    1.0           MAR - 0.1
# 12                                   1.0           MAR - 0.3
# 18                                   1.0           MAR - 0.5
# 24                                   1.0         MCAR - 0.01
# ...                                  ...                 ...
# 1333                                 1.0          MCAR - 0.5
# 1339                                 1.0         MNAR - 0.01
# 1345                                 1.0          MNAR - 0.1
# 1351                                 1.0          MNAR - 0.3
# 1357                                 1.0          MNAR - 0.5
#
# [228 rows x 21 columns]

# %% [markdown]
# ## Set Average Best Imputation Method Manually

# %%
# SET AVERAGE BEST IMPUTATION METHOD HERE, BASED ON THE PREVIOUS RESULTS
# Alternatively you can define a baseline method here, which will be used instead, depending on your analysis goals

AVERAGE_BEST_IMPUTATION_METHOD = "Random Forest"

# %% [markdown]
# ## Differences in Performance Relative to Average Best Imputation Method

# %%
av_best = data.loc[data['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
av_best['Task'] = av_best['Task'].astype(str)
av_best['Data_Constellation'] = av_best['Data_Constellation'] + ' - ' + av_best['Task']

av_best = av_best[['Imputation_Method', 'Imputed_Subset', 'Data_Constellation', 'Downstream Performance Rank Subset']]
av_best = av_best.rename(columns={'Imputation_Method':'Imputation_Method_average', 
                               'Imputed_Subset':'Imputed_average_Subset',
                                 'Downstream Performance Rank Subset':'Downstream Performance Rank Average Subset'})


rank_1['Task'] = rank_1['Task'].astype(str)
rank_1['Data_Constellation'] = rank_1['Data_Constellation'] + ' - ' + rank_1['Task']
rank_1 = rank_1[['Imputation_Method', 'Imputed_Subset', 'Data_Constellation', 'Downstream Performance Rank Subset']]
rank_1 = rank_1.rename(columns={'Imputation_Method':'Imputation_Method_best', 
                               'Imputed_Subset':'Imputed_best_Subset',
                               'Downstream Performance Rank Subset':'Downstream Performance Rank Best Subset'})

performance_difference = pd.merge(av_best, rank_1, on='Data_Constellation')
#performance_difference.head()
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\2223696874.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\2223696874.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\2223696874.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\2223696874.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Calculate the difference between the best imputation method for each data constellation to the average best imputation method in F1 score
performance_difference['Performance Difference Best to Average'] = performance_difference['Imputed_best_Subset'] - performance_difference['Imputed_average_Subset']
Average_Difference = performance_difference['Performance Difference Best to Average'].mean()
print("Average Difference in Improvement from best method to average best method for RMSE", Average_Difference)
# Out:
# Average Difference in Improvement from best method to average best method for RMSE -0.12004634403392152

# %%
performance_difference.to_csv('performance_difference.csv')
performance_difference.head()
# Out:
#   Imputation_Method_average  Imputed_average_Subset Data_Constellation  \
# 0             Random Forest                0.225470   MAR - 0.01 - 189
# 1             Random Forest                0.225864    MAR - 0.1 - 189
# 2             Random Forest                0.226752    MAR - 0.3 - 189
# 3             Random Forest                0.223393    MAR - 0.5 - 189
# 4             Random Forest                0.225389  MCAR - 0.01 - 189
#
#    Downstream Performance Rank Average Subset Imputation_Method_best  \
# 0                                         6.0              Mean/Mode
# 1                                         5.0      Discriminative DL
# 2                                         6.0                    KNN
# 3                                         3.0      Discriminative DL
# 4                                         5.0      Discriminative DL
#
#    Imputed_best_Subset  Downstream Performance Rank Best Subset  \
# 0             0.224662                                      1.0
# 1             0.224106                                      1.0
# 2             0.223568                                      1.0
# 3             0.223194                                      1.0
# 4             0.225247                                      1.0
#
#    Performance Difference Best to Average
# 0                               -0.000808
# 1                               -0.001758
# 2                               -0.003184
# 3                               -0.000199
# 4                               -0.000142

# %% [markdown]
# ## Analysis and Ranking based on F1 Score

# %%
# Relative Difference in Percent -> Best Method to Average Best Method

data = downstream_results_rank.copy()
data['Task'] = data['Task'].astype(str)
data['Data_Constellation_full'] = data['Data_Constellation'] + ' - ' + data['Task']

dc_unique = data.Data_Constellation_full.unique()

data_constellations = dc_unique.tolist()
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
average_best_complete = pd.DataFrame()


for i in data_constellations:
    data_constel = data.loc[data['Data_Constellation_full'] == i]
    best_score = data_constel.loc[data_constel['Downstream Performance Rank Subset'] == 1.0]
    average_best = data_constel.loc[data_constel['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
    best_score_int = best_score.iloc[0]['Imputed_Subset']
    average_best_int = average_best.iloc[0]['Imputed_Subset']
    calc_result = ((best_score_int - average_best_int)/best_score_int)
    calc_result = abs(calc_result)
    average_best['Performance Difference to Best to Average in Percent'] = calc_result
    average_best_complete = average_best_complete.append(average_best)

average_best_complete
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# ...
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:22: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\1136548942.py:23: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#      Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 5        Random Forest    189          MAR             0.01    theta8
# 10       Random Forest    189          MAR              0.1    theta8
# 17       Random Forest    189          MAR              0.3    theta8
# 20       Random Forest    189          MAR              0.5    theta8
# 28       Random Forest    189         MCAR             0.01    theta8
# ...                ...    ...          ...              ...       ...
# 1333     Random Forest  42712         MCAR              0.5  humidity
# 1339     Random Forest  42712         MNAR             0.01  humidity
# 1345     Random Forest  42712         MNAR              0.1  humidity
# 1352     Random Forest  42712         MNAR              0.3  humidity
# 1357     Random Forest  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 5     downstream_performance_mean  Regression Tasks    0.225190        0.0
# 10    downstream_performance_mean  Regression Tasks    0.226175        0.0
# 17    downstream_performance_mean  Regression Tasks    0.227089        0.0
# 20    downstream_performance_mean  Regression Tasks    0.225029        0.0
# 28    downstream_performance_mean  Regression Tasks    0.225486        0.0
# ...                           ...               ...         ...        ...
# 1333  downstream_performance_mean  Regression Tasks  204.349055        0.0
# 1339  downstream_performance_mean  Regression Tasks  205.186741        0.0
# 1345  downstream_performance_mean  Regression Tasks  205.419418        0.0
# 1352  downstream_performance_mean  Regression Tasks  203.211946        0.0
# 1357  downstream_performance_mean  Regression Tasks  203.690837        0.0
#
#       Imputed_Subset  ...  MinorityClassSize NumberOfFeatures  \
# 5           0.225470  ...                NaN              9.0
# 10          0.225864  ...                NaN              9.0
# 17          0.226752  ...                NaN              9.0
# 20          0.223393  ...                NaN              9.0
# 28          0.225389  ...                NaN              9.0
# ...              ...  ...                ...              ...
# 1333      204.639271  ...                NaN             13.0
# 1339      205.211177  ...                NaN             13.0
# 1345      205.400159  ...                NaN             13.0
# 1352      202.969127  ...                NaN             13.0
# 1357      202.581392  ...                NaN             13.0
#
#       NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 5                8192.0                      9.0                          0.0
# 10               8192.0                      9.0                          0.0
# 17               8192.0                      9.0                          0.0
# 20               8192.0                      9.0                          0.0
# 28               8192.0                      9.0                          0.0
# ...                 ...                      ...                          ...
# 1333            17379.0                      9.0                          4.0
# 1339            17379.0                      9.0                          4.0
# 1345            17379.0                      9.0                          4.0
# 1352            17379.0                      9.0                          4.0
# 1357            17379.0                      9.0                          4.0
#
#       NumberOfClasses  Downstream Performance Rank Subset  Data_Constellation  \
# 5                 NaN                                 6.0          MAR - 0.01
# 10                NaN                                 5.0           MAR - 0.1
# 17                NaN                                 6.0           MAR - 0.3
# 20                NaN                                 3.0           MAR - 0.5
# 28                NaN                                 5.0         MCAR - 0.01
# ...               ...                                 ...                 ...
# 1333              NaN                                 1.0          MCAR - 0.5
# 1339              NaN                                 1.0         MNAR - 0.01
# 1345              NaN                                 1.0          MNAR - 0.1
# 1352              NaN                                 2.0          MNAR - 0.3
# 1357              NaN                                 1.0          MNAR - 0.5
#
#       Data_Constellation_full  \
# 5            MAR - 0.01 - 189
# 10            MAR - 0.1 - 189
# 17            MAR - 0.3 - 189
# 20            MAR - 0.5 - 189
# 28          MCAR - 0.01 - 189
# ...                       ...
# 1333       MCAR - 0.5 - 42712
# 1339      MNAR - 0.01 - 42712
# 1345       MNAR - 0.1 - 42712
# 1352       MNAR - 0.3 - 42712
# 1357       MNAR - 0.5 - 42712
#
#       Performance Difference to Best to Average in Percent
# 5                                              0.003597
# 10                                             0.007844
# 17                                             0.014241
# 20                                             0.000893
# 28                                             0.000628
# ...                                                 ...
# 1333                                           0.000000
# 1339                                           0.000000
# 1345                                           0.000000
# 1352                                           0.000423
# 1357                                           0.000000
#
# [228 rows x 23 columns]

# %%
#Difference in Percentage
average_difference = average_best_complete['Performance Difference to Best to Average in Percent'].mean()
print(average_difference, "average difference in Percent (Verschlechterung der durchschnittlich besten Methode relativ zu jeweils besten Methode)")
# Out:
# 0.0022150369721622163 average difference in Percent (Verschlechterung der durchschnittlich besten Methode relativ zu jeweils besten Methode)

# %% [markdown]
# ## Heatmap to Show Detailled Performance of Each Imputation Method for Each Data Constellation

# %%
df_heat = downstream_results_rank.copy()
df_heat.drop(["Missing Type", "Missing Fraction", "Column", "result_type", "metric", "Baseline", "Corrupted", "Unnamed: 0", "Unnamed: 0", "name", "NumberOfClasses", "MajorityClassSize", "MinorityClassSize"], axis=1, inplace=True)
df_heat
# Out:
#       Imputation_Method   Task  Imputed_Subset  NumberOfFeatures  \
# 0             Mean/Mode    189        0.224662               9.0
# 1                   KNN    189        0.224708               9.0
# 2                   VAE    189        0.225196               9.0
# 3     Discriminative DL    189        0.225248               9.0
# 4                  GAIN    189        0.225407               9.0
# ...                 ...    ...             ...               ...
# 1358  Discriminative DL  42712      202.789082              13.0
# 1359               GAIN  42712      203.723620              13.0
# 1360          Mean/Mode  42712      205.088208              13.0
# 1361                VAE  42712      205.193612              13.0
# 1362                KNN  42712      205.719979              13.0
#
#       NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0                8192.0                      9.0                          0.0
# 1                8192.0                      9.0                          0.0
# 2                8192.0                      9.0                          0.0
# 3                8192.0                      9.0                          0.0
# 4                8192.0                      9.0                          0.0
# ...                 ...                      ...                          ...
# 1358            17379.0                      9.0                          4.0
# 1359            17379.0                      9.0                          4.0
# 1360            17379.0                      9.0                          4.0
# 1361            17379.0                      9.0                          4.0
# 1362            17379.0                      9.0                          4.0
#
#       Downstream Performance Rank Subset Data_Constellation
# 0                                    1.0         MAR - 0.01
# 1                                    2.0         MAR - 0.01
# 2                                    3.0         MAR - 0.01
# 3                                    4.0         MAR - 0.01
# 4                                    5.0         MAR - 0.01
# ...                                  ...                ...
# 1358                                 2.0         MNAR - 0.5
# 1359                                 3.0         MNAR - 0.5
# 1360                                 4.0         MNAR - 0.5
# 1361                                 5.0         MNAR - 0.5
# 1362                                 6.0         MNAR - 0.5
#
# [1363 rows x 9 columns]

# %%
# Heatmap for total RMSE score for each data constellation for each method

df_heat = df_heat.astype({"Task":"string"})

data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MCAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']


for i in data_constellations:
    data_constel = df_heat.loc[df_heat['Data_Constellation'] == i]

    ### uncomment whatever you want to investigate

    ## sort by amount datapoints (ascending)
    data_constel = data_constel.sort_values(by=['NumberOfInstances'])

    ## sort by amount of features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfFeatures'])

    ## sort by amount of datapoints and features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances', 'NumberOfFeatures'])

    ## sort by amount of categorical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfCategoricalFeatures', 'NumberOfInstances'])

    ## sort by amount of numerical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfNumericFeatures', 'NumberOfInstances'])
    
    Dataset_number = data_constel["Task"]
    Imputation_Method = data_constel["Imputation_Method"]
    Improvement = data_constel["Imputed_Subset"]
    

    trace = go.Heatmap(
                   z=Improvement,
                   x=Dataset_number,
                   y=Imputation_Method,
                   type = 'heatmap',
                    autocolorscale= False,
                    colorscale = 'Reds',
                    zmin=0,
                    )
    data = [trace]
    fig = go.Figure(data=data)
    fig.update_layout(
        title=i,
        xaxis_nticks=36)
    fig.show()
# Out:
# <div>                            <div id="3534d3fb-8612-4b38-bc39-cbabd7f1fd9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3534d3fb-8612-4b38-bc39-cbabd7f1fd9c")) {                    Plotly.newPlot(                        "3534d3fb-8612-4b38-bc39-cbabd7f1fd9c",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["KNN","VAE","Mean/Mode","GAIN","Discriminative DL","Random Forest","KNN","Random Forest","GAIN","Discriminative DL","Mean/Mode","VAE","Mean/Mode","Random Forest","VAE","GAIN","KNN","Discriminative DL","Mean/Mode","VAE","KNN","VAE","Discriminative DL","GAIN","Random Forest","Mean/Mode
" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23d50292-0b60-4784-b2d3-26a17b92b89d")) {                    Plotly.newPlot(                        "23d50292-0b60-4784-b2d3-26a17b92b89d",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(255,245,240)"],[0.125,"rgb(254,224,210)"],[0.25,"rgb(252,187,161)"],[0.375,"rgb(252,146,114)"],[0.5,"rgb(251,106,74)"],[0.625,"rgb(239,59,44)"],[0.75,"rgb(203,24,29)"],[0.875,"rgb(165,15,21)"],[1.0,"rgb(103,0,13)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","197","197","197","197","189","197","189","189","189","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["GAIN","Mean/Mode","KNN","Random Forest","Discriminative DL","VAE","KNN","Mean/Mode","VAE","GAIN","Random Forest","GAIN","Discriminative DL","KNN","Mean/Mode","Random Forest","VAE","Discriminative DL","Random Forest","Mean/Mode","Mean/Mode","VAE","KNN","Discriminative DL","KNN","GAIN","VAE","GAIN","Random Forest","Random Forest","Mean/Mode","VAE","KNN","GAIN","Discriminative DL","Random Forest","Mean/Mode","Discriminative DL","GAIN","KNN","VAE","Random Forest","Mean/Mode","VAE","Discriminative DL","KNN","GAIN","Random Forest","VAE","Discriminative DL","KNN","Mean/Mode","GAIN","VAE","KNN","Mean/Mode","GAIN","Discriminative DL","Random Forest","Random Forest","Discriminative DL","GAIN","Mean/Mode","KNN","VAE","VAE","Discriminative DL","Random Forest","Mean/Mode","KNN","GAIN","VAE","Random Forest","KNN","Mean/Mode","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","KNN","GAIN","VAE","Random Forest","VAE","GAIN","Discriminative DL","Random Forest","Mean/Mode","KNN","KNN","Discriminative DL","GAIN","Random Forest","Mean/Mode","VAE","GAIN","Mean/Mode","Random Forest","KNN","Discriminative DL","VAE","Random Forest","Mean/Mode","GAIN","VAE","Discriminative DL","KNN","KNN","GAIN","VAE","Discriminative DL","Random Forest","Mean/Mode"],"z":[0.482060145297676,0.4859771812568112,0.4897266904637716,0.482438387637896,0.4804493196733229,0.4489752592559317,14.973847212490424,14.973851488207158,14.973899326656138,14.9739451353875,14.973831960108214,1.0739028449447618,1.0816394616440188,1.0798718411166146,1.0698123093145062,1.0817861819181105,1.0738868819103276,0.2257049328434413,57.40421071474186,0.2331352729060455,57.27449822890025,57.36818753695189,57.37725873029615,57.45815252052307,0.2314321718416623,57.59965707490736,0.2297759134603624,0.2278188314862501,0.23053506833001,0.0016198971319557,0.0016208854565234,0.0016223625373521,0.0016220658392543,0.0016223225110077,0.0016198898834162,0.0323305541697876,0.0323428610844072,0.0323535199953709,0.0323378933409368,0.0322674227184101,0.0323064686206876,6510.048756189363,6510.048637604855,6510.048875601405,6510.04880877728,6510.048789518823,6510.048797665783,5.768235521864347,5.747978452524829,5.767741439725287,5.76840641215749,5.769019742086969,5.774436885341372,0.0034184322932731,0.0034154262701034,0.0033888061628683,0.0034010124121378,0.0034339255446022,0.0034031584184227,202.5813921295818,202.7890823184135,203.7236 ...

# %%
#downstream_results_rank_heatmap2
df_heat_dif = downstream_results_rank_heatmap2.copy()
df_heat_dif
# Out:
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 0             Mean/Mode    189          MAR             0.01    theta8
# 1                   KNN    189          MAR             0.01    theta8
# 2                   VAE    189          MAR             0.01    theta8
# 3     Discriminative DL    189          MAR             0.01    theta8
# 4                  GAIN    189          MAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1358  Discriminative DL  42712         MNAR              0.5  humidity
# 1359               GAIN  42712         MNAR              0.5  humidity
# 1360          Mean/Mode  42712         MNAR              0.5  humidity
# 1361                VAE  42712         MNAR              0.5  humidity
# 1362                KNN  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks    0.225185        0.0
# 1     downstream_performance_mean  Regression Tasks    0.225176        0.0
# 2     downstream_performance_mean  Regression Tasks    0.225180        0.0
# 3     downstream_performance_mean  Regression Tasks    0.225196        0.0
# 4     downstream_performance_mean  Regression Tasks    0.225167        0.0
# ...                           ...               ...         ...        ...
# 1358  downstream_performance_mean  Regression Tasks  203.803893        0.0
# 1359  downstream_performance_mean  Regression Tasks  205.260299        0.0
# 1360  downstream_performance_mean  Regression Tasks  204.556231        0.0
# 1361  downstream_performance_mean  Regression Tasks  205.508743        0.0
# 1362  downstream_performance_mean  Regression Tasks  205.569068        0.0
#
#       Imputed_Subset  ...                 name MajorityClassSize  \
# 0           0.224662  ...               kin8nm               NaN
# 1           0.224708  ...               kin8nm               NaN
# 2           0.225196  ...               kin8nm               NaN
# 3           0.225248  ...               kin8nm               NaN
# 4           0.225407  ...               kin8nm               NaN
# ...              ...  ...                  ...               ...
# 1358      202.789082  ...  Bike_Sharing_Demand               NaN
# 1359      203.723620  ...  Bike_Sharing_Demand               NaN
# 1360      205.088208  ...  Bike_Sharing_Demand               NaN
# 1361      205.193612  ...  Bike_Sharing_Demand               NaN
# 1362      205.719979  ...  Bike_Sharing_Demand               NaN
#
#       MinorityClassSize  NumberOfFeatures  NumberOfInstances  \
# 0                   NaN               9.0             8192.0
# 1                   NaN               9.0             8192.0
# 2                   NaN               9.0             8192.0
# 3                   NaN               9.0             8192.0
# 4                   NaN               9.0             8192.0
# ...                 ...               ...                ...
# 1358                NaN              13.0            17379.0
# 1359                NaN              13.0            17379.0
# 1360                NaN              13.0            17379.0
# 1361                NaN              13.0            17379.0
# 1362                NaN              13.0            17379.0
#
#       NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                         9.0                          0.0              NaN
# 1                         9.0                          0.0              NaN
# 2                         9.0                          0.0              NaN
# 3                         9.0                          0.0              NaN
# 4                         9.0                          0.0              NaN
# ...                       ...                          ...              ...
# 1358                      9.0                          4.0              NaN
# 1359                      9.0                          4.0              NaN
# 1360                      9.0                          4.0              NaN
# 1361                      9.0                          4.0              NaN
# 1362                      9.0                          4.0              NaN
#
#       Downstream Performance Rank Subset  Data_Constellation
# 0                                    1.0          MAR - 0.01
# 1                                    2.0          MAR - 0.01
# 2                                    3.0          MAR - 0.01
# 3                                    4.0          MAR - 0.01
# 4                                    5.0          MAR - 0.01
# ...                                  ...                 ...
# 1358                                 2.0          MNAR - 0.5
# 1359                                 3.0          MNAR - 0.5
# 1360                                 4.0          MNAR - 0.5
# 1361                                 5.0          MNAR - 0.5
# 1362                                 6.0          MNAR - 0.5
#
# [1363 rows x 21 columns]

# %%
# Calculate Difference for every Imputation towards average best Imputation Method per Data Constellation
# Calculation for RMSE Differences in Percentage (RMSE alone not comparable over different datasets)

data = downstream_results_rank.copy()
data['Task'] = data['Task'].astype(str)
data['Data_Constellation_full'] = data['Data_Constellation'] + ' - ' + data['Task']

dc_unique = data.Data_Constellation_full.unique()
#print(dc_unique)

data_constellations = dc_unique.tolist()
methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
heatmap_data_difference = pd.DataFrame()


for i in data_constellations:
    data_constel = data.loc[data['Data_Constellation_full'] == i]
    average_best = data_constel.loc[data_constel['Imputation_Method'] == AVERAGE_BEST_IMPUTATION_METHOD]
    dataset_number = best_score.iloc[0]['Task']
    for i in methods:
        if ((data_constel['Imputation_Method'] == i).any()):
            current_score_row = data_constel.loc[data['Imputation_Method'] == i]
            current_score_int = current_score_row.iloc[0]['Imputed_Subset']
            average_best_int = average_best.iloc[0]['Imputed_Subset']
            calc_result = ((average_best_int - current_score_int)/current_score_int)

            current_score_row['Performance Difference to Average Best in Percent'] = calc_result
            heatmap_data_difference = heatmap_data_difference.append(current_score_row)  
        else:
            print("Imputation Method not here ---------------------")

heatmap_data_difference
# Out:
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# ...
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dittr\AppData\Local\Temp\ipykernel_3864\3955374020.py:28: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 5         Random Forest    189          MAR             0.01    theta8
# 1                   KNN    189          MAR             0.01    theta8
# 0             Mean/Mode    189          MAR             0.01    theta8
# 2                   VAE    189          MAR             0.01    theta8
# 4                  GAIN    189          MAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1362                KNN  42712         MNAR              0.5  humidity
# 1360          Mean/Mode  42712         MNAR              0.5  humidity
# 1361                VAE  42712         MNAR              0.5  humidity
# 1359               GAIN  42712         MNAR              0.5  humidity
# 1358  Discriminative DL  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 5     downstream_performance_mean  Regression Tasks    0.225190        0.0
# 1     downstream_performance_mean  Regression Tasks    0.225176        0.0
# 0     downstream_performance_mean  Regression Tasks    0.225185        0.0
# 2     downstream_performance_mean  Regression Tasks    0.225180        0.0
# 4     downstream_performance_mean  Regression Tasks    0.225167        0.0
# ...                           ...               ...         ...        ...
# 1362  downstream_performance_mean  Regression Tasks  205.569068        0.0
# 1360  downstream_performance_mean  Regression Tasks  204.556231        0.0
# 1361  downstream_performance_mean  Regression Tasks  205.508743        0.0
# 1359  downstream_performance_mean  Regression Tasks  205.260299        0.0
# 1358  downstream_performance_mean  Regression Tasks  203.803893        0.0
#
#       Imputed_Subset  ...  MinorityClassSize NumberOfFeatures  \
# 5           0.225470  ...                NaN              9.0
# 1           0.224708  ...                NaN              9.0
# 0           0.224662  ...                NaN              9.0
# 2           0.225196  ...                NaN              9.0
# 4           0.225407  ...                NaN              9.0
# ...              ...  ...                ...              ...
# 1362      205.719979  ...                NaN             13.0
# 1360      205.088208  ...                NaN             13.0
# 1361      205.193612  ...                NaN             13.0
# 1359      203.723620  ...                NaN             13.0
# 1358      202.789082  ...                NaN             13.0
#
#       NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 5                8192.0                      9.0                          0.0
# 1                8192.0                      9.0                          0.0
# 0                8192.0                      9.0                          0.0
# 2                8192.0                      9.0                          0.0
# 4                8192.0                      9.0                          0.0
# ...                 ...                      ...                          ...
# 1362            17379.0                      9.0                          4.0
# 1360            17379.0                      9.0                          4.0
# 1361            17379.0                      9.0                          4.0
# 1359            17379.0                      9.0                          4.0
# 1358            17379.0                      9.0                          4.0
#
#       NumberOfClasses  Downstream Performance Rank Subset  Data_Constellation  \
# 5                 NaN                                 6.0          MAR - 0.01
# 1                 NaN                                 2.0          MAR - 0.01
# 0                 NaN                                 1.0          MAR - 0.01
# 2                 NaN                                 3.0          MAR - 0.01
# 4                 NaN                                 5.0          MAR - 0.01
# ...               ...                                 ...                 ...
# 1362              NaN                                 6.0          MNAR - 0.5
# 1360              NaN                                 4.0          MNAR - 0.5
# 1361              NaN                                 5.0          MNAR - 0.5
# 1359              NaN                                 3.0          MNAR - 0.5
# 1358              NaN                                 2.0          MNAR - 0.5
#
#       Data_Constellation_full  \
# 5            MAR - 0.01 - 189
# 1            MAR - 0.01 - 189
# 0            MAR - 0.01 - 189
# 2            MAR - 0.01 - 189
# 4            MAR - 0.01 - 189
# ...                       ...
# 1362       MNAR - 0.5 - 42712
# 1360       MNAR - 0.5 - 42712
# 1361       MNAR - 0.5 - 42712
# 1359       MNAR - 0.5 - 42712
# 1358       MNAR - 0.5 - 42712
#
#       Performance Difference to Average Best in Percent
# 5                                              0.000000
# 1                                              0.003392
# 0                                              0.003597
# 2                                              0.001218
# 4                                              0.000280
# ...                                                 ...
# 1362                                          -0.015257
# 1360                                          -0.012223
# 1361                                          -0.012731
# 1359                                          -0.005607
# 1358                                          -0.001024
#
# [1363 rows x 23 columns]

# %%
# Heatmap for RMSE differences in Percentage for each data constellation for each method relative to average best imputation method

heatmap_data_difference = heatmap_data_difference.astype({"Task":"string"})
data_constellations = ['MAR - 0.01', 'MAR - 0.1', 'MAR - 0.3', 'MAR - 0.5', 'MCAR - 0.01', 'MCAR - 0.1', 'MCAR - 0.3', 'MCAR - 0.5', 'MNAR - 0.01', 'MNAR - 0.1', 'MNAR - 0.3', 'MNAR - 0.5']
for i in data_constellations:
    data_constel = heatmap_data_difference.loc[df_heat['Data_Constellation'] == i]

    ### uncomment whatever you want to investigate

    ## sort by amount datapoints (ascending)
    data_constel = data_constel.sort_values(by=['NumberOfInstances'])

    ## sort by amount of features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfFeatures'])

    ## sort by amount of datapoints and features (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfInstances', 'NumberOfFeatures'])

    ## sort by amount of categorical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfCategoricalFeatures', 'NumberOfInstances'])

    ## sort by amount of numerical features and datapoints (ascending)
    #data_constel = data_constel.sort_values(by=['NumberOfNumericFeatures', 'NumberOfInstances'])
    
    Dataset_number = data_constel["Task"]
    Imputation_Method = data_constel["Imputation_Method"]
    Improvement = data_constel["Performance Difference to Average Best in Percent"]
    

    trace = go.Heatmap(
                   z=Improvement,
                   x=Dataset_number,
                   y=Imputation_Method,
                   type = 'heatmap',
                    autocolorscale= False,
                    colorscale = 'RdBu_r',
                    zmid=0,
                    zmin=(-0.1),
                    zmax=0.1,
                    )
    data = [trace]
    fig = go.Figure(data=data)
    fig.update_layout(
        title=i,
        xaxis_nticks=36)
    fig.show()
    fig.write_image("regression_subset_heatmap_f1_score_improvement_to_avbest%s.pdf" %i)
# Out:
# <div>                            <div id="729e6829-faab-4e4d-af97-13d4fae23ac8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("729e6829-faab-4e4d-af97-13d4fae23ac8")) {                    Plotly.newPlot(                        "729e6829-faab-4e4d-af97-13d4fae23ac8",                        [{"autocolorscale":false,"colorscale":[[0.0,"rgb(5,48,97)"],[0.1,"rgb(33,102,172)"],[0.2,"rgb(67,147,195)"],[0.3,"rgb(146,197,222)"],[0.4,"rgb(209,229,240)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(253,219,199)"],[0.7,"rgb(244,165,130)"],[0.8,"rgb(214,96,77)"],[0.9,"rgb(178,24,43)"],[1.0,"rgb(103,0,31)"]],"x":["42636","42636","42636","42636","42636","42636","42545","42545","42545","42545","42545","42545","287","287","287","287","287","287","189","197","189","189","189","189","189","197","197","197","197","197","198","198","198","198","198","198","23515","23515","23515","23515","23515","23515","42688","42688","42688","42688","42688","42688","42183","42183","42183","42183","42183","42183","216","216","216","216","216","216","42712","42712","42712","42712","42712","42712","1199","1199","1199","1199","1199","1199","218","218","218","218","218","218","1193","1193","1193","1193","1193","1193","215","215","215","215","215","215","42225","42225","42225","42225","42225","42225","1200","1200","1200","1200","1200","1200","1213","1213","1213","1213","1213","1213","23395","23395","23395","23395","23395","23395"],"y":["Mean/Mode","GAIN","Discriminative DL","VAE","KNN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Random Forest","Discriminative DL","VAE","GAIN","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","VAE","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Discriminative DL","GAIN","Mean/Mode","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","KNN","Random Forest","Discriminative DL","GAIN","Mean/Mode","VAE","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","VAE","Random Forest","KNN","Discriminative DL","Mean/Mode","Random Forest","KNN","Mean/Mode","VAE","Discriminative DL","GAIN","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","KNN","VAE","Mean/Mode","GAIN","Random Forest","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest","Random Forest","KNN","Mean/Mode","VAE","GAIN","Discriminative DL","Mean/Mode","Random Forest","KNN","VAE","GAIN","Discriminative DL","GAIN","Mean/Mode","VAE","Random Forest","KNN","Discriminative DL","Discriminative DL","GAIN","VAE","Mean/Mode","KNN","Random Forest"],"z":[-0
074,-0.0007098400911736597,0.0007455333290303175,0.0,0.0019565074015495936,-5.119694234880847e-09,0.0,-8.077960448955806e-09,-6.371138101538055e-09,1.8215610224849036e-08,-1.8342725787082003e-08,-0.00013593647754412379,0.0,-2.96252172493985e-05,0.0035242075986941243,-0.0010739338917648688,8.56630180501474e-05,0.0006309904301557463,-0.00446809342412794,0.0,-0.00359189474768805,-0.0089597534308 ...

# %%
#heatmap_data_difference.agg(['min', 'max'])
#heatmap_data_difference.to_csv('heatmap_data_difference.csv')
heatmap_data_difference['Performance Difference to Average Best in Percent'].agg(['min', 'max'])
# Out:
# min   -0.101089
# max    0.074532
# Name: Performance Difference to Average Best in Percent, dtype: float64

# %%
#heatmap_data_difference
heatmap_data_difference.to_csv('regression_subset_full_info.csv', index=False)

# %% [markdown]
# ## Improvment Proportions for All Data Constellations and Methods Relative to Average Best Method

# %%
# data preprocessing here
df_quantiles = heatmap_data_difference.copy()
df_quantiles = df_quantiles.drop(df_quantiles[df_quantiles["Imputation_Method"] == AVERAGE_BEST_IMPUTATION_METHOD].index)

df_10 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] > (-0.09))].index)
df_09 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.09)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (-0.07))].index)
df_07 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.07)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (-0.05))].index)
df_05 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.05)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (-0.03))].index)
df_03 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.03)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (-0.01))].index)
df_01 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (-0.01)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.01))].index)
df01 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.01)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.03))].index)
df03 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.03)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.05))].index)
df05 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.05)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.07))].index)
df07 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.07)) | (df_quantiles["Performance Difference to Average Best in Percent"] > (0.09))].index)
df09 = df_quantiles.drop(df_quantiles[(df_quantiles["Performance Difference to Average Best in Percent"] <= (0.09))].index)

#df_quantiles
#df_quantiles.dtypes

# %%
len_df_10 = len(df_10.index)
len_df_09 = len(df_09.index)
len_df_07 = len(df_07.index)
len_df_05 = len(df_05.index)
len_df_03 = len(df_03.index)
len_df_01 = len(df_01.index)
len_df01 = len(df01.index)
len_df03 = len(df03.index)
len_df05 = len(df05.index)
len_df07 = len(df07.index)
len_df09 = len(df09.index)

quantile_freq = []
#quantile_freq.append()
quantile_freq.extend((len_df_10, len_df_09, len_df_07, len_df_05, len_df_03, len_df_01, len_df01, len_df03, len_df05, len_df07, len_df09))
print(quantile_freq)


quantiles = []
quantiles.extend(['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09'])
print(quantiles)

improvement_quantiles = pd.DataFrame(
    {'Improvement to Average Best in Percent': quantiles,
     'Amount': quantile_freq,
    })
# Out:
# [1, 2, 6, 12, 57, 1034, 22, 0, 0, 1, 0]
# ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03', '-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']

# %%
fig = px.bar(improvement_quantiles, x='Improvement to Average Best in Percent', y='Amount')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl.pdf")
# Out:
# <div>                            <div id="7a6657e7-3229-42c6-9118-bd695c53b2e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a6657e7-3229-42c6-9118-bd695c53b2e2")) {                    Plotly.newPlot(                        "7a6657e7-3229-42c6-9118-bd695c53b2e2",                        [{"alignmentgroup":"True","hovertemplate":"Improvement to Average Best in Percent=%{x}<br>Amount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"xaxis":"x","y":[1,2,6,12,57,1034,22,0,0,1,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","s ...

# %%
# split barchart stacks into methods
#quantile_freq
quantile_datasets = [df_10, df_09, df_07, df_05, df_03, df_01, df01, df03, df05, df07, df09]

methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
methods.remove(AVERAGE_BEST_IMPUTATION_METHOD)
print(methods)

forest_freq = []
knn_freq = []
mode_freq = []
dl_freq = []
vae_freq = []
gain_freq = []
#print(quantile_datasets)

for i in methods:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Imputation_Method'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'Random Forest'):
            forest_freq.append(df_temp_len)
        elif (i == 'KNN'):
            knn_freq.append(df_temp_len)                                       
        elif (i == 'Mean/Mode'):
            mode_freq.append(df_temp_len)                                                 
        elif (i == 'Discriminative DL'):
            dl_freq.append(df_temp_len)                                       
        elif (i == 'VAE'):
            vae_freq.append(df_temp_len)                                         
        elif (i == 'GAIN'):
            gain_freq.append(df_temp_len)                                          
                                       
print(forest_freq)
print(knn_freq)
print(mode_freq)
print(dl_freq)
print(vae_freq)
print(gain_freq)
# Out:
# ['KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
# []
# [0, 0, 0, 1, 8, 214, 5, 0, 0, 0, 0]
# [0, 1, 0, 4, 14, 205, 4, 0, 0, 0, 0]
# [0, 0, 0, 2, 3, 212, 6, 0, 0, 0, 0]
# [0, 1, 5, 2, 15, 202, 2, 0, 0, 1, 0]
# [1, 0, 1, 3, 17, 201, 5, 0, 0, 0, 0]

# %%
quantiles = ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']

fig = go.Figure(data=[
    go.Bar(name='Random Forest', x=quantiles, y=forest_freq),
    go.Bar(name='KNN', x=quantiles, y=knn_freq),
    go.Bar(name='Mean/Mode', x=quantiles, y=mode_freq),
    go.Bar(name='Discriminative DL', x=quantiles, y=dl_freq),
    go.Bar(name='VAE', x=quantiles, y=vae_freq),
    go.Bar(name='GAIN', x=quantiles, y=gain_freq)
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_per_method.pdf")
# Out:
# <div>                            <div id="852459ee-ea03-43db-a055-b91867ee47c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("852459ee-ea03-43db-a055-b91867ee47c0")) {                    Plotly.newPlot(                        "852459ee-ea03-43db-a055-b91867ee47c0",                        [{"name":"Random Forest","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[],"type":"bar"},{"name":"KNN","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,0,0,1,8,214,5,0,0,0,0],"type":"bar"},{"name":"Mean/Mode","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,1,0,4,14,205,4,0,0,0,0],"type":"bar"},{"name":"Discriminative DL","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,0,0,2,3,212,6,0,0,0,0],"type":"bar"},{"name":"VAE","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,1,5,2,15,202,2,0,0,1,0],"type":"bar"},{"name":"GAIN","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[1,0,1,3,17,201,5,0,0,0,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7 ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_10, df_09, df_07, df_05, df_03, df_01, df01, df03, df05, df07, df09]

fractions = ['0.01', '0.1', '0.3', '0.5']
#print(fractions)
#print(df_10)

freq_001 = []
freq_01 = []
freq_03 = []
freq_05 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Fraction'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == '0.01'):
            freq_001.append(df_temp_len)
        elif (i == '0.1'):
            freq_01.append(df_temp_len)                                       
        elif (i == '0.3'):
            freq_03.append(df_temp_len)                                                 
        elif (i == '0.5'):
            freq_05.append(df_temp_len)                                       
                                        
                                       
print(freq_001)
print(freq_01)
print(freq_03)
print(freq_05)
# Out:
# [0, 0, 0, 0, 0, 283, 0, 0, 0, 0, 0]
# [0, 0, 0, 2, 14, 268, 0, 0, 0, 0, 0]
# [1, 1, 3, 3, 22, 243, 11, 0, 0, 0, 0]
# [0, 1, 3, 7, 21, 240, 11, 0, 0, 1, 0]

# %%
quantiles = ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='1% Missing Data', x=quantiles, y=freq_001, marker_color='#FD3216'),
    go.Bar(name='10% Missing Data', x=quantiles, y=freq_01, marker_color='#00FE35'),
    go.Bar(name='30% Missing Data', x=quantiles, y=freq_03, marker_color='#511CFB'),
    go.Bar(name='50% Missing Data', x=quantiles, y=freq_05, marker_color='#FF7F0E'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_per_frac.pdf")
# Out:
# <div>                            <div id="46fb0e53-0d7c-4276-b2f2-f1b230b84247" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46fb0e53-0d7c-4276-b2f2-f1b230b84247")) {                    Plotly.newPlot(                        "46fb0e53-0d7c-4276-b2f2-f1b230b84247",                        [{"marker":{"color":"#FD3216"},"name":"1% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,0,0,0,0,283,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#00FE35"},"name":"10% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,0,0,2,14,268,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#511CFB"},"name":"30% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[1,1,3,3,22,243,11,0,0,0,0],"type":"bar"},{"marker":{"color":"#FF7F0E"},"name":"50% Missing Data","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,1,3,7,21,240,11,0,0,1,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8 ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_10, df_09, df_07, df_05, df_03, df_01, df01, df03, df05, df07, df09]

fractions = ['MCAR', 'MAR', 'MNAR']
print(fractions)
#print(df_10)

freq_001 = []
freq_01 = []
freq_03 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Type'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'MCAR'):
            freq_001.append(df_temp_len)
        elif (i == 'MAR'):
            freq_01.append(df_temp_len)                                       
        elif (i == 'MNAR'):
            freq_03.append(df_temp_len)                                                                                     
                                        
                                       
print(freq_001)
print(freq_01)
print(freq_03)
# Out:
# ['MCAR', 'MAR', 'MNAR']
# [0, 1, 2, 5, 16, 353, 2, 0, 0, 0, 0]
# [1, 1, 2, 2, 21, 348, 5, 0, 0, 0, 0]
# [0, 0, 2, 5, 20, 333, 15, 0, 0, 1, 0]

# %%
quantiles = ['less than -0.09', '-0.09 to -0.07', '-0.07 to -0.05', '-0.05 to -0.03','-0.03 to -0.01', '-0.01 to 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='MCAR', x=quantiles, y=freq_001, marker_color='#222A2A'),
    go.Bar(name='MAR', x=quantiles, y=freq_01, marker_color='#B68100'),
    go.Bar(name='MNAR', x=quantiles, y=freq_03, marker_color='#750D86'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_per_patt.pdf")
# Out:
# <div>                            <div id="a8bf5142-4af2-4184-b5fc-2326479bab2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8bf5142-4af2-4184-b5fc-2326479bab2c")) {                    Plotly.newPlot(                        "a8bf5142-4af2-4184-b5fc-2326479bab2c",                        [{"marker":{"color":"#222A2A"},"name":"MCAR","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,1,2,5,16,353,2,0,0,0,0],"type":"bar"},{"marker":{"color":"#B68100"},"name":"MAR","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[1,1,2,2,21,348,5,0,0,0,0],"type":"bar"},{"marker":{"color":"#750D86"},"name":"MNAR","x":["less than -0.09","-0.09 to -0.07","-0.07 to -0.05","-0.05 to -0.03","-0.03 to -0.01","-0.01 to 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[0,0,2,5,20,333,15,0,0,1,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line": ...

# %% [markdown]
# ## Improvment Proportions for the Best Imputation Method per Data Constellation Relative to Average Best Method

# %%
improv_to_av_bar = heatmap_data_difference.copy()

improv_to_av_bar = improv_to_av_bar.drop(improv_to_av_bar[improv_to_av_bar["Downstream Performance Rank Subset"] != 1.0].index)

df_01 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (-0.01)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.01))].index)
df01 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.01)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.03))].index)
df03 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.03)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.05))].index)
df05 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.05)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.07))].index)
df07 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.07)) | (improv_to_av_bar["Performance Difference to Average Best in Percent"] > (0.09))].index)
df09 = improv_to_av_bar.drop(improv_to_av_bar[(improv_to_av_bar["Performance Difference to Average Best in Percent"] <= (0.09))].index)

improv_to_av_bar
# Out:
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 0             Mean/Mode    189          MAR             0.01    theta8
# 6     Discriminative DL    189          MAR              0.1    theta8
# 12                  KNN    189          MAR              0.3    theta8
# 18    Discriminative DL    189          MAR              0.5    theta8
# 24    Discriminative DL    189         MCAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1333      Random Forest  42712         MCAR              0.5  humidity
# 1339      Random Forest  42712         MNAR             0.01  humidity
# 1345      Random Forest  42712         MNAR              0.1  humidity
# 1351                VAE  42712         MNAR              0.3  humidity
# 1357      Random Forest  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks    0.225185        0.0
# 6     downstream_performance_mean  Regression Tasks    0.225352        0.0
# 12    downstream_performance_mean  Regression Tasks    0.226497        0.0
# 18    downstream_performance_mean  Regression Tasks    0.225885        0.0
# 24    downstream_performance_mean  Regression Tasks    0.225430        0.0
# ...                           ...               ...         ...        ...
# 1333  downstream_performance_mean  Regression Tasks  204.349055        0.0
# 1339  downstream_performance_mean  Regression Tasks  205.186741        0.0
# 1345  downstream_performance_mean  Regression Tasks  205.419418        0.0
# 1351  downstream_performance_mean  Regression Tasks  203.125694        0.0
# 1357  downstream_performance_mean  Regression Tasks  203.690837        0.0
#
#       Imputed_Subset  ...  MinorityClassSize NumberOfFeatures  \
# 0           0.224662  ...                NaN              9.0
# 6           0.224106  ...                NaN              9.0
# 12          0.223568  ...                NaN              9.0
# 18          0.223194  ...                NaN              9.0
# 24          0.225247  ...                NaN              9.0
# ...              ...  ...                ...              ...
# 1333      204.639271  ...                NaN             13.0
# 1339      205.211177  ...                NaN             13.0
# 1345      205.400159  ...                NaN             13.0
# 1351      202.883274  ...                NaN             13.0
# 1357      202.581392  ...                NaN             13.0
#
#       NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0                8192.0                      9.0                          0.0
# 6                8192.0                      9.0                          0.0
# 12               8192.0                      9.0                          0.0
# 18               8192.0                      9.0                          0.0
# 24               8192.0                      9.0                          0.0
# ...                 ...                      ...                          ...
# 1333            17379.0                      9.0                          4.0
# 1339            17379.0                      9.0                          4.0
# 1345            17379.0                      9.0                          4.0
# 1351            17379.0                      9.0                          4.0
# 1357            17379.0                      9.0                          4.0
#
#       NumberOfClasses  Downstream Performance Rank Subset  Data_Constellation  \
# 0                 NaN                                 1.0          MAR - 0.01
# 6                 NaN                                 1.0           MAR - 0.1
# 12                NaN                                 1.0           MAR - 0.3
# 18                NaN                                 1.0           MAR - 0.5
# 24                NaN                                 1.0         MCAR - 0.01
# ...               ...                                 ...                 ...
# 1333              NaN                                 1.0          MCAR - 0.5
# 1339              NaN                                 1.0         MNAR - 0.01
# 1345              NaN                                 1.0          MNAR - 0.1
# 1351              NaN                                 1.0          MNAR - 0.3
# 1357              NaN                                 1.0          MNAR - 0.5
#
#       Data_Constellation_full  \
# 0            MAR - 0.01 - 189
# 6             MAR - 0.1 - 189
# 12            MAR - 0.3 - 189
# 18            MAR - 0.5 - 189
# 24          MCAR - 0.01 - 189
# ...                       ...
# 1333       MCAR - 0.5 - 42712
# 1339      MNAR - 0.01 - 42712
# 1345       MNAR - 0.1 - 42712
# 1351       MNAR - 0.3 - 42712
# 1357       MNAR - 0.5 - 42712
#
#       Performance Difference to Average Best in Percent
# 0                                              0.003597
# 6                                              0.007844
# 12                                             0.014241
# 18                                             0.000893
# 24                                             0.000628
# ...                                                 ...
# 1333                                           0.000000
# 1339                                           0.000000
# 1345                                           0.000000
# 1351                                           0.000423
# 1357                                           0.000000
#
# [228 rows x 23 columns]

# %%
#improv_to_av_bar.agg(['min', 'max'])
# Out:
#      Imputation_Method   Task Missing Type Missing Fraction    Column  \
# min  Discriminative DL   1193          MAR             0.01  Material
# max                VAE  42712         MNAR              0.5        x6
#
#                      result_type            metric      Baseline  Corrupted  \
# min  downstream_performance_mean  Regression Tasks      0.001620        0.0
# max  downstream_performance_mean  Regression Tasks  76167.042425        0.0
#
#      Imputed_Subset  ...  MinorityClassSize NumberOfFeatures  \
# min         0.00162  ...                NaN              6.0
# max     76167.04242  ...                NaN             22.0
#
#      NumberOfInstances  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# min             4477.0                      3.0                          0.0
# max            89640.0                     22.0                          7.0
#
#      NumberOfClasses  Downstream Performance Rank Subset  Data_Constellation  \
# min              NaN                                 1.0          MAR - 0.01
# max              NaN                                 1.0          MNAR - 0.5
#
#      Data_Constellation_full  \
# min        MAR - 0.01 - 1193
# max       MNAR - 0.5 - 42712
#
#      Performance Difference to Average Best in Percent
# min                                           0.000000
# max                                           0.074532
#
# [2 rows x 23 columns]

# %%
len_df_01 = len(df_01.index)
len_df01 = len(df01.index)
len_df03 = len(df03.index)
len_df05 = len(df05.index)
len_df07 = len(df07.index)
len_df09 = len(df09.index)

quantile_freq = []
quantile_freq.extend((len_df_01, len_df01, len_df03, len_df05, len_df07, len_df09))
print(quantile_freq)


quantiles = []
quantiles.extend(['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09'])
print(quantiles)

improvement_quantiles = pd.DataFrame(
    {'Improvement to Average Best in Percent': quantiles,
     'Amount': quantile_freq,
    })

fig = px.bar(improvement_quantiles, x='Improvement to Average Best in Percent', y='Amount')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_only_best.pdf")
# Out:
# [215, 12, 0, 0, 1, 0]
# ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']
# <div>                            <div id="2a30d2c1-8419-40f0-ba29-96b754b4caab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a30d2c1-8419-40f0-ba29-96b754b4caab")) {                    Plotly.newPlot(                        "2a30d2c1-8419-40f0-ba29-96b754b4caab",                        [{"alignmentgroup":"True","hovertemplate":"Improvement to Average Best in Percent=%{x}<br>Amount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"xaxis":"x","y":[215,12,0,0,1,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{" ...

# %%
# split barchart stacks into methods

quantile_datasets = [df_01, df01, df03, df05, df07, df09]

methods = ['Random Forest', 'KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
methods.remove(AVERAGE_BEST_IMPUTATION_METHOD)
print(methods)

forest_freq = []
knn_freq = []
mode_freq = []
dl_freq = []
vae_freq = []
gain_freq = []
#print(quantile_datasets)

for i in methods:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Imputation_Method'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'Random Forest'):
            forest_freq.append(df_temp_len)
        elif (i == 'KNN'):
            knn_freq.append(df_temp_len)                                       
        elif (i == 'Mean/Mode'):
            mode_freq.append(df_temp_len)                                                 
        elif (i == 'Discriminative DL'):
            dl_freq.append(df_temp_len)                                       
        elif (i == 'VAE'):
            vae_freq.append(df_temp_len)                                         
        elif (i == 'GAIN'):
            gain_freq.append(df_temp_len)                                          
                                       
print(forest_freq)
print(knn_freq)
print(mode_freq)
print(dl_freq)
print(vae_freq)
print(gain_freq)
# Out:
# ['KNN', 'Mean/Mode', 'VAE', 'GAIN', 'Discriminative DL']
# []
# [31, 3, 0, 0, 0, 0]
# [39, 1, 0, 0, 0, 0]
# [27, 4, 0, 0, 0, 0]
# [43, 1, 0, 0, 1, 0]
# [28, 3, 0, 0, 0, 0]

# %%
quantiles = ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='Random Forest', x=quantiles, y=forest_freq),
    go.Bar(name='KNN', x=quantiles, y=knn_freq),
    go.Bar(name='Mean/Mode', x=quantiles, y=mode_freq),
    go.Bar(name='Discriminative DL', x=quantiles, y=dl_freq),
    go.Bar(name='VAE', x=quantiles, y=vae_freq),
    go.Bar(name='GAIN', x=quantiles, y=gain_freq)
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_only_best_per_method.pdf")
# Out:
# <div>                            <div id="9099c0b5-daf3-4353-8e10-4ebd3be9abcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9099c0b5-daf3-4353-8e10-4ebd3be9abcb")) {                    Plotly.newPlot(                        "9099c0b5-daf3-4353-8e10-4ebd3be9abcb",                        [{"name":"Random Forest","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[],"type":"bar"},{"name":"KNN","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[31,3,0,0,0,0],"type":"bar"},{"name":"Mean/Mode","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[39,1,0,0,0,0],"type":"bar"},{"name":"Discriminative DL","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[27,4,0,0,0,0],"type":"bar"},{"name":"VAE","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[43,1,0,0,1,0],"type":"bar"},{"name":"GAIN","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[28,3,0,0,0,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size" ...

# %%
# split barchart stacks into missingness fractions

quantile_datasets = [df_01, df01, df03, df05, df07, df09]

fractions = ['0.01', '0.1', '0.3', '0.5']
print(fractions)


freq_001 = []
freq_01 = []
freq_03 = []
freq_05 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Fraction'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == '0.01'):
            freq_001.append(df_temp_len)
        elif (i == '0.1'):
            freq_01.append(df_temp_len)                                       
        elif (i == '0.3'):
            freq_03.append(df_temp_len)                                                 
        elif (i == '0.5'):
            freq_05.append(df_temp_len)                                       
                                        
                                       
print(freq_001)
print(freq_01)
print(freq_03)
print(freq_05)
# Out:
# ['0.01', '0.1', '0.3', '0.5']
# [57, 0, 0, 0, 0, 0]
# [57, 0, 0, 0, 0, 0]
# [52, 5, 0, 0, 0, 0]
# [49, 7, 0, 0, 1, 0]

# %%
quantiles = ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='1% Missing Data', x=quantiles, y=freq_001, marker_color='#FD3216'),
    go.Bar(name='10% Missing Data', x=quantiles, y=freq_01, marker_color='#00FE35'),
    go.Bar(name='30% Missing Data', x=quantiles, y=freq_03, marker_color='#511CFB'),
    go.Bar(name='50% Missing Data', x=quantiles, y=freq_05, marker_color='#FF7F0E'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_only_best_per_frac.pdf")
# Out:
# <div>                            <div id="037d35ea-fc4e-45fe-a018-59d0f76c4619" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("037d35ea-fc4e-45fe-a018-59d0f76c4619")) {                    Plotly.newPlot(                        "037d35ea-fc4e-45fe-a018-59d0f76c4619",                        [{"marker":{"color":"#FD3216"},"name":"1% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[57,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#00FE35"},"name":"10% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[57,0,0,0,0,0],"type":"bar"},{"marker":{"color":"#511CFB"},"name":"30% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[52,5,0,0,0,0],"type":"bar"},{"marker":{"color":"#FF7F0E"},"name":"50% Missing Data","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[49,7,0,0,1,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"ty ...

# %%
# split barchart stacks into missingness fractions

quantile_datasets = [df_01, df01, df03, df05, df07, df09]

fractions = ['MCAR', 'MAR', 'MNAR']
print(fractions)


freq_001 = []
freq_01 = []
freq_03 = []
#freq_05 = []
#print(quantile_datasets)

for i in fractions:
    for j in quantile_datasets:
        df_temp = j.copy()
        df_temp = df_temp[df_temp['Missing Type'].str.contains(i)]
        df_temp_len = len(df_temp.index)
        if (i == 'MCAR'):
            freq_001.append(df_temp_len)
        elif (i == 'MAR'):
            freq_01.append(df_temp_len)                                       
        elif (i == 'MNAR'):
            freq_03.append(df_temp_len)                                                                                      
                                        
                                       
print(freq_001)
print(freq_01)
print(freq_03)
# Out:
# ['MCAR', 'MAR', 'MNAR']
# [74, 2, 0, 0, 0, 0]
# [73, 3, 0, 0, 0, 0]
# [68, 7, 0, 0, 1, 0]

# %%
quantiles = ['less than 0.01', '0.01 to 0.03', '0.03 to 0.05', '0.05 to 0.07', '0.07 to 0.09', 'more than 0.09']


fig = go.Figure(data=[
    go.Bar(name='MCAR', x=quantiles, y=freq_001, marker_color='#222A2A'),
    go.Bar(name='MAR', x=quantiles, y=freq_01, marker_color='#B68100'),
    go.Bar(name='MNAR', x=quantiles, y=freq_03, marker_color='#750D86'),
])
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
fig.write_image("sub_improv_rel_to_av_all_DC_no_av_incl_only_best_per_patt.pdf")
# Out:
# <div>                            <div id="319938e2-fd39-48cb-8ca3-915021071045" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("319938e2-fd39-48cb-8ca3-915021071045")) {                    Plotly.newPlot(                        "319938e2-fd39-48cb-8ca3-915021071045",                        [{"marker":{"color":"#222A2A"},"name":"MCAR","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[74,2,0,0,0,0],"type":"bar"},{"marker":{"color":"#B68100"},"name":"MAR","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[73,3,0,0,0,0],"type":"bar"},{"marker":{"color":"#750D86"},"name":"MNAR","x":["less than 0.01","0.01 to 0.03","0.03 to 0.05","0.05 to 0.07","0.07 to 0.09","more than 0.09"],"y":[68,7,0,0,1,0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay"," ...

# %% [markdown]
# ## Extract datasets for Automated Imputation Method Selection -> not used in this thesis
#
# To Do: Explore the possibility, that the average best method replaces the best method for a data constellation, if the improvement gain for the best method is below 1%
#
# ### Potential Features:
# Missingess Pattern (Missing Type)
# Missing Fraction (Missing Fraction)
# Datapoints (NumberOfInstances)
# Features in total (NumberOfFeatures)
# Numeric Features (NumberOfNumericFeatures)
# Categorical Features (NumberOfCategoricalFeatures)
# Downstream Task Type -> Classification/Regression (metric)
#
#
#
# Label: Best Imputation Method (Imputation_Method)

# %%
# Use dataset with only the best method for each data constellation
rank_1_backup.to_csv('rank_1_backup.csv')
rank_1_backup
# Out:
#       Imputation_Method   Task Missing Type Missing Fraction    Column  \
# 0             Mean/Mode    189          MAR             0.01    theta8
# 6     Discriminative DL    189          MAR              0.1    theta8
# 12                  KNN    189          MAR              0.3    theta8
# 18    Discriminative DL    189          MAR              0.5    theta8
# 24    Discriminative DL    189         MCAR             0.01    theta8
# ...                 ...    ...          ...              ...       ...
# 1333      Random Forest  42712         MCAR              0.5  humidity
# 1339      Random Forest  42712         MNAR             0.01  humidity
# 1345      Random Forest  42712         MNAR              0.1  humidity
# 1351                VAE  42712         MNAR              0.3  humidity
# 1357      Random Forest  42712         MNAR              0.5  humidity
#
#                       result_type            metric    Baseline  Corrupted  \
# 0     downstream_performance_mean  Regression Tasks    0.225185        0.0
# 6     downstream_performance_mean  Regression Tasks    0.225352        0.0
# 12    downstream_performance_mean  Regression Tasks    0.226497        0.0
# 18    downstream_performance_mean  Regression Tasks    0.225885        0.0
# 24    downstream_performance_mean  Regression Tasks    0.225430        0.0
# ...                           ...               ...         ...        ...
# 1333  downstream_performance_mean  Regression Tasks  204.349055        0.0
# 1339  downstream_performance_mean  Regression Tasks  205.186741        0.0
# 1345  downstream_performance_mean  Regression Tasks  205.419418        0.0
# 1351  downstream_performance_mean  Regression Tasks  203.125694        0.0
# 1357  downstream_performance_mean  Regression Tasks  203.690837        0.0
#
#       Imputed_Subset  ...                 name MajorityClassSize  \
# 0           0.224662  ...               kin8nm               NaN
# 6           0.224106  ...               kin8nm               NaN
# 12          0.223568  ...               kin8nm               NaN
# 18          0.223194  ...               kin8nm               NaN
# 24          0.225247  ...               kin8nm               NaN
# ...              ...  ...                  ...               ...
# 1333      204.639271  ...  Bike_Sharing_Demand               NaN
# 1339      205.211177  ...  Bike_Sharing_Demand               NaN
# 1345      205.400159  ...  Bike_Sharing_Demand               NaN
# 1351      202.883274  ...  Bike_Sharing_Demand               NaN
# 1357      202.581392  ...  Bike_Sharing_Demand               NaN
#
#       MinorityClassSize  NumberOfFeatures  NumberOfInstances  \
# 0                   NaN               9.0             8192.0
# 6                   NaN               9.0             8192.0
# 12                  NaN               9.0             8192.0
# 18                  NaN               9.0             8192.0
# 24                  NaN               9.0             8192.0
# ...                 ...               ...                ...
# 1333                NaN              13.0            17379.0
# 1339                NaN              13.0            17379.0
# 1345                NaN              13.0            17379.0
# 1351                NaN              13.0            17379.0
# 1357                NaN              13.0            17379.0
#
#       NumberOfNumericFeatures  NumberOfCategoricalFeatures  NumberOfClasses  \
# 0                         9.0                          0.0              NaN
# 6                         9.0                          0.0              NaN
# 12                        9.0                          0.0              NaN
# 18                        9.0                          0.0              NaN
# 24                        9.0                          0.0              NaN
# ...                       ...                          ...              ...
# 1333                      9.0                          4.0              NaN
# 1339                      9.0                          4.0              NaN
# 1345                      9.0                          4.0              NaN
# 1351                      9.0                          4.0              NaN
# 1357                      9.0                          4.0              NaN
#
#       Downstream Performance Rank Subset  Data_Constellation
# 0                                    1.0          MAR - 0.01
# 6                                    1.0           MAR - 0.1
# 12                                   1.0           MAR - 0.3
# 18                                   1.0           MAR - 0.5
# 24                                   1.0         MCAR - 0.01
# ...                                  ...                 ...
# 1333                                 1.0          MCAR - 0.5
# 1339                                 1.0         MNAR - 0.01
# 1345                                 1.0          MNAR - 0.1
# 1351                                 1.0          MNAR - 0.3
# 1357                                 1.0          MNAR - 0.5
#
# [228 rows x 21 columns]

# %%
# Dataset for Training 
properties_train_dataset_8 = rank_1_backup.copy()
properties_train_dataset_8 = properties_train_dataset_8[['Imputation_Method','Missing Type','Missing Fraction',
                                                         'NumberOfInstances','NumberOfFeatures','NumberOfNumericFeatures',
                                                         'NumberOfCategoricalFeatures','metric']]

properties_train_dataset_8
# Out:
#       Imputation_Method Missing Type Missing Fraction  NumberOfInstances  \
# 0             Mean/Mode          MAR             0.01             8192.0
# 6     Discriminative DL          MAR              0.1             8192.0
# 12                  KNN          MAR              0.3             8192.0
# 18    Discriminative DL          MAR              0.5             8192.0
# 24    Discriminative DL         MCAR             0.01             8192.0
# ...                 ...          ...              ...                ...
# 1333      Random Forest         MCAR              0.5            17379.0
# 1339      Random Forest         MNAR             0.01            17379.0
# 1345      Random Forest         MNAR              0.1            17379.0
# 1351                VAE         MNAR              0.3            17379.0
# 1357      Random Forest         MNAR              0.5            17379.0
#
#       NumberOfFeatures  NumberOfNumericFeatures  NumberOfCategoricalFeatures  \
# 0                  9.0                      9.0                          0.0
# 6                  9.0                      9.0                          0.0
# 12                 9.0                      9.0                          0.0
# 18                 9.0                      9.0                          0.0
# 24                 9.0                      9.0                          0.0
# ...                ...                      ...                          ...
# 1333              13.0                      9.0                          4.0
# 1339              13.0                      9.0                          4.0
# 1345              13.0                      9.0                          4.0
# 1351              13.0                      9.0                          4.0
# 1357              13.0                      9.0                          4.0
#
#                 metric
# 0     Regression Tasks
# 6     Regression Tasks
# 12    Regression Tasks
# 18    Regression Tasks
# 24    Regression Tasks
# ...                ...
# 1333  Regression Tasks
# 1339  Regression Tasks
# 1345  Regression Tasks
# 1351  Regression Tasks
# 1357  Regression Tasks
#
# [228 rows x 8 columns]

# %%
# Dataset for Training 
properties_train_dataset_7 = rank_1_backup.copy()
properties_train_dataset_7 = properties_train_dataset_7[['Imputation_Method','Missing Type','Missing Fraction',
                                                         'NumberOfInstances','NumberOfFeatures','NumberOfNumericFeatures',
                                                         'NumberOfCategoricalFeatures']]

properties_train_dataset_7
properties_train_dataset_7.to_csv('properties_train_dataset_7.csv', index=False)
