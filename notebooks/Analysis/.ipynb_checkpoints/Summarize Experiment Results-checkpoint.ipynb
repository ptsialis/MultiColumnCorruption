# %% [markdown]
# # Summarize Experiment Results
#
# This notebook collects the information from the single results files from the experiments

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import seaborn as sns

from pathlib import Path
from experiment import read_experiment, read_csv_files

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Settings

# %%
sns.set(style="whitegrid")
sns.set_context('paper', font_scale=1.5)
mpl.rcParams['lines.linewidth'] = '2'

# %%
#Adjust EXPERIMENT depending on the analysis target, suggestions are commented below

EXPERIMENT = "experiment_multi_column_corrupted"
#corrupted_binary_experiment
#corrupted_multi_experiment
#corrupted_regression_experiment

EXPERIMENT_PATH = Path(f"../../results/{EXPERIMENT}/")

IMPUTE_RESULT_TYPE = "downstream_performance_mean"

CLF_METRIC = "Categorical Columns"
REG_METRIC = "Numerical Columns"
print(EXPERIMENT_PATH)
# Out:
# ../../results/experiment_multi_column_corrupted

# %% [markdown]
# ## Import the data

# %%
# %%time

results = read_csv_files(read_experiment(EXPERIMENT_PATH), read_details=False)
results
# Out:
# CPU times: user 23.1 s, sys: 741 ms, total: 23.8 s
# Wall time: 24.7 s
#                               experiment     imputer   task missing_type  \
# 0      experiment_multi_column_corrupted  KNNImputer     30         MNAR
# 1      experiment_multi_column_corrupted  KNNImputer     30         MNAR
# 2      experiment_multi_column_corrupted  KNNImputer     30         MNAR
# 3      experiment_multi_column_corrupted  KNNImputer     30         MNAR
# 4      experiment_multi_column_corrupted  KNNImputer     30         MNAR
# ...                                  ...         ...    ...          ...
# 41107  experiment_multi_column_corrupted  VAEImputer  42493         MCAR
# 41108  experiment_multi_column_corrupted  VAEImputer  42493         MCAR
# 41109  experiment_multi_column_corrupted  VAEImputer  42493         MCAR
# 41110  experiment_multi_column_corrupted  VAEImputer  42493         MCAR
# 41111  experiment_multi_column_corrupted  VAEImputer  42493         MCAR
#
#        missing_fraction    strategy  column                  result_type  \
# 0                  0.50  single_all   eccen       impute_performance_std
# 1                  0.50  single_all   eccen       impute_performance_std
# 2                  0.50  single_all   eccen       impute_performance_std
# 3                  0.30  single_all   eccen       impute_performance_std
# 4                  0.30  single_all   eccen       impute_performance_std
# ...                 ...         ...     ...                          ...
# 41107              0.01  single_all  Length  downstream_performance_mean
# 41108              0.01  single_all  Length  downstream_performance_mean
# 41109              0.10  single_all  Length  downstream_performance_mean
# 41110              0.10  single_all  Length  downstream_performance_mean
# 41111              0.10  single_all  Length  downstream_performance_mean
#
#             metric       train      test  baseline  corrupted   imputed
# 0              MAE   10.103773  0.295436       NaN        NaN       NaN
# 1              MSE  223.302351  0.301545       NaN        NaN       NaN
# 2             RMSE   10.103773  0.295436       NaN        NaN       NaN
# 3              MAE   10.103773  0.295436       NaN        NaN       NaN
# 4              MSE  223.302351  0.301545       NaN        NaN       NaN
# ...            ...         ...       ...       ...        ...       ...
# 41107     F1_macro         NaN       NaN  0.625821        0.0  0.625176
# 41108  F1_weighted         NaN       NaN  0.636672        0.0  0.636012
# 41109     F1_micro         NaN       NaN  0.641268        0.0  0.642380
# 41110     F1_macro         NaN       NaN  0.619542        0.0  0.621121
# 41111  F1_weighted         NaN       NaN  0.630430        0.0  0.631869
#
# [41112 rows x 14 columns]

# %%
#Adjust filename depending on the analysis target, suggestions are commented below

results.to_csv('multicolumn_corrupted.csv', index=False)

# binary_classification.csv  /  binary_classification_corrupted.csv
# multiclass_classification.csv  /  multiclass_classification_corrupted.csv
# regression.csv  /  regression_corrupted.csv
