# %% [markdown]
# # Summarize Experiment Results
#
# This notebook collects the information from the single results files from the experiments

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import seaborn as sns

from pathlib import Path
from experiment import read_experiment, read_csv_files

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Settings

# %%
sns.set(style="whitegrid")
sns.set_context('paper', font_scale=1.5)
mpl.rcParams['lines.linewidth'] = '2'

# %%
#Adjust EXPERIMENT depending on the analysis target, suggestions are commented below

EXPERIMENT = "test_imputed_corrupted"
#corrupted_binary_experiment
#corrupted_multi_experiment
#corrupted_regression_experiment

EXPERIMENT_PATH = Path(f"../../../results/{EXPERIMENT}/")

IMPUTE_RESULT_TYPE = "downstream_performance_mean"

CLF_METRIC = "Categorical Columns"
REG_METRIC = "Numerical Columns"
print(EXPERIMENT_PATH)
# Out:
# ..\..\..\results\test_imputed_corrupted

# %% [markdown]
# ## Import the data

# %%
# %%time

results = read_csv_files(read_experiment(EXPERIMENT_PATH), read_details=False)
results
# Out:
# Wall time: 609 ms
#                  experiment        imputer  task missing_type  \
# 0    test_imputed_corrupted  ForestImputer  1459         MCAR
# 1    test_imputed_corrupted  ForestImputer  1459         MCAR
# 2    test_imputed_corrupted  ForestImputer  1459         MCAR
# 3    test_imputed_corrupted  ForestImputer  1481         MCAR
# 4    test_imputed_corrupted  ForestImputer  1481         MCAR
# ..                      ...            ...   ...          ...
# 343  test_imputed_corrupted     KNNImputer  4552         MNAR
# 344  test_imputed_corrupted     KNNImputer  4552         MNAR
# 345  test_imputed_corrupted     KNNImputer     6         MNAR
# 346  test_imputed_corrupted     KNNImputer     6         MNAR
# 347  test_imputed_corrupted     KNNImputer     6         MNAR
#
#      missing_fraction       strategy column                  result_type  \
# 0                 0.5  single_single     V7       impute_performance_std
# 1                 0.5  single_single     V7       impute_performance_std
# 2                 0.5  single_single     V7       impute_performance_std
# 3                 0.5  single_single     V2       impute_performance_std
# 4                 0.5  single_single     V2       impute_performance_std
# ..                ...            ...    ...                          ...
# 343               0.5  single_single     V2  downstream_performance_mean
# 344               0.5  single_single     V2  downstream_performance_mean
# 345               0.5  single_single  x-box  downstream_performance_mean
# 346               0.5  single_single  x-box  downstream_performance_mean
# 347               0.5  single_single  x-box  downstream_performance_mean
#
#           metric     train      test  baseline  corrupted   imputed
# 0            MAE  0.011539  0.057807       NaN        NaN       NaN
# 1            MSE  0.377482  0.583563       NaN        NaN       NaN
# 2           RMSE  0.035738  0.054511       NaN        NaN       NaN
# 3            MAE  0.000827  0.001614       NaN        NaN       NaN
# 4            MSE  0.000296  0.003775       NaN        NaN       NaN
# ..           ...       ...       ...       ...        ...       ...
# 343     F1_macro       NaN       NaN  0.460263        0.0  0.462974
# 344  F1_weighted       NaN       NaN  0.757891        0.0  0.760829
# 345     F1_micro       NaN       NaN  0.961500        0.0  0.962083
# 346     F1_macro       NaN       NaN  0.961363        0.0  0.961861
# 347  F1_weighted       NaN       NaN  0.961625        0.0  0.962185
#
# [348 rows x 14 columns]

# %%
#Adjust filename depending on the analysis target, suggestions are commented below

results.to_csv('multicolumn_corrupted1.csv', index=False)

# binary_classification.csv  /  binary_classification_corrupted.csv
# multiclass_classification.csv  /  multiclass_classification_corrupted.csv
# regression.csv  /  regression_corrupted.csv
