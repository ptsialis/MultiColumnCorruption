# %% [markdown]
# # Summarize Experiment Results
#
# This notebook collects the information from the single results files from the experiments

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import re
import seaborn as sns

from pathlib import Path
from experiment import read_experiment, read_csv_files

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Settings

# %%
sns.set(style="whitegrid")
sns.set_context('paper', font_scale=1.5)
mpl.rcParams['lines.linewidth'] = '2'

# %%
#Adjust EXPERIMENT depending on the analysis target, suggestions are commented below

EXPERIMENT = "corrupted_test_autogluonasimputer2"
#corrupted_binary_experiment
#corrupted_multi_experiment
#corrupted_regression_experiment

EXPERIMENT_PATH = Path(f"../../../results/{EXPERIMENT}/")

IMPUTE_RESULT_TYPE = "corrupted_imputer_test_binary"

CLF_METRIC = "Categorical Columns"
REG_METRIC = "Numerical Columns"
print(EXPERIMENT_PATH)
# Out:
# ..\..\..\results\corrupted_test_autogluonasimputer2

# %% [markdown]
# ## Import the data

# %%
# %%time

results = read_csv_files(read_experiment(EXPERIMENT_PATH), read_details=False)
results
# Out:
# Wall time: 1.18 s
#                              experiment        imputer   task missing_type  \
# 0    corrupted_test_autogluonasimputer2  ForestImputer   1459         MNAR
# 1    corrupted_test_autogluonasimputer2  ForestImputer   1459         MNAR
# 2    corrupted_test_autogluonasimputer2  ForestImputer   1459         MNAR
# 3    corrupted_test_autogluonasimputer2  ForestImputer   1526         MNAR
# 4    corrupted_test_autogluonasimputer2  ForestImputer   1526         MNAR
# ..                                  ...            ...    ...          ...
# 211  corrupted_test_autogluonasimputer2     KNNImputer  41671         MNAR
# 212  corrupted_test_autogluonasimputer2     KNNImputer  41671         MNAR
# 213  corrupted_test_autogluonasimputer2     KNNImputer      6         MNAR
# 214  corrupted_test_autogluonasimputer2     KNNImputer      6         MNAR
# 215  corrupted_test_autogluonasimputer2     KNNImputer      6         MNAR
#
#      missing_fraction       strategy column                  result_type  \
# 0                 0.5  single_single     V7       impute_performance_std
# 1                 0.5  single_single     V7       impute_performance_std
# 2                 0.5  single_single     V7       impute_performance_std
# 3                 0.5  single_single     V3       impute_performance_std
# 4                 0.5  single_single     V3       impute_performance_std
# ..                ...            ...    ...                          ...
# 211               0.5  single_single     a9  downstream_performance_mean
# 212               0.5  single_single     a9  downstream_performance_mean
# 213               0.5  single_single  x-box  downstream_performance_mean
# 214               0.5  single_single  x-box  downstream_performance_mean
# 215               0.5  single_single  x-box  downstream_performance_mean
#
#           metric     train       test  baseline  corrupted   imputed
# 0            MAE  0.177793   0.961401       NaN        NaN       NaN
# 1            MSE  3.605765  13.375175       NaN        NaN       NaN
# 2           RMSE  0.188833   0.750593       NaN        NaN       NaN
# 3            MAE  0.051845   0.101510       NaN        NaN       NaN
# 4            MSE  0.067487   0.089376       NaN        NaN       NaN
# ..           ...       ...        ...       ...        ...       ...
# 211     F1_macro       NaN        NaN  0.419767        0.0  0.421251
# 212  F1_weighted       NaN        NaN  0.578056        0.0  0.578117
# 213     F1_micro       NaN        NaN  0.965750        0.0  0.966333
# 214     F1_macro       NaN        NaN  0.965488        0.0  0.966122
# 215  F1_weighted       NaN        NaN  0.965773        0.0  0.966360
#
# [216 rows x 14 columns]

# %%
#Adjust filename depending on the analysis target, suggestions are commented below

results.to_csv('corrupted_imputer_test_multi_autogluon.csv', index=False)

# binary_classification.csv  /  binary_classification_corrupted.csv
# multiclass_classification.csv  /  multiclass_classification_corrupted.csv
# regression.csv  /  regression_corrupted.csv
